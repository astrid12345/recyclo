# %% [markdown]
# The purpose of this notebook is to convert a COCO-ish dataset to a format that can be used to train an Ultralytics YOLO model.
#
# # Using this notebook: workflow
#
# To use, make a copy of this notebook, and adapt it to work with your specific dataset. Please save your version of this ipynb file on GitHub in *recyclo/scripts*.
#
# (File > Save a copy in GitHub > File path = "scripts/my_filename.ipynb" to save notebook in scripts folder)
#
# Once you've generated your YOLO dataset, and are confident you can train a model with it, please upload your converted dataset to the Recyclo datasets google drive, https://drive.google.com/drive/folders/1bUkIYQRXX08OKI5TuOSg-eqntSudGaFB.
#
# (Why Google Drive? Because these datasets are too large for GitHub!)
#
# # What's in this notebook: contents
#
# Notebook contents:
# - intro to YOLO
# - intro to COCO
# - dataset specific notes (update for your specific dataset)
# - convert dataset to simple COCO (update for your specific dataset)
# - convert simple COCO to YOLO
#
# # Pro tips about Colabs
#
# When you open the "Files" tab on the left, you'll find yourself in a folder containing
# * ..
# * sample data
#
# This is a colab thing, the "content" folder, to get you started.
# Ignore it: click the .. to go up a level.

# %% [markdown]
# # Intro to YOLO
#
# ## General
#
# In general, YOLO models output the following for a given image:
# * Bounding box
# * Class label
# * Confidence score
#
# To train a YOLO model, we need object detection datasets that contain images of what we're looking for (trash), and annotations: class labels and bounding boxes.
#
# ## Ultralytics YOLO
#
# In this project we will use Ultralytics YOLO object detection, eg their YOLO11n model. YOLO11n is a pretrained object detection model developed by Ultralytics.
#
# Ultralytics YOLO expects datasets in the following format:
#
# ```
# dataset/
# ├── images/
# │   ├── train/  <-- image files for training.
# │   ├── val/    <-- image files for validation after each epoch. Must not overlap with images in train.
# |   └── test/   <-- optional: can put some image files here for benchmarking.
# ├── labels/
# │   ├── train/  <-- one .txt file per train image (must have same name). Contains class and bbox info..
# │   ├── val/    <-- one .txt file per val image.
# |   └── test/   <-- one .txt file per test image.
# └── data.yaml   <-- config file; helps tie all the above together.
# ```
#
# Example labels/train file:
# ```
# <class_id> <x_center> <y_center> <width> <height>
# ```
#
# Example data.yaml file:
# ```
# path: /content/dataset  # Root folder
# train: images/train
# val: images/val
#
# nc: 5  # number of classes
# names: ['bottle', 'can', 'plastic bag', 'wrapper', 'paper']
#
# ```

# %% [markdown]
# # Intro to COCO
#
# ## General
# COCO, Common Objects in Context, is a object detection, segmentation, and captioning dataset developed by Microsoft. It uses an annotations.json file to organize image data. This json annotation approach has become standard for other datasets to use.
#
# Lots of datasets use COCO-style of formatting. In addition to the training images themselves, these datasets have at least one annotations json file which contains the following:
# *   "images":  List of image metadata
# *   "annotations":  List of label data (type of trash, bounding box definition, segmentation data; corresponds to images list)
# *   "categories":  List of the different categories this dataset uses
#
# An example of a COCO-style dataset file structure is as follows:
# ```
# dataset/
# ├── annotations/
# │   ├── instances_train2017.json
# │   ├── instances_val2017.json
# │   ├── person_keypoints_train2017.json
# │   ├── captions_train2017.json
# │   └── ... (other task-specific .json files)
# ├── images/
# │   ├── train2017/
# │   │   ├── 000000000009.jpg
# │   │   ├── 000000000025.jpg
# │   │   └── ...
# │   └── val2017/
# │       ├── 000000000139.jpg
# │       ├── 000000000285.jpg
# │       └── ...
# └── LICENSE.txt (optional)
# ```
#
# ## Simple COCO format required by the COCO-to-YOLO conversion function
#
#
# To use the COCO to YOLO conversion function below, your data set must conform to the following (vastly simplified) COCO-like directory structure and json structure. It's unlikely that your dataset will conform to these specifications out of the box, so please use the code section below to modify your data's structure to match.
#
# The simple COCO directory structure must be as follows, with a folder called "dataset" located in your "content" directory:
# ```
# dataset/
# ├── images/
# │   ├── 000001.jpg  # or png or whatever
# │   ├── 000002.jpg
# │   └── ...
# └── annotations.json
# ```
#
# And the annotations.json file must contain information in the following structure, and using the following json keywords:
# ```
# {
#   "images": [
#     {
#       "id": 0,
#       "file_name": "000000.jpg",
#       "width": 640,
#       "height": 480
#     },
#     {
#       "id": 1,
#       "file_name": "000001.jpg",
#       "width": 800,
#       "height": 600
#     }
#   ],
#   "annotations": [
#     {
#       "id": 0,
#       "image_id": 0,
#       "category_id": 0,
#       "bbox": [100, 120, 50, 60],
#       "area": 3000,
#       "iscrowd": 0
#     },
#     {
#       "id": 1,
#       "image_id": 1,
#       "category_id": 0,
#       "bbox": [20, 30, 40, 50],
#       "area": 2000,
#       "iscrowd": 0
#     }
#   ],
#   "categories": [
#     {
#       "id": 0,
#       "name": "trash"
#     }
#   ]
# }
# ```
# Note that there is only one category: "trash".

# %% [markdown]
# # Helpful functions
#
# This section has some helpful functions you can use later in this notebook.

# %%
# ⚠️ DO NOT MODIFY THIS CELL
# This cell sets up a helpful function for inspecting json file contents

import json
from pprint import pprint

def show_first_two_per_category(json_path):
    """
    Prints the first two entries of each root-level list in a JSON file.

    Useful for quickly inspecting the structure and content of a COCO-style
    annotations json file.

    It pretty-prints the first two entries of each top-level key that contains a list.

    Args:
        json_path (str or Path): Path to the JSON file to inspect.

    Raises:
        FileNotFoundError: If the provided path does not point to an existing file.
        json.JSONDecodeError: If the file is not valid JSON.
    """
    json_path = Path(json_path)

    if not json_path.exists():
        print(f"File not found: {json_path}")
        return

    with open(json_path, 'r') as f:
        data = json.load(f)

    for key, value in data.items():
        print(f"\n--- {key.upper()} (showing first 2 entries) ---")
        if isinstance(value, list):
            for item in value[:2]:
                pprint(item)
        else:
            print(f"{key} is not a list, skipping.")

# %% [markdown]
# ---
# ⚠️‼️ ***THE SECTION TO CHANGE FOR YOUR SPECIFIC DATASET STARTS HERE*** ‼️⚠️
#
# The sections above apply for all dataset conversions.
#
# ---

# %%
# ✏️ Enter your dataset-specific code here
# This cell is for importing your dataset to the notebook, and defining its name and path.

# TACO: Sometimes you have to wait a while or run this twice for it to show up in the file tree
# import kagglehub
from pathlib import Path

dataset_name = "TACO"
taco_dataset_path = Path('/kaggle/working/AquaTrash_dataset')
if not taco_dataset_path.exists():
    print(f"Cloning AquaTrash dataset to {taco_dataset_path}...")
    # !git clone https://github.com/Harsh9524/AquaTrash.git /kaggle/working/AquaTrash_dataset
    print(f"Dataset downloaded to {taco_dataset_path}\n")
else:
    print(f"Dataset directory {taco_dataset_path} already exists. Skipping clone.\n")

print(f"{dataset_name} dataset downloaded to {taco_dataset_path}\n")
# Out:
# Cloning AquaTrash dataset to /kaggle/working/AquaTrash_dataset...
# Cloning into '/kaggle/working/AquaTrash_dataset'...
# remote: Enumerating objects: 2948, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 2948 (delta 22), reused 6 (delta 1), pack-reused 2902 (from 1)
# Receiving objects: 100% (2948/2948), 122.45 MiB | 16.83 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# Dataset downloaded to /kaggle/working/AquaTrash_dataset
#
# TACO dataset downloaded to /kaggle/working/AquaTrash_dataset

# %%
# ✏️ Enter your dataset-specific code here
# This cell is for inspecting your annotations json file(s), to help discover some of the quirks your dataset has

show_first_two_per_category(taco_dataset_path / "data" / "annotations.json")
# Out:
# File not found: /kaggle/working/AquaTrash_dataset/data/annotations.json

# %% [markdown]
# # TACO dataset
# ✏️ Modify this section for your specific dataset.
#
# The TACO dataset uses COCO-style formatting (it has segmentation).
#
# ## Quirks
#
# TACO has 15 batch folders, each containing jpgs with names like 000000.jpg, 000001.jpg, 000002.jpg, etc.
# * Some numbers are skipped, eg 000000.jpg, 000001.jpg, 000003.jpg.
# * The name 000000.jpg is used in multiple batch folders, to name different image files.
# * It contains segmentation data (will be discarded).
# * It uses categories (specific) and supercategories (more general) - only the supercategories will be retained.
# * It includes scene categories (eg clearn streets) - this will be discarded.
#   * It might be interesting in the future to consider using a multi-tasking model - detecting trash and also classsifying the scene might improve the models performance by adding a bit of context awareness.
#
# ## Conversion
# To convert the TACO dataset to a format ultralytics YOLO can use, we must:
# * Give the images unique names
# * Split the TACO images into train and val sets
# * Extract label and bbox info from annotations.json, and save it in individual txt files corresponding to the image files
# * Make a data.yaml file

# %%
import json
import shutil
import random
from pathlib import Path
from sklearn.model_selection import train_test_split
import yaml
import pandas as pd
from PIL import Image
from collections import defaultdict # Import defaultdict

# === IMPORT DATASET ===
dataset_target_path = Path('/kaggle/working/AquaTrash_dataset')
if not dataset_target_path.exists():
    print(f"Cloning AquaTrash dataset to {dataset_target_path}...")
    # !git clone https://github.com/Harsh9524/AquaTrash.git /kaggle/working/AquaTrash_dataset
    print(f"Dataset downloaded to {dataset_target_path}\n")
else:
    print(f"Dataset directory {dataset_target_path} already exists. Skipping clone.\n")

# === CONFIG ===
input_root = Path('/kaggle/working/AquaTrash_dataset')
# Output directory for the simple COCO format data
simple_coco_output_root = Path('/kaggle/working/aquatrash_simple_coco')
dataset_name = "AquaTrash" # Define dataset name for the output YOLO dataset


# Create simple COCO output folders
simple_coco_images_dir = simple_coco_output_root / 'images'
simple_coco_images_dir.mkdir(parents=True, exist_ok=True)

# === LOAD ANNOTATIONS ===
IMAGE_SOURCE_DIR = 'Images'

try:
    annotations_df = pd.read_csv(
        input_root / 'annotations.csv',
        dtype={'x_min': float, 'y_min': float, 'x_max': float, 'y_max': float}
    )

    def get_image_size(image_path):
        try:
            with Image.open(image_path) as img:
                return img.size
        except FileNotFoundError:
            # print(f"Warning: Image file not found when trying to get size: {image_path}") # Too chatty
            return None
        except Exception as e:
            print(f"Error getting size of image {image_path}: {e}")
            return None

    # Prepare data for simple COCO format
    simple_coco_images = []
    simple_coco_annotations = []
    simple_coco_categories = []

    # Create category map
    unique_class_names = annotations_df['class_name'].drop_duplicates().tolist()
    unique_class_names.sort() # Ensure consistent class IDs
    category_map = {name: idx for idx, name in enumerate(unique_class_names)}

    simple_coco_categories = [{"id": idx, "name": name} for name, idx in category_map.items()]


    image_id_counter = 0
    annotation_id_counter = 0

    # Collect unique image names from the CSV that actually have corresponding files
    # and build the simple_coco_images list and a mapping for quick lookup
    image_name_to_simple_coco_id = {}

    # Iterate through unique image names in the CSV to find existing files and get their sizes
    processed_image_count = 0
    for original_image_name_in_csv in annotations_df['image_name'].drop_duplicates():
        # Construct the full image path using the correct image directory
        img_path_full = input_root / IMAGE_SOURCE_DIR / original_image_name_in_csv

        size = get_image_size(img_path_full)
        if size:
            width, height = size
            # Assign a new sequential ID for the simple COCO format
            simple_coco_id = image_id_counter
            image_name_to_simple_coco_id[original_image_name_in_csv] = simple_coco_id

            simple_coco_images.append({
                "id": simple_coco_id,
                "file_name": original_image_name_in_csv, # Use the name from the CSV directly for now
                "width": width,
                "height": height
            })
            image_id_counter += 1
            processed_image_count += 1
            if processed_image_count % 100 == 0:
                print(f"Processed info for {processed_image_count} unique images...")
        # else:
            # Warning about missing image is handled in get_image_size function
            # print(f"Skipping image {original_image_name_in_csv} due to missing file or size error.")


    print(f"Finished processing info for {processed_image_count} unique images that exist on disk.")


    # Create simple_coco_annotations from the DataFrame
    skipped_annotations_count = 0
    for index, row in annotations_df.iterrows():
        original_image_name_in_csv = row['image_name']

        # Check if the image associated with this annotation was successfully added to simple_coco_images
        if original_image_name_in_csv in image_name_to_simple_coco_id:
            image_id = image_name_to_simple_coco_id[original_image_name_in_csv]
            class_name = row['class_name']

            if class_name in category_map:
                category_id = category_map[class_name]
                bbox = [row['x_min'], row['y_min'], row['x_max'], row['y_max']]
                # Calculate area (simple bounding box area)
                area = (bbox[2] - bbox[0]) * (bbox[3] - bbox[1])

                simple_coco_annotations.append({
                    "id": annotation_id_counter,
                    "image_id": image_id,
                    "category_id": category_id,
                    "bbox": bbox, # Keep as [x_min, y_min, width, height] for now, conversion function expects this
                    "area": area,
                    "iscrowd": 0 # Assuming no crowded objects for simplicity
                })
                annotation_id_counter += 1
            else:
                # This case should be rare if category_map is built from the same data
                print(f"Warning: Skipping annotation for image {original_image_name_in_csv} with unknown class '{class_name}'.")
                skipped_annotations_count += 1
        else:
            # This annotation belongs to an image that was skipped (e.g., missing file)
            # print(f"Warning: Skipping annotation for image {original_image_name_in_csv} because the image was not processed.") # Too chatty
            skipped_annotations_count += 1


    print(f"Finished processing {len(simple_coco_annotations)} annotations. Skipped {skipped_annotations_count} annotations.")


    # Write the simple COCO annotations.json file
    simple_coco_json_data = {
        "images": simple_coco_images,
        "annotations": simple_coco_annotations,
        "categories": simple_coco_categories
    }

    simple_coco_json_path = simple_coco_output_root / 'annotations.json'
    with open(simple_coco_json_path, 'w') as f:
        json.dump(simple_coco_json_data, f, indent=4)

    print(f"Simple COCO annotations saved to {simple_coco_json_path}")

    # Copy image files to the simple COCO images directory
    print(f"\nCopying image files to {simple_coco_images_dir}...")
    copied_image_count = 0
    for img_info in simple_coco_images:
        original_file_name = img_info['file_name']
        source_image_path = input_root / IMAGE_SOURCE_DIR / original_file_name
        target_image_path = simple_coco_images_dir / original_file_name

        if source_image_path.exists():
            shutil.copy(source_image_path, target_image_path)
            copied_image_count += 1
            if copied_image_count % 100 == 0:
                 print(f"  Copied {copied_image_count}/{len(simple_coco_images)} images...")

    print(f"Finished copying {copied_image_count} images.")


except pd.errors.EmptyDataError:
    print(f"Error: The file {input_root / 'annotations.csv'} is empty.")
except FileNotFoundError:
    print(f"Error: The file {input_root / 'annotations.csv'} was not found.")
except KeyError as e:
    print(f"Error: Missing expected column in annotations.csv: {e}. Please check your column names ('image_name', 'x_min', 'y_min', 'x_max', 'y_max', 'class_name').")
except Exception as e:
    print(f"An unexpected error occurred while processing the CSV file: {e}")


# === CONVERT SIMPLE COCO TO YOLO USING THE PROVIDED FUNCTION ===
# Call the conversion function here with the path to the simple COCO dataset
print("\nConverting simple COCO to YOLO format...")
# The convert_coco_to_yolo function expects a Path object to the root of the simple COCO dataset
yolo_data_yaml_path = convert_coco_to_yolo(simple_coco_output_root, dataset_name)

print(f"\nYOLO dataset created at: {yolo_data_yaml_path.parent}")
print(f"Data YAML file: {yolo_data_yaml_path}")

# Store the path to the data.yaml file in a variable that can be used by subsequent cells
output_root = yolo_data_yaml_path.parent # Set output_root to the root of the generated YOLO dataset
# Out:
# Dataset directory /kaggle/working/AquaTrash_dataset already exists. Skipping clone.
#
# Processed info for 100 unique images...
# Processed info for 200 unique images...
# Processed info for 300 unique images...
# Finished processing info for 369 unique images that exist on disk.
# Finished processing 469 annotations. Skipped 0 annotations.
# Simple COCO annotations saved to /kaggle/working/aquatrash_simple_coco/annotations.json
#
# Copying image files to /kaggle/working/aquatrash_simple_coco/images...
#   Copied 100/369 images...
#   Copied 200/369 images...
#   Copied 300/369 images...
# Finished copying 369 images.
#
# Converting simple COCO to YOLO format...
# Dataset split: Train=295 images, Validation=37 images, Test=37 images
# Processing split for images/train...
#   Processed 100/295 images for train...
#   Processed 200/295 images for train...
# Finished processing for train. Copied 295 images. Wrote 295 label files.
# Processing split for images/val...
# Finished processing for val. Copied 37 images. Wrote 37 label files.
# Processing split for images/test...
# Finished processing for test. Copied 37 images. Wrote 37 label files.
#
# Generated data.yaml at /kaggle/working/AquaTrash_yolo/data.yaml
#
# YOLO dataset created at: /kaggle/working/AquaTrash_yolo
# Data YAML file: /kaggle/working/AquaTrash_yolo/data.yaml

# %% [markdown]
# ---
# ⚠️‼️ ***THE SECTION TO CHANGE FOR YOUR SPECIFIC DATASET STOPS HERE*** ‼️⚠️
#
# The sections below apply for all dataset conversions.
#
# ---

# %%
# ⚠️ DO NOT MODIFY THIS CELL
# This cell shows part of your annotations.json file to make sure the format and field names match the required simple COCO format

show_first_two_per_category(target_root / "annotations.json")
# Out:
# --- IMAGES (showing first 2 entries) ---
# {'file_name': '000000.jpg', 'height': 2049, 'id': 0, 'width': 1537}
# {'file_name': '000001.jpg', 'height': 2049, 'id': 1, 'width': 1537}
#
# --- ANNOTATIONS (showing first 2 entries) ---
# {'area': 403954.0,
#  'bbox': [517.0, 127.0, 447.0, 1322.0],
#  'category_id': 0,
#  'id': 0,
#  'image_id': 0,
#  'iscrowd': 0}
# {'area': 1071259.5,
#  'bbox': [1.0, 457.0, 1429.0, 1519.0],
#  'category_id': 0,
#  'id': 1,
#  'image_id': 1,
#  'iscrowd': 0}
#
# --- CATEGORIES (showing first 2 entries) ---
# {'id': 0, 'name': 'trash'}

# %%
# ⚠️ DO NOT MODIFY THIS CELL
# This cell executes the simple COCO dataset to YOLO conversion

# Use the output_root defined in the data processing cell
# target_root = output_root # No longer needed as conversion happens in the previous cell
# dataset_name = "AquaTrash" # Define dataset_name based on the dataset being processed

# yolo_data = convert_coco_to_yolo(target_root, dataset_name) # Remove this line
print(f"YOLO data.yaml path is stored in the variable `output_root`: {output_root / 'data.yaml'}")
# Out:
# YOLO data.yaml path is stored in the variable `output_root`: /kaggle/working/AquaTrash_yolo/data.yaml

# %% [markdown]
# To verify that your conversion worked, make sure you can train a model and that it outputs images with a bounding box and label.

# %%
# ⚠️ DO NOT MODIFY THIS CELL
# This cell imports the ultralytics library required for training a model

# !pip install -U ultralytics

from ultralytics import YOLO
import os
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.152-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.152-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 63.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 94.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 106.7 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.152 ultralytics-thop-2.0.14
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# ⚠️ DO NOT MODIFY THIS CELL
# This cell sets up the function that converts the simple COCO dataset to YOLO format

import shutil
import random
import yaml
from collections import defaultdict

def convert_coco_to_yolo(coco_root: Path, dataset_name: str, train_split: float = 0.8):
    """
    Converts a simple COCO dataset to YOLOv8 format, including train/val split and data.yaml generation.

    Args:
        coco_root (Path): Path to the root of the simple COCO dataset (should contain images/ and annotations.json).
        dataset_name (str): Name of the output dataset folder (e.g., "taco" -> creates "taco_yolo").
        train_split (float, optional): Fraction of images to use for training. Defaults to 0.8.
          The remaining images are split between validation and testing.

    Returns:
        Path: Path to the data.yaml file
    """
    # Paths
    coco_json_path = coco_root / 'annotations.json'
    coco_images_path = coco_root / 'images'

    # Load COCO JSON and get number of images for naming
    with open(coco_json_path, 'r') as f:
        coco = json.load(f)
    n_total = len(coco['images'])

    # Paths con't
    yolo_root = coco_root.parent / f"{dataset_name}_yolo_{n_total}"
    yolo_img_dirs = {
        'train': yolo_root / 'images' / 'train',
        'val': yolo_root / 'images' / 'val',
        'test': yolo_root / 'images' / 'test',
    }
    yolo_lbl_dirs = {
        'train': yolo_root / 'labels' / 'train',
        'val': yolo_root / 'labels' / 'val',
        'test': yolo_root / 'labels' / 'test',
    }

    # Clear and recreate folders
    for d in list(yolo_img_dirs.values()) + list(yolo_lbl_dirs.values()):
        if d.exists():
            shutil.rmtree(d)
        d.mkdir(parents=True, exist_ok=True)

    # Map image_id -> metadata
    image_info = {img['id']: (img['width'], img['height'], img['file_name']) for img in coco['images']}

    # Map image_id -> annotations
    annots_per_image = defaultdict(list)
    for ann in coco['annotations']:
        annots_per_image[ann['image_id']].append(ann)

    # Shuffle and split image IDs
    all_image_ids = list(image_info.keys())
    random.shuffle(all_image_ids)
    n_total = len(all_image_ids)
    n_train = int(n_total * train_split)
    n_val = int((n_total - n_train) / 2)
    n_test = n_total - n_train - n_val

    split_ids = {
        'train': set(all_image_ids[:n_train]),
        'val': set(all_image_ids[n_train:n_train + n_val]),
        'test': set(all_image_ids[n_train + n_val:]),
    }

    def write_labels_and_copy_images(image_ids, img_dir, lbl_dir):
        for image_id in image_ids:
            width, height, filename = image_info[image_id]
            orig_stem = Path(filename).stem
            new_stem = f"{dataset_name}_{orig_stem}"
            label_path = lbl_dir / f"{new_stem}.txt"
            image_src = coco_images_path / filename
            image_dst = img_dir / f"{new_stem}.jpg"

            # Copy image
            if image_src.exists():
                shutil.copy(image_src, image_dst)
            else:
                print(f"Warning: Image not found: {image_src}")
                continue

            # Write labels
            with open(label_path, 'w') as f:
                for ann in annots_per_image.get(image_id, []):
                    class_id = ann['category_id']
                    x, y, w, h = ann['bbox']
                    x_center = (x + w / 2) / width
                    y_center = (y + h / 2) / height
                    w /= width
                    h /= height
                    f.write(f"{class_id} {x_center:.6f} {y_center:.6f} {w:.6f} {h:.6f}\n")

    # Process splits
    for split in ['train', 'val', 'test']:
        write_labels_and_copy_images(
            split_ids[split],
            yolo_img_dirs[split],
            yolo_lbl_dirs[split]
        )

    # Build data.yaml
    categories = sorted(coco['categories'], key=lambda x: x['id'])
    names = [cat['name'] for cat in categories]
    data_yaml = {
        'path': str(yolo_root),
        'train': 'images/train', # Corrected path
        'val': 'images/val',     # Corrected path
        'test': 'images/test',
        'nc': len(names),
        'names': names
    }

    with open(yolo_root / 'data.yaml', 'w') as f:
        yaml.dump(data_yaml, f)

    print(f"YOLO conversion complete: {yolo_root}")
    print(f"  Train: {len(split_ids['train'])}, Val: {len(split_ids['val'])}, Test: {len(split_ids['test'])}")
    return yolo_root / 'data.yaml'

# %%
# ⚠️ DO NOT MODIFY THIS CELL
# This cell trains a YOLO model on the converted YOLO dataset to see if it's set up correctly
# Tip: inspect the output of this cell to assess whether training occured properly.

model = YOLO('yolo11n.pt')
# Use the output_root directly as the data path
results = model.train(data=str(output_root / 'data.yaml'), epochs=20, imgsz=640)  # epoch size is small - this is just to see if it can work!
# Out:
# Ultralytics 8.3.152 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/AquaTrash_yolo/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 662.7±364.2 MB/s, size: 23.7 KB)
# train: Scanning /kaggle/working/AquaTrash_yolo/labels/train.cache... 295 images, 0 backgrounds, 0 corrupt: 100%|██████████| 295/295 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 505.1±222.9 MB/s, size: 174.3 KB)
# val: Scanning /kaggle/working/AquaTrash_yolo/labels/val.cache... 37 images, 0 backgrounds, 0 corrupt: 100%|██████████| 37/37 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20       2.4G      2.473      3.187       2.77         22        640: 100%|██████████| 19/19 [00:10<00:00,  1.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.67it/s]
#                    all         37         45    0.00396      0.978     0.0937     0.0394
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      2.79G      2.054      2.973      2.318         18        640: 100%|██████████| 19/19 [00:07<00:00,  2.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.67it/s]
#                    all         37         45    0.00396      0.978      0.132     0.0427
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20       2.8G      2.078      2.859      2.321         20        640: 100%|██████████| 19/19 [00:07<00:00,  2.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.58it/s]
#                    all         37         45      0.045      0.178     0.0542     0.0203
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20       2.8G      2.064      2.823      2.328         21        640: 100%|██████████| 19/19 [00:08<00:00,  2.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.55it/s]
#                    all         37         45      0.453      0.222      0.262     0.0676
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      2.81G       2.08      2.777      2.321         18        640: 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.21it/s]
#                    all         37         45     0.0575     0.0444     0.0447     0.0155
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      2.81G      1.986      2.676       2.24         22        640: 100%|██████████| 19/19 [00:07<00:00,  2.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.29it/s]
#                    all         37         45     0.0528        0.2     0.0459     0.0115
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      2.82G      1.938      2.672      2.229         15        640: 100%|██████████| 19/19 [00:08<00:00,  2.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.31it/s]
#                    all         37         45     0.0683     0.0889     0.0356      0.011
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20      2.83G      1.897      2.627      2.204         12        640: 100%|██████████| 19/19 [00:07<00:00,  2.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.89it/s]
#                    all         37         45      0.257      0.267      0.183     0.0638
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      2.83G      1.892      2.561      2.196         23        640: 100%|██████████| 19/19 [00:06<00:00,  2.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.07it/s]
#                    all         37         45      0.272      0.267      0.199      0.108
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20      2.83G      1.909       2.53      2.193         17        640: 100%|██████████| 19/19 [00:07<00:00,  2.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.90it/s]
#                    all         37         45      0.326      0.467       0.33      0.192
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20      2.83G      1.618      2.678      2.106          7        640: 100%|██████████| 19/19 [00:11<00:00,  1.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.56it/s]
#                    all         37         45      0.601      0.489      0.464      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      2.83G      1.562      2.423      2.062          9        640: 100%|██████████| 19/19 [00:07<00:00,  2.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.72it/s]
#                    all         37         45      0.267      0.578       0.22      0.111
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      2.83G      1.454       2.35       1.93         10        640: 100%|██████████| 19/19 [00:06<00:00,  3.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.19it/s]
#                    all         37         45      0.407      0.467      0.315      0.161
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      2.83G      1.482      2.263      1.937         10        640: 100%|██████████| 19/19 [00:07<00:00,  2.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.61it/s]
#                    all         37         45      0.369      0.599      0.438      0.272
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      2.83G      1.532      2.279      1.968         10        640: 100%|██████████| 19/19 [00:07<00:00,  2.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.96it/s]
#                    all         37         45      0.672      0.556      0.592      0.358
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      2.83G      1.437      2.196      1.887          8        640: 100%|██████████| 19/19 [00:06<00:00,  3.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.98it/s]
#                    all         37         45      0.423      0.667      0.377       0.21
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      2.83G      1.439       2.13      1.881         10        640: 100%|██████████| 19/19 [00:07<00:00,  2.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.57it/s]
#                    all         37         45      0.383       0.62      0.338      0.168
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      2.83G      1.396      2.093      1.868          9        640: 100%|██████████| 19/19 [00:06<00:00,  2.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.87it/s]
#                    all         37         45      0.399      0.644      0.413      0.228
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      2.83G      1.475       2.09      1.902         10        640: 100%|██████████| 19/19 [00:06<00:00,  3.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.39it/s]
#                    all         37         45      0.425      0.689      0.406      0.216
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      2.83G      1.423      2.108      1.851          8        640: 100%|██████████| 19/19 [00:07<00:00,  2.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.19it/s]
#                    all         37         45       0.41       0.71      0.425      0.239
# 20 epochs completed in 0.051 hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 5.5MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 5.5MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.152 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.48it/s]
#                    all         37         45      0.672      0.556      0.593      0.359
# Speed: 0.2ms preprocess, 3.6ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to runs/detect/train2

# %% [markdown]
# If the model outputs even one image with a bounding box and label, then the dataset should work for our project! Verify this using the code below.

# %%
# ⚠️ DO NOT MODIFY THIS CELL
# This cell passes the trained model some images, to see if the model can identify some trash

import cv2
from random import sample
import matplotlib.pyplot as plt
import os # Moved import here

# Get the latest model
runs_detect_dir = Path('runs/detect')
train_dirs = [d for d in runs_detect_dir.iterdir() if d.is_dir() and d.name.startswith("train")]
train_dirs.sort(key=lambda d: d.stat().st_mtime, reverse=True)  # sort by modification time
latest_train_dir = train_dirs[0]
best_model_path = latest_train_dir / 'weights' / 'best.pt'
print(f"Loading {best_model_path}")

# Load the model and try it out
model = YOLO(best_model_path)
train_images_path = output_root / "images" / "train" # Corrected path to use output_root
image_files = list(train_images_path.glob('*.jpg'))

sample_images = sample(image_files, 10)

for image_path in sample_images:
    result = model(image_path)[0]
    annotated_image = result.plot()

    plt.figure(figsize=(8, 6))
    plt.imshow(annotated_image)
    plt.title(f'Predictions: {image_path.name}')
    plt.axis('off')
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# If the model successfully generated even one image with a bounding box and label, please run the following code block to zip the taco_yolo dataset, download the zipped file, and upload it on Google Drive, https://www.google.com/url?q=https%3A%2F%2Fdrive.google.com%2Fdrive%2Ffolders%2F1bUkIYQRXX08OKI5TuOSg-eqntSudGaFB.

# %%
import zipfile
import os
from pathlib import Path
from google.colab import files

def zip_and_download_folder(folder_path, zip_name=None):
    """
    Zips a specified folder and triggers a download in Google Colab.

    Args:
        folder_path (str or Path): The path to the folder to zip.
        zip_name (str, optional): The name of the output zip file.
                                  If None, uses the folder name with a .zip extension.
    """
    folder_path = Path(folder_path)

    if not folder_path.is_dir():
        print(f"Error: Folder not found at {folder_path}")
        return

    if zip_name is None:
        zip_name = f"{folder_path.name}.zip"

    # Ensure the zip name has a .zip extension
    if not zip_name.lower().endswith('.zip'):
        zip_name += '.zip'

    print(f"Creating zip archive: {zip_name} from {folder_path}...")

    try:
        with zipfile.ZipFile(zip_name, 'w', zipfile.ZIP_DEFLATED) as zipf:
            for root, dirs, files_in_dir in os.walk(folder_path):
                # Create archive path relative to the folder_path
                arc_root = Path(root).relative_to(folder_path)
                for file in files_in_dir:
                    file_path = Path(root) / file
                    arc_path = arc_root / file
                    zipf.write(file_path, arc_path)
        print("Zip archive created successfully.")

        # Trigger download
        print(f"Downloading {zip_name}...")
        files.download(zip_name)
        print("Download triggered.")

    except Exception as e:
        print(f"An error occurred during zipping or downloading: {e}")

# %%
# ⚠️ DO NOT MODIFY THIS CELL
# This cell zips your converted YOLO dataset with an informative name, so you can download it and upload it to google drive.

from datetime import datetime
from pathlib import Path
import os

# Generate date prefix
date_str = datetime.now().strftime('%Y%m%d')

# Define the folder to zip (the final YOLO dataset folder)
folder_to_zip = output_root # output_root is set to the path of the generated YOLO dataset

# Define the name of the output zip file
# Using the parent directory name in the zip name might be confusing if the folder to zip is the final output
# Let's use the folder_to_zip name directly for the zip name prefix
zip_name = f"{date_str}_{folder_to_zip.name}.zip"

# Define the full path for the output zip file
output_zip_path = Path('/content') / zip_name

# Change directory to the parent of the folder to zip so the zip command includes the folder itself
# Or, more simply, use the zip command directly on the folder_to_zip path
# %cd {folder_to_zip.parent} # No need to change directory if zipping directly

print(f"Creating zip archive from {folder_to_zip}...")

# Use the zip command to archive the specific folder
# The -r flag is for recursive zipping (includes subdirectories)
# The first argument is the output zip file path
# The second argument is the folder to be zipped (relative to the current directory or absolute path)
# We will use the absolute path to the folder_to_zip
# !zip -r {output_zip_path} {folder_to_zip}

print(f"Zip created at {output_zip_path}")
# Out:
# Creating zip archive from /kaggle/working/AquaTrash_yolo...
#   adding: kaggle/working/AquaTrash_yolo/ (stored 0%)
#   adding: kaggle/working/AquaTrash_yolo/data.yaml (deflated 20%)
#   adding: kaggle/working/AquaTrash_yolo/labels/ (stored 0%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/ (stored 0%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000098_JPG.rf.a5665b7913007535189b824dfb05aedc.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000082_jpg.rf.aa55332900465a30687548c20145a4e4.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000021_jpg.rf.686ef3b74a19214af6e22e15ad692bca.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000020_JPG.rf.ebbafb64b09f4937003dcda6b94d27ee.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000024_jpg.rf.5545363767994e0edf0a31ceda3dc6e5.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000086_jpg.rf.21d6c190ab94e71b2f49fb97de73d378.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000022_jpg.rf.24374a2700679021d5ab94c2ad2434e7.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000017_jpg.rf.1b16bea2730faf919fea7016568d1630.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000124_JPG.rf.11c5626f03313f2a2700d2131bbee98e.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000064_jpg.rf.a1cc41f6879e58b49881a28cd5ea539c.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000041_jpg.rf.92043de1d993c43f5aa9b77afd2f1d63.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000054_jpg.rf.24392ce9c7bd1720c838a311c17f958e.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000077_jpg.rf.37455f94e58126e1310cae690bdf8e25.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000063_jpg.rf.52308eca5e26989dbf3d5d54da6e7dc4.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000071_jpg.rf.03e05c930100da1c0facea5f23b89f7d.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000049_jpg.rf.3dc5ad8a124f2516da33d49496ff55dc.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000011_jpg.rf.8b7fff6ea8f7330e402b6a7757b1866b.txt (deflated 19%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000006_jpg.rf.33a70c1d2244237b53e6924046000d26.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000004_jpg.rf.a08d4635ed056a7cc41f66fefa9eccc4.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000066_JPG.rf.4d451656ce9628a9eb263c2b47828227.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000061_jpg.rf.e15cc3e3cd9bc8fb042b83bfaae11857.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000128_JPG.rf.eb71904df1426bfc208c7f961ae52d22.txt (deflated 48%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000079_jpg.rf.29fa0266416a159608cf24b4e72c0b6a.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000091_JPG.rf.6ab34e036290bbab1a78573b63cfb996.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000084_JPG.rf.942837bfb405ac2730506b6f511f608e.txt (deflated 39%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000002_jpg.rf.cc63f3f198e4bafa011b425d63252066.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000039_JPG.rf.18085a5d84e17aca7dbc278f39f141a0.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000009_jpg.rf.8434a803f417f51fe5ebe4f6b9697cce.txt (deflated 32%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000010_jpg.rf.d731a0e01f49ec0a95a0f3a1b10ef155.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000035_jpg.rf.50f05fa6ede845869668871e91e31f71.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000042_jpg.rf.01523622698a610b1e98c82007f8d91f.txt (deflated 27%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000064_jpg.rf.d848c83989a9551ef394ff479572f411.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000054_jpg.rf.3fa00c0cefb8d7fac889afd3fbfff716.txt (deflated 27%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000058_jpg.rf.04df31ce152c94461e36817d87803047.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000069_jpg.rf.cb1b72feff05a77571afa6dcdcccc334.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000061_jpg.rf.d9ca75b67361d9fcc54b1c8962457f19.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val/000001_jpg.rf.42c4ba88119aae9d425f5c004cb2ce0d.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/val.cache (deflated 73%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/ (stored 0%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000094_JPG.rf.b6241bd0418850c0ca1916017d039774.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000012_jpg.rf.c50f074f2cd7a6b5362f0c6f98300848.txt (deflated 31%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000085_JPG.rf.6601a3f912670beac53085714278db85.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000025_jpg.rf.27b0c7d7e6bb159099bf20cc703c2662.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000037_jpg.rf.313662ef20a5ccca5fc196365095bf22.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000030_jpg.rf.decccf4babe0f1d8526ce55ce0d931d0.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000041_jpg.rf.a45728032928eb56e55b61ebf7d5a5a0.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000080_jpg.rf.905783efbe74ab1c175fa94d5697d4e0.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000048_jpg.rf.d1fe2466217a45a9b771617022ee7c18.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000029_jpg.rf.cf85d3fcd918116e30994de824d50752.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000097_jpg.rf.5ee362e58370980eb351d337f6409ef4.txt (deflated 28%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000021_jpg.rf.22832d293d317b13e588374218a71e00.txt (deflated 36%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000000_jpg.rf.beffaf3b548106ccf1da5dc629bc9504.txt (deflated 28%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000015_jpg.rf.eebd5ba151182f6edadd573ffdf6fe85.txt (deflated 35%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000019_jpg.rf.cdf730508ce823ef87c6ee777bf9cf1c.txt (deflated 28%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000007_JPG.rf.a40debf74b3f5228742cd22b8ea9ce08.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000015_JPG.rf.df7d83766fb301cd8635988698f82196.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000031_jpg.rf.8c396e9a76da42438aed8a9346072d35.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000008_jpg.rf.a24ec77372a4a2d8f9cd694ffec10c9a.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000067_JPG.rf.2758d801c66557b16af99505fcadeca8.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000029_jpg.rf.5784f2b6c1db027a77b6dce92fe4560d.txt (deflated 16%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000061_jpg.rf.c09706e87e6b429d4069e8bddb554c44.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000019_jpg.rf.e4d28c72e4ca25a59b07de7d8cc87080.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000025_jpg.rf.2c5a598559f4ac3e19a1a3bf2a098d4a.txt (deflated 35%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000092_JPG.rf.41d0b245d0c489dfc1914d665a7e5e62.txt (deflated 27%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000053_JPG.rf.8bab99ebbbad46087e65e6c47f7fdaf0.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000000_jpg.rf.ee75fdf06813399a8376c6ff7056423a.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000012_jpg.rf.fb1054104801ab389977b568bde7e0ce.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000097_JPG.rf.f5d6b5572b60dba12a4b39a6af33ac05.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000108_JPG.rf.a2d50edbe09c14b390aeabac181f2e0f.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000069_JPG.rf.754c7034631beace810600af537cf1d3.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000033_JPG.rf.1a792603df082c1ffc695159498aa4eb.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000081_JPG.rf.a35d5c0eaa37af2f138eb0e1e2401329.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000065_jpg.rf.adefa5b0d326eea9e928516289993384.txt (deflated 19%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000033_jpg.rf.b651954382c3ffa0651021309555c8d9.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000015_jpg.rf.8a658891a7ac82f12000145ec489cf4c.txt (deflated 29%)
#   adding: kaggle/working/AquaTrash_yolo/labels/test/000027_jpg.rf.17f02195e9d2f6c52cf2ec29995d1190.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train.cache (deflated 78%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/ (stored 0%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000010_JPG.rf.80b3f35a4216f2c10fe1457f402994bf.txt (deflated 29%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000099_JPG.rf.39fa14946e0ae5cf85c07ed1af0c3d00.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000087_jpg.rf.690ec33d4afb8bd8fe24d397b278fa19.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000056_JPG.rf.dfcd12c23a39c09df1dd428915deb8f6.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000047_JPG.rf.72be7e73ce0d387830038342f92e0d6d.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000060_jpg.rf.9f232ad79a42efbeb938398e8867ad51.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000025_JPG.rf.815dda9504412159afed35e46b5a7bc6.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000037_jpg.rf.faf287f1243cfc2dcab9aca232abe93d.txt (deflated 29%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000035_jpg.rf.8db8187059ccaf7094168b0fb6272c8a.txt (deflated 27%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000026_jpg.rf.cb9edd2738736188ea9a5c1a33f2d085.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000014_JPG.rf.7b43c4e66af30c5b5e9914628b7a92e1.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000049_jpg.rf.0c8e5b44339feb4cc686ebbd443732c3.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000065_JPG.rf.8ffc3e122419146e7016bcefe3df02fc.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000105_JPG.rf.a330a129113c4f5f88b610530a971012.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000084_jpg.rf.f44a770ba1b45b5390f90e977e147578.txt (deflated 25%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000027_jpg.rf.971b8cf615c3c0239d8d8acf9bf5e93b.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000079_JPG.rf.0d7e0fb2df1f2aaa5b5c3966ccf931b1.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000001_jpg.rf.3b10b06a0479e6c9e52202033c95d203.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000056_jpg.rf.59f517d36d5603cf93fab05fe19eaf51.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000037_jpg.rf.8ad39cbfee50a24f9206369a13376025.txt (deflated 42%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000076_jpg.rf.b9b869ca9da200bf355acbf878fd5893.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000084_JPG.rf.92caefae2de3a94bbab6df88bdf33dc8.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000074_JPG.rf.67fca822f9b1926b356922af64e583f4.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000014_jpg.rf.38b062b115e46087392c4a6a42009aa3.txt (deflated 36%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000111_JPG.rf.927d622eef402872a82857c9023d8dc8.txt (deflated 38%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000043_jpg.rf.dcc353439f9822c87e9addf87786a0bd.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000023_JPG.rf.c65a0d2377e99a060d4cfac3b8273594.txt (deflated 28%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000018_JPG.rf.36e111eac7cbfd6aaa50376c786844a0.txt (deflated 28%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000005_JPG.rf.216ea83ee4d2dd49c9633c1367894151.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000087_JPG.rf.468a151affd32005f62c675d8e1bb714.txt (deflated 16%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000013_jpg.rf.29e141f4c018605414d7abd5ec4740e9.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000081_jpg.rf.3324339669b6639069474cead9b2d18a.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000110_JPG.rf.1234fd1e36c337e944e129929f83d0db.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000069_jpg.rf.46d560bf60ef856322d7dfbf2d0fbbbb.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000067_jpg.rf.a9517e2a94617e0eb350cc2dedc84fa7.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000003_jpg.rf.9ca0e5925486fa97540b07414ea9b277.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000062_JPG.rf.d6fb3faeeeebdde7bc81cac72f5f2667.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000035_JPG.rf.0d4d0bd8899beca4e91a1510ceaee1fc.txt (deflated 38%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000045_jpg.rf.a3ae271406456c4ad09b79565c688343.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000059_JPG.rf.924270bb72369c33953e656b40325fbd.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000093_JPG.rf.664f76e5289f311393e8e9388334022d.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000052_JPG.rf.9d27271635175c59e9509c7f70d87801.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000023_jpg.rf.2c7afb3316f1734a18b8d1169b907f85.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000055_jpg.rf.44eeba23c4e8813b50a409ad8fb34ad0.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000028_jpg.rf.dda4470887046c5c09a97fd6b6e6d3f1.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000066_jpg.rf.75f8981fccaeeb5214198ca1b0011e4e.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000085_JPG.rf.3a330c761f605d89e6574aebf45e90a1.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000095_JPG.rf.e753a5b2a9e39abe1223dd53e3e1cc3b.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000018_jpg.rf.0058d47042114f3a156f9232b3a53568.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000051_jpg.rf.92178b1d22661dc4a10ffe6bfd5b4277.txt (deflated 31%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000079_JPG.rf.0f2718510c3e0e2a18fbc4e7d4883d61.txt (deflated 27%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000030_jpg.rf.e1e9870f5ac27db278018cf38e4134d4.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000096_JPG.rf.bb1e71a6719d5b92c64747e681d3193a.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000008_JPG.rf.b7fd07c74e94aeda797b5469cb78809a.txt (deflated 29%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000007_jpg.rf.dd0bfb8e733e43961547eec533fea3b8.txt (deflated 38%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000073_jpg.rf.89b23fe20d196ec2e09be07f273d97f6.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000060_JPG.rf.484b7b820b45a4f99f2657b9e9179be9.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000008_jpg.rf.581796408fb44c037aa30c62dd8400c5.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000052_jpg.rf.a786dd2b6c05e8ffdb102af2b2e11be1.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000016_JPG.rf.9a8b06d326724914d88ff7bf7e59a19b.txt (deflated 28%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000036_JPG.rf.0c1ef2f74ed2d1b89a669bf5ffd06078.txt (deflated 30%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000021_jpg.rf.dedb632cd4867ee95608a988ff38fee7.txt (deflated 38%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000013_jpg.rf.9ba00883de5b5dd801c272cce5818c89.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000070_JPG.rf.ac12be75acbb1f1fca8f1947860d0da1.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000053_jpg.rf.58742b4cc98ffea73836546c05bc1547.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000072_jpg.rf.390f3117daa887331568b07f96fbd893.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000013_jpg.rf.276a38f9b9f8e84d3f72cc9cabba0cfc.txt (deflated 27%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000003_jpg.rf.9977c8a2ac9cb00ea0f60901a4b77333.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000026_jpg.rf.7f0e1403c9665cc1ab664ca6100d6308.txt (deflated 27%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000057_jpg.rf.090b69a8cf99e176436fb111a65e81c9.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000090_JPG.rf.c97c3949f635efcdd64c34a3507e0843.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000034_jpg.rf.a2ab4f9fc73f9a6b8ccdde4129d1c8ea.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000073_JPG.rf.145dc63ae9acd801448a99fe37a03c94.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000078_jpg.rf.f28c5c7961f5d92ad58e2cab69afbb60.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000073_JPG.rf.b7b3da44f9a28163038e7d3429b67b27.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000022_jpg.rf.6c1e872d94a0fb00c1d2b610a5c3184a.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000069_JPG.rf.4769df06d950594f211723a5fb04c972.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000041_JPG.rf.b9c7187161b371d475b9cd1e1e8d1e9a.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000072_JPG.rf.15eda39142f329e131b4f7b7a8524e6c.txt (deflated 27%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000019_jpg.rf.a18fa60b6d2094c68414610227aa951d.txt (deflated 39%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000068_jpg.rf.454129fcb1f7c7d009626ba0adddc8b3.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000064_JPG.rf.a76010b9e4374502cab5dc7a4bf721ab.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000053_jpg.rf.6767a8e4466955cd84a41f391e4aef80.txt (deflated 19%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000043_jpg.rf.89692ae77bf2b39f40254f4998e61121.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000042_jpg.rf.50f2d9c09c3129b84f2ef041e24b38c0.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000002_jpg.rf.ba12a4ce95a3dd81818a5e373efe28be.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000005_jpg.rf.003793a128998b50c820a5951d5a5ba5.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000020_jpg.rf.94c0d1159c8aaa257792cf2c13801ef9.txt (deflated 16%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000045_jpg.rf.455034f3fb1f0f78b617ba0d877dea3c.txt (deflated 27%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000016_jpg.rf.62a0c2e7104b1c47655ff1d0bc5890dd.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000067_jpg.rf.8746caea06137e0d921d481470170ef3.txt (deflated 27%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000030_jpg.rf.cf4fb622e9b578e660bdc9bfd12accc3.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000038_JPG.rf.d949f49ef17f034a45517c7ee5d4ccd5.txt (deflated 19%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000040_jpg.rf.acee0a18ebd6288ce78e384562c3071c.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000024_jpg.rf.090bff7e0ebd097734b99fa1013d587d.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000024_jpg.rf.5ae48b6ddd7f0f7f3ba97f14717cc6c6.txt (deflated 29%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000040_jpg.rf.70a4d78ca394877e9ecd43e10e3ec9ab.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000096_JPG.rf.81524839612961c65378b67c9944af85.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000082_JPG.rf.f4ab7cd5eb7f3f2eaec22644a49b4280.txt (deflated 25%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000035_jpg.rf.1452f2f42d63e062ed907eaa79e8e892.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000121_JPG.rf.cf0d71db1bc87ad39a55c0a70bbbd0a0.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000071_jpg.rf.0f771105c36a967b8532d02db90a47df.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000074_JPG.rf.47a9151525777468c44e8691f29e6789.txt (deflated 27%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000076_jpg.rf.175c02bcb8e9c7b877f0e092de470156.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000092_JPG.rf.f79df099c5856824fcd647d2767596c7.txt (deflated 16%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000052_jpg.rf.25b847f3b003bf3d15c848751ee6c4e3.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000104_JPG.rf.332a5aa47edc75e29cc9a26b80635198.txt (deflated 44%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000095_JPG.rf.6a841ed816f96a34eaaba03356885682.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000093_JPG.rf.80736b0d6e3659f91445ad3fce4c95e4.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000068_JPG.rf.b6d34dfe4b896d0c753385ca4c3072a3.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000082_JPG.rf.00a21c7095239899701f24df09060248.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000016_jpg.rf.73e85f3f95f7bdba3be928f90b7586f5.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000075_JPG.rf.56a161638e45d3d42c88e751bae4ff44.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000038_jpg.rf.f495ce764fef2fedcefdf9da0b96510a.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000025_jpg.rf.96f8a937bf9ac013ea3422706daad7f2.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000034_jpg.rf.82ca4f12eecc7c30bea59f141d42dfb3.txt (deflated 16%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000059_jpg.rf.8a05b618a5d7b50ee78f9014a0f0b85f.txt (deflated 16%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000088_JPG.rf.e947547f0688564d69784cf4b067cc05.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000003_jpg.rf.cf210b41c1d6dfa4e817572b3eae08b6.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000096_jpg.rf.9a4acf1ff6f712d135693810d6776ba6.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000064_JPG.rf.82e6a02e0c40403343b8b5d42eb828be.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000028_jpg.rf.b86deb4fce55807f757fa2b52feba0af.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000044_JPG.rf.62df54827e28b5224339874dad868241.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000023_jpg.rf.1957fc0be7e5963e79f9caa40915198d.txt (deflated 54%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000067_JPG.rf.88f9c6d648c46d0a3195d049c83b8b3d.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000038_jpg.rf.e84ad63ee9a34f619e6bd2b41ef98607.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000012_jpg.rf.5054aa20e9cbd6b10b821db6b300ac0c.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000127_JPG.rf.fd5002b407acccd8ae1e918c23cf7b91.txt (deflated 38%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000077_jpg.rf.7107bcb67410ae43090bc6c4644d2e01.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000007_jpg.rf.c1aa0a792a4edb7de41bcc9a00738a8a.txt (deflated 27%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000093_jpg.rf.8d536f36e117812a1ef369c7b67f0635.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000013_JPG.rf.da886096a055f2b459a99d202eb3fdbf.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000083_jpg.rf.249c5fa4724ca90ecd2ad773286ea1ac.txt (deflated 19%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000040_jpg.rf.4e71645b58f3690e9fb7c065df60327c.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000033_jpg.rf.3c607c41efea726d6b92ffdf6596d6dd.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000059_jpg.rf.e9dd8b4e994229ab3e92710b6cc8e4af.txt (deflated 28%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000029_jpg.rf.f3e792ceb992bc41415a77a69c5b93ee.txt (deflated 16%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000021_JPG.rf.83716ea370ecf4752af77f799e00cff8.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000106_JPG.rf.dc2345e3176c7524cfdbb42983dd3db0.txt (deflated 27%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000011_jpg.rf.5ce2ed4dcf441076fc5244f22aedb9b7.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000037_JPG.rf.93d931816a73f48ddc2f46341f3316c2.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000026_JPG.rf.4e2d2c91e5c4c4797ec026217430960c.txt (deflated 42%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000074_jpg.rf.8aa73efb149a020c7c5397c454598483.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000084_jpg.rf.0b52fe6d752013618857704318aab583.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000032_jpg.rf.7133218ca5f644dad64b6936fb74201f.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000089_JPG.rf.950dfd2b9380d77f7e5e80a9ff068b5d.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000032_jpg.rf.fee88c0ab919cec5db2c78d4cb2d2b3d.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000014_jpg.rf.ea60de2dbaca4cb3980931bc035b65b9.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000070_jpg.rf.b72d2081548c4410e01638f1713062dc.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000082_jpg.rf.6b6f7ad63a90f9d9d860b803e99ec49a.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000048_jpg.rf.de00f8d19645a2ddeb2c60fa6cbee63f.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000101_JPG.rf.a7c1b7e330f8e26da6f5e66603e76bf6.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000006_JPG.rf.9b7b9fcb1ec280c54ddf5eafa9a0ba02.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000017_JPG.rf.da78d08bc1a77af01c0c4c51a71f6f70.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000017_jpg.rf.ba2e5fa6533e4d7816d2a7e294a6d040.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000095_jpg.rf.5a1e9f2f9e387ba2f2c8155b8410656e.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000055_JPG.rf.0ba25c38ed10af00810dda648d2461a0.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000022_JPG.rf.2142a3416365cf34993f4abb1d7d8458.txt (deflated 27%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000062_jpg.rf.acdd0f27e3fcc9d7a86af6b9c7e22d79.txt (deflated 29%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000009_jpg.rf.c6c0c6c8403228f34ac9b2e13fb43904.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000080_JPG.rf.993f9dbfdbb7c771b54270554b538de5.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000010_jpg.rf.69db314ea2d581e398dbbc6b0477b22a.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000005_jpg.rf.64c6c9f622771b349148c96d537e8ff5.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000058_JPG.rf.4ca01dd26d4560668e688cef86d9991b.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000065_jpg.rf.db526887a8a626cbec62106baf05c712.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000129_JPG.rf.eb4bb302dd9580081c49afc5465f58ce.txt (deflated 45%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000088_JPG.rf.0b5b57682430c8c107553f91bf24be8e.txt (deflated 38%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000042_jpg.rf.04f62abf4f94222669321580b8270762.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000068_jpg.rf.f0ac438ac2d888e854e2b6292484f6b7.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000090_jpg.rf.ec22543b6e14ec1cac1f5a0013bb863d.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000062_JPG.rf.6b330fe3640fd645f556b593287bd5b5.txt (deflated 28%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000005_jpg.rf.2e2ec7a6579289fe5714bdb2753880b4.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000115_JPG.rf.427cc9deffec8a9b16bf0afcad140b25.txt (deflated 38%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000010_jpg.rf.6c2f5a56db2ee454cac569cf9b78437a.txt (deflated 16%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000004_jpg.rf.2b05f74aef4b9075fc4850b59e2cb840.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000051_JPG.rf.6539945e2a3c2ed0824526617798b26c.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000009_JPG.rf.ae53b7d399c8fa7b5a4d80c2c59d92ed.txt (deflated 38%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000045_jpg.rf.35d41e4cce69c5e3fdf60eba5fd9f01e.txt (deflated 19%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000028_jpg.rf.da8e70a1ce6cda35988ebe1471b0cd78.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000036_jpg.rf.da61f54af653c78b4df5c3ef1c2606d1.txt (deflated 16%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000008_jpg.rf.aebe91f54e904a647432057275ae9403.txt (deflated 25%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000091_jpg.rf.1c2835b63b19d5c0af7a27129abfbb2f.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000022_jpg.rf.6305b19f11fbdabcba40fa94e8b45bbd.txt (deflated 31%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000001_JPG.rf.ccfdd243a78a6cfa119be0349d18c0ed.txt (deflated 28%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000079_jpg.rf.b2d3b1c6905651b9cf1d939eafd87a52.txt (deflated 16%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000040_JPG.rf.fc1bb55b2d7de403f691406d979da825.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000077_JPG.rf.e9b90c05e5361fe7c9eeb5f3c644a975.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000091_JPG.rf.54bec092812303b6db4922bdb9945a4f.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000098_JPG.rf.11ffd21ae91ef5ba3c82ec792c0f0b60.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000099_jpg.rf.553bd2f567aead09fa6ce582ee1f1fdb.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000031_JPG.rf.5556409546e8d45b63abb898a841cbf0.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000001_jpg.rf.a23b83dbda863601c92725ae9ba3bab7.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000049_JPG.rf.e209e826a07c82e6068790992a260120.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000017_jpg.rf.8f00dc3b244ac3116d76a494bf3d15c1.txt (deflated 22%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000000_jpg.rf.e662cb85f63817325956fea222d0990f.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000080_jpg.rf.bfa237d8070193b4cb690ae88b747d0f.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000070_JPG.rf.002423292827c0192719e23f3ee1d20a.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000075_jpg.rf.70594fffc48d625deb65ece444d3696c.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000083_JPG.rf.9d560f08f9052b58d3e4d55b076c2cca.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000085_jpg.rf.3474819b7c82c49b380fcdf478766207.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000078_JPG.rf.11fe3fdd9daf4c106fd15d42463088c9.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000047_jpg.rf.07bed9ecc70954519a440edb39ffa37f.txt (deflated 28%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000063_JPG.rf.c34b95fa0c610f82e3cada41a46d5f95.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000048_JPG.rf.192e18b148d3faf4514fd896eb5e5326.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000056_jpg.rf.0d4d304fd2f03ba889305fb9ff43394b.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000011_jpg.rf.6559a6761a9fef22596aaea88cde3747.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000030_JPG.rf.c15e0ebc324ac9b1c9789f824124ebb8.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000070_jpg.rf.b047a475b7f68a21260af3a9000acf42.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000072_jpg.rf.94042e6b9b6418ed601c5b245790afcc.txt (deflated 28%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000006_jpg.rf.6748007ba9263baa2c6a7961da13e343.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000032_JPG.rf.2f4a0c2e65acfb0c0bd48599204a16a5.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000094_JPG.rf.a30f2b512b80a5829b54518071bcce59.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000034_JPG.rf.d6ff68db163a8b54ffcd3abf769bfe20.txt (deflated 27%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000039_jpg.rf.35f589fbfaa26392393ed6370dcb7d72.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000063_jpg.rf.d1a3a30f3844145e3301b8899b07fac8.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000120_JPG.rf.520a1f3428c6ebd24d3fdd103082afc0.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000056_jpg.rf.95e52796966f772775c4d95c5c3d62ac.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000004_jpg.rf.bc8c3c9f203da611f150d441db9ac7ae.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000074_jpg.rf.ec9d0227c327aae1a43d1ece31927667.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000049_jpg.rf.272258d1d7994ce7f1064abf6690dc20.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000038_jpg.rf.42a1060772b6e12dea0366652ecf9817.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000107_JPG.rf.8e2873181ee1acfb953a1ef5f3506bda.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000019_JPG.rf.84f4d33da2cd2fcf85f50f1d715a46eb.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000081_jpg.rf.ddc70e72bf7f39fce3a6892c203459f3.txt (deflated 45%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000102_JPG.rf.3c36d45336bb9af4b54cb2ac29766390.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000078_jpg.rf.7bbd087a733dfd7a22418dab6e9d0bce.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000065_JPG.rf.e06e729d4af3f1e6a87e4fa2435cc782.txt (deflated 28%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000043_JPG.rf.97b188ae84207f3ee32e795188a04d0d.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000076_JPG.rf.a0b9ad753a233efb6df431527a468297.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000024_JPG.rf.f8cbab833a31156b0ba7441b9bcee081.txt (deflated 25%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000000_JPG.rf.d3371cb3d63a59c5ba6730368b7905af.txt (deflated 16%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000071_JPG.rf.71712e41ac49488b771991daa54266a9.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000043_jpg.rf.4d513b8ca4c5a243fcfb10ad7d3d3052.txt (deflated 22%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000055_jpg.rf.58e1c338ac4aa308d78ceb9b8e93d7ee.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000050_jpg.rf.2e801127ca66b17e472bca68800afb40.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000018_jpg.rf.5ed8b50a0baee1603b659c848822fa24.txt (deflated 27%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000083_JPG.rf.9d1f623c8bef60b865c9c20abfd54386.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000027_JPG.rf.8063f46827257d27073fc88c205da226.txt (deflated 37%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000057_JPG.rf.149bf40f203756af065d76c89db81c27.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000062_jpg.rf.606ca7944ce7d2b7f87f8ab0d1840baf.txt (deflated 25%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000027_jpg.rf.78100628554443378adcc62660a75524.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000047_jpg.rf.e449cc43414312bd60753116ff1cd5b9.txt (deflated 29%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000076_JPG.rf.a119806e7929c22e2c21ee95d0913e0d.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000054_JPG.rf.76b2370020ef79a2e46989421daa1133.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000029_JPG.rf.fcf8924626cf7b9079801100444609a4.txt (deflated 27%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000031_jpg.rf.361fe414c2979c2ebc9941f147c6ad6a.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000051_jpg.rf.b4ca307c76db86f30e337b25e9fa54cd.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000044_jpg.rf.215bd723ad8d987f75dd33f33fbf2c00.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000086_JPG.rf.2b89cfe42c327e4eea7d99d8c5fa456e.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000094_jpg.rf.ffade2ec7e41ef7d1fe564591764eb43.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000047_jpg.rf.c04a677ec28e0c24aaeec39f894b1fe2.txt (deflated 27%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000050_JPG.rf.db57f41c8e36c19a476b085e91bcf3d7.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000003_JPG.rf.94d22bad4e3f02b1bef15f769561cd9e.txt (deflated 28%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000092_jpg.rf.ffe152373a93f35fe9e4e95baa88cf63.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000015_jpg.rf.f1be72fdd82f24951e7abf8c86b9dbeb.txt (deflated 39%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000098_jpg.rf.293ef58f232e1d7f69675e47277df69f.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000031_jpg.rf.29e96ddf2bdb022113e103b7a75835de.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000117_JPG.rf.792aeeed8617c75c61e6ca1c5a433dae.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000083_jpg.rf.d2118dfada822631307421d62fc27a7d.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000006_jpg.rf.0c45474870c2a5df516344df31448c15.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000081_JPG.rf.ea3619a1163b1494d458dbd578f58523.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000050_jpg.rf.10dfca50c92084c90bd0ec9b2b5fbaed.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000086_JPG.rf.a9c84c634a161dec85f5ca62fff0d0b7.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000122_JPG.rf.257323c30f94a7c71f2db4613eb8bac5.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000088_jpg.rf.9728d1367ea3ab96892d07a6bc662ec3.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000066_jpg.rf.4cd79288b17ea0efdc2d548acfaeb4cb.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000055_jpg.rf.819465c234876c06ce66ea2fc9c9b2d6.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000068_JPG.rf.8ad38475b9ee36d5d972e3f3105dba6e.txt (deflated 37%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000090_JPG.rf.bc3088c0d0847041b9a2274937af9057.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000057_jpg.rf.36c41aa6a8b0706bcdabbc74693ca82b.txt (deflated 19%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000014_jpg.rf.927348ca51d74a05e3c578fcce761d33.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000060_jpg.rf.81ffb8074efac19d9e5262ef20bfb798.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000012_JPG.rf.2c4c735b011d8b107a71fea25fa2e7cd.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000061_JPG.rf.5d8e6c70d07936c222d0513ae3ab920f.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000100_JPG.rf.09ba700d952797e7bcc046066f1758d4.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000020_jpg.rf.b2ba1f0d153f592d072b38bdd755df45.txt (deflated 16%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000059_jpg.rf.acd795453e9adb3e6722da8075e66b05.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000016_jpg.rf.44f83f63a4ab9ab4519ff90f087397c4.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000026_jpg.rf.0c461fdb6595f50eeb6fee3b8532f452.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000118_JPG.rf.7210ba6eef46f0727afbc548098fee07.txt (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000046_JPG.rf.c5f7cb4aba7aaca4f6386737a180f353.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000048_jpg.rf.2381f52a308a97ca3ee02325e2c93824.txt (deflated 43%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000073_jpg.rf.6842cbbd47a4deaa5efba665912652c5.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000023_jpg.rf.5aa9e0a58af86a4baa08d4bfe7513ef9.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000039_jpg.rf.abffb6d1a849a745b7323aa5402ea595.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000099_JPG.rf.c2ef3af6f95642fde1e1f26c70bc8726.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000075_jpg.rf.bd32d52408fa0d543d2c48baacf7404c.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000089_jpg.rf.2260e83c8296b37a3532392442fe36ff.txt (deflated 19%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000007_jpg.rf.aacac0039250183e0db8e195ab9a1e9f.txt (deflated 19%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000044_jpg.rf.b397d82ddd718a92bb3e8adc6d0cbea7.txt (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000071_JPG.rf.2b5d02a4e6c70c644358c781ec3d1faa.txt (deflated 16%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000072_JPG.rf.694e1d668b22358432288e9027607c66.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000042_JPG.rf.3540075c32a95902f389fb56efabf3da.txt (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000032_jpg.rf.8dd019d56117c6c3bfe285d764931d2f.txt (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/labels/train/000036_jpg.rf.6989ea6ca94bc9345c0d3781c5524d8f.txt (deflated 28%)
#   adding: kaggle/working/AquaTrash_yolo/images/ (stored 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/ (stored 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000079_jpg.rf.29fa0266416a159608cf24b4e72c0b6a.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000054_jpg.rf.3fa00c0cefb8d7fac889afd3fbfff716.jpg (deflated 2%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000042_jpg.rf.01523622698a610b1e98c82007f8d91f.jpg (deflated 2%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000064_jpg.rf.a1cc41f6879e58b49881a28cd5ea539c.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000022_jpg.rf.24374a2700679021d5ab94c2ad2434e7.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000069_jpg.rf.cb1b72feff05a77571afa6dcdcccc334.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000001_jpg.rf.42c4ba88119aae9d425f5c004cb2ce0d.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000035_jpg.rf.50f05fa6ede845869668871e91e31f71.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000039_JPG.rf.18085a5d84e17aca7dbc278f39f141a0.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000020_JPG.rf.ebbafb64b09f4937003dcda6b94d27ee.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000006_jpg.rf.33a70c1d2244237b53e6924046000d26.jpg (deflated 2%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000061_jpg.rf.d9ca75b67361d9fcc54b1c8962457f19.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000011_jpg.rf.8b7fff6ea8f7330e402b6a7757b1866b.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000086_jpg.rf.21d6c190ab94e71b2f49fb97de73d378.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000049_jpg.rf.3dc5ad8a124f2516da33d49496ff55dc.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000098_JPG.rf.a5665b7913007535189b824dfb05aedc.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000091_JPG.rf.6ab34e036290bbab1a78573b63cfb996.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000064_jpg.rf.d848c83989a9551ef394ff479572f411.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000082_jpg.rf.aa55332900465a30687548c20145a4e4.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000041_jpg.rf.92043de1d993c43f5aa9b77afd2f1d63.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000124_JPG.rf.11c5626f03313f2a2700d2131bbee98e.jpg (deflated 10%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000061_jpg.rf.e15cc3e3cd9bc8fb042b83bfaae11857.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000084_JPG.rf.942837bfb405ac2730506b6f511f608e.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000004_jpg.rf.a08d4635ed056a7cc41f66fefa9eccc4.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000009_jpg.rf.8434a803f417f51fe5ebe4f6b9697cce.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000066_JPG.rf.4d451656ce9628a9eb263c2b47828227.jpg (deflated 4%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000077_jpg.rf.37455f94e58126e1310cae690bdf8e25.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000010_jpg.rf.d731a0e01f49ec0a95a0f3a1b10ef155.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000017_jpg.rf.1b16bea2730faf919fea7016568d1630.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000054_jpg.rf.24392ce9c7bd1720c838a311c17f958e.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/val/000024_jpg.rf.5545363767994e0edf0a31ceda3dc6e5.jpg (deflated 0%)
# ...
#   adding: kaggle/working/AquaTrash_yolo/images/train/000068_JPG.rf.8ad38475b9ee36d5d972e3f3105dba6e.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000017_jpg.rf.8f00dc3b244ac3116d76a494bf3d15c1.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000065_JPG.rf.e06e729d4af3f1e6a87e4fa2435cc782.jpg (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000037_jpg.rf.faf287f1243cfc2dcab9aca232abe93d.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000030_jpg.rf.cf4fb622e9b578e660bdc9bfd12accc3.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000086_JPG.rf.a9c84c634a161dec85f5ca62fff0d0b7.jpg (deflated 3%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000074_jpg.rf.8aa73efb149a020c7c5397c454598483.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000073_jpg.rf.6842cbbd47a4deaa5efba665912652c5.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000064_JPG.rf.a76010b9e4374502cab5dc7a4bf721ab.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000107_JPG.rf.8e2873181ee1acfb953a1ef5f3506bda.jpg (deflated 3%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000007_jpg.rf.c1aa0a792a4edb7de41bcc9a00738a8a.jpg (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000074_JPG.rf.67fca822f9b1926b356922af64e583f4.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000032_jpg.rf.7133218ca5f644dad64b6936fb74201f.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000094_jpg.rf.ffade2ec7e41ef7d1fe564591764eb43.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000089_jpg.rf.2260e83c8296b37a3532392442fe36ff.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000055_jpg.rf.44eeba23c4e8813b50a409ad8fb34ad0.jpg (deflated 6%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000052_jpg.rf.25b847f3b003bf3d15c848751ee6c4e3.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000129_JPG.rf.eb4bb302dd9580081c49afc5465f58ce.jpg (deflated 3%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000072_jpg.rf.390f3117daa887331568b07f96fbd893.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000093_JPG.rf.664f76e5289f311393e8e9388334022d.jpg (deflated 4%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000052_JPG.rf.9d27271635175c59e9509c7f70d87801.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000060_jpg.rf.81ffb8074efac19d9e5262ef20bfb798.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000118_JPG.rf.7210ba6eef46f0727afbc548098fee07.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000013_jpg.rf.276a38f9b9f8e84d3f72cc9cabba0cfc.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000082_JPG.rf.f4ab7cd5eb7f3f2eaec22644a49b4280.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000030_JPG.rf.c15e0ebc324ac9b1c9789f824124ebb8.jpg (deflated 2%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000058_JPG.rf.4ca01dd26d4560668e688cef86d9991b.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000078_JPG.rf.11fe3fdd9daf4c106fd15d42463088c9.jpg (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000111_JPG.rf.927d622eef402872a82857c9023d8dc8.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000023_JPG.rf.c65a0d2377e99a060d4cfac3b8273594.jpg (deflated 9%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000070_JPG.rf.ac12be75acbb1f1fca8f1947860d0da1.jpg (deflated 2%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000044_jpg.rf.b397d82ddd718a92bb3e8adc6d0cbea7.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000049_JPG.rf.e209e826a07c82e6068790992a260120.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000087_jpg.rf.690ec33d4afb8bd8fe24d397b278fa19.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000048_jpg.rf.de00f8d19645a2ddeb2c60fa6cbee63f.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000006_JPG.rf.9b7b9fcb1ec280c54ddf5eafa9a0ba02.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000043_jpg.rf.4d513b8ca4c5a243fcfb10ad7d3d3052.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000076_JPG.rf.a119806e7929c22e2c21ee95d0913e0d.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000016_jpg.rf.62a0c2e7104b1c47655ff1d0bc5890dd.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000059_jpg.rf.e9dd8b4e994229ab3e92710b6cc8e4af.jpg (deflated 14%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000090_JPG.rf.bc3088c0d0847041b9a2274937af9057.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000009_JPG.rf.ae53b7d399c8fa7b5a4d80c2c59d92ed.jpg (deflated 2%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000042_JPG.rf.3540075c32a95902f389fb56efabf3da.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000088_JPG.rf.0b5b57682430c8c107553f91bf24be8e.jpg (deflated 11%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000000_jpg.rf.e662cb85f63817325956fea222d0990f.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000005_jpg.rf.64c6c9f622771b349148c96d537e8ff5.jpg (deflated 2%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000081_jpg.rf.3324339669b6639069474cead9b2d18a.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000078_jpg.rf.f28c5c7961f5d92ad58e2cab69afbb60.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000038_jpg.rf.e84ad63ee9a34f619e6bd2b41ef98607.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000053_jpg.rf.58742b4cc98ffea73836546c05bc1547.jpg (deflated 3%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000005_jpg.rf.003793a128998b50c820a5951d5a5ba5.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000017_jpg.rf.ba2e5fa6533e4d7816d2a7e294a6d040.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000086_JPG.rf.2b89cfe42c327e4eea7d99d8c5fa456e.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000063_JPG.rf.c34b95fa0c610f82e3cada41a46d5f95.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000028_jpg.rf.da8e70a1ce6cda35988ebe1471b0cd78.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000099_JPG.rf.39fa14946e0ae5cf85c07ed1af0c3d00.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000028_jpg.rf.b86deb4fce55807f757fa2b52feba0af.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000040_jpg.rf.4e71645b58f3690e9fb7c065df60327c.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000022_JPG.rf.2142a3416365cf34993f4abb1d7d8458.jpg (deflated 2%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000076_jpg.rf.b9b869ca9da200bf355acbf878fd5893.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000019_jpg.rf.a18fa60b6d2094c68414610227aa951d.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000072_JPG.rf.694e1d668b22358432288e9027607c66.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000072_JPG.rf.15eda39142f329e131b4f7b7a8524e6c.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000024_jpg.rf.090bff7e0ebd097734b99fa1013d587d.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000025_JPG.rf.815dda9504412159afed35e46b5a7bc6.jpg (deflated 6%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000075_jpg.rf.bd32d52408fa0d543d2c48baacf7404c.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000030_jpg.rf.e1e9870f5ac27db278018cf38e4134d4.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000080_JPG.rf.993f9dbfdbb7c771b54270554b538de5.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000013_JPG.rf.da886096a055f2b459a99d202eb3fdbf.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000056_jpg.rf.95e52796966f772775c4d95c5c3d62ac.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000071_JPG.rf.71712e41ac49488b771991daa54266a9.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000026_jpg.rf.7f0e1403c9665cc1ab664ca6100d6308.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000026_jpg.rf.cb9edd2738736188ea9a5c1a33f2d085.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000006_jpg.rf.0c45474870c2a5df516344df31448c15.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000093_jpg.rf.8d536f36e117812a1ef369c7b67f0635.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000089_JPG.rf.950dfd2b9380d77f7e5e80a9ff068b5d.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000014_jpg.rf.ea60de2dbaca4cb3980931bc035b65b9.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000050_jpg.rf.10dfca50c92084c90bd0ec9b2b5fbaed.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000007_jpg.rf.dd0bfb8e733e43961547eec533fea3b8.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000098_jpg.rf.293ef58f232e1d7f69675e47277df69f.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000043_jpg.rf.89692ae77bf2b39f40254f4998e61121.jpg (deflated 2%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000078_jpg.rf.7bbd087a733dfd7a22418dab6e9d0bce.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000025_jpg.rf.96f8a937bf9ac013ea3422706daad7f2.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000029_JPG.rf.fcf8924626cf7b9079801100444609a4.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000055_JPG.rf.0ba25c38ed10af00810dda648d2461a0.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000046_JPG.rf.c5f7cb4aba7aaca4f6386737a180f353.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000034_jpg.rf.a2ab4f9fc73f9a6b8ccdde4129d1c8ea.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000093_JPG.rf.80736b0d6e3659f91445ad3fce4c95e4.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000014_JPG.rf.7b43c4e66af30c5b5e9914628b7a92e1.jpg (deflated 2%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000017_JPG.rf.da78d08bc1a77af01c0c4c51a71f6f70.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000070_jpg.rf.b72d2081548c4410e01638f1713062dc.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000037_jpg.rf.8ad39cbfee50a24f9206369a13376025.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000013_jpg.rf.9ba00883de5b5dd801c272cce5818c89.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000036_jpg.rf.6989ea6ca94bc9345c0d3781c5524d8f.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000066_jpg.rf.75f8981fccaeeb5214198ca1b0011e4e.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000043_jpg.rf.dcc353439f9822c87e9addf87786a0bd.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000016_jpg.rf.44f83f63a4ab9ab4519ff90f087397c4.jpg (deflated 3%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000075_JPG.rf.56a161638e45d3d42c88e751bae4ff44.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000003_jpg.rf.cf210b41c1d6dfa4e817572b3eae08b6.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000050_JPG.rf.db57f41c8e36c19a476b085e91bcf3d7.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000104_JPG.rf.332a5aa47edc75e29cc9a26b80635198.jpg (deflated 18%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000024_JPG.rf.f8cbab833a31156b0ba7441b9bcee081.jpg (deflated 15%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000048_JPG.rf.192e18b148d3faf4514fd896eb5e5326.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000055_jpg.rf.819465c234876c06ce66ea2fc9c9b2d6.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000038_jpg.rf.f495ce764fef2fedcefdf9da0b96510a.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000010_jpg.rf.69db314ea2d581e398dbbc6b0477b22a.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000065_jpg.rf.db526887a8a626cbec62106baf05c712.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000045_jpg.rf.a3ae271406456c4ad09b79565c688343.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000027_jpg.rf.78100628554443378adcc62660a75524.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000012_JPG.rf.2c4c735b011d8b107a71fea25fa2e7cd.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000100_JPG.rf.09ba700d952797e7bcc046066f1758d4.jpg (deflated 5%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000027_jpg.rf.971b8cf615c3c0239d8d8acf9bf5e93b.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000019_JPG.rf.84f4d33da2cd2fcf85f50f1d715a46eb.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000035_jpg.rf.8db8187059ccaf7094168b0fb6272c8a.jpg (deflated 4%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000083_jpg.rf.d2118dfada822631307421d62fc27a7d.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000060_JPG.rf.484b7b820b45a4f99f2657b9e9179be9.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000061_JPG.rf.5d8e6c70d07936c222d0513ae3ab920f.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000082_JPG.rf.00a21c7095239899701f24df09060248.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000035_jpg.rf.1452f2f42d63e062ed907eaa79e8e892.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000045_jpg.rf.35d41e4cce69c5e3fdf60eba5fd9f01e.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000056_jpg.rf.0d4d304fd2f03ba889305fb9ff43394b.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000084_jpg.rf.0b52fe6d752013618857704318aab583.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000076_JPG.rf.a0b9ad753a233efb6df431527a468297.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000042_jpg.rf.50f2d9c09c3129b84f2ef041e24b38c0.jpg (deflated 2%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000001_jpg.rf.3b10b06a0479e6c9e52202033c95d203.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000005_jpg.rf.2e2ec7a6579289fe5714bdb2753880b4.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000090_jpg.rf.ec22543b6e14ec1cac1f5a0013bb863d.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000068_JPG.rf.b6d34dfe4b896d0c753385ca4c3072a3.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000069_JPG.rf.4769df06d950594f211723a5fb04c972.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000033_jpg.rf.3c607c41efea726d6b92ffdf6596d6dd.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000052_jpg.rf.a786dd2b6c05e8ffdb102af2b2e11be1.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000011_jpg.rf.6559a6761a9fef22596aaea88cde3747.jpg (deflated 1%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000106_JPG.rf.dc2345e3176c7524cfdbb42983dd3db0.jpg (deflated 8%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000073_JPG.rf.b7b3da44f9a28163038e7d3429b67b27.jpg (deflated 0%)
#   adding: kaggle/working/AquaTrash_yolo/images/train/000092_jpg.rf.ffe152373a93f35fe9e4e95baa88cf63.jpg (deflated 0%)
# Zip created at /content/20250610_AquaTrash_yolo.zip

# %%
# Rerun the training cell with the corrected data.yaml path
# ⚠️ DO NOT MODIFY THIS CELL
# This cell trains a YOLO model on the converted YOLO dataset to see if it's set up correctly
# Tip: inspect the output of this cell to assess whether training occured properly.

from ultralytics import YOLO # Moved import here

model = YOLO('yolo11n.pt')
# Use the output_root directly as the data path
results = model.train(data=str(output_root / 'data.yaml'), epochs=4, imgsz=640)  # epoch size is small - this is just to see if it can work!
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 343MB/s]
# Ultralytics 8.3.152 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/aquatrash_yolo/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=4, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431452  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,620 parameters, 2,590,604 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.1±0.1 ms, read: 676.5±338.7 MB/s, size: 23.7 KB)
# train: Scanning /kaggle/working/aquatrash_yolo/labels/train.cache... 295 images, 0 backgrounds, 0 corrupt: 100%|██████████| 295/295 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 358.2±161.8 MB/s, size: 154.9 KB)
# val: Scanning /kaggle/working/aquatrash_yolo/labels/val.cache... 74 images, 0 backgrounds, 0 corrupt: 100%|██████████| 74/74 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 4 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/4       2.4G      1.822      4.109      1.719         20        640: 100%|██████████| 19/19 [00:09<00:00,  2.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  2.31it/s]
#                    all         74         91     0.0138      0.787      0.101     0.0463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/4      2.79G      1.763      3.708      1.639         16        640: 100%|██████████| 19/19 [00:08<00:00,  2.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  2.58it/s]
#                    all         74         91    0.00716      0.913      0.105     0.0444
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/4       2.8G      1.743      3.432      1.617         13        640: 100%|██████████| 19/19 [00:09<00:00,  2.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  2.47it/s]
#                    all         74         91    0.00675      0.822       0.17     0.0814
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/4       2.8G      1.703      3.226      1.602         17        640: 100%|██████████| 19/19 [00:08<00:00,  2.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  2.64it/s]
#                    all         74         91    0.00549      0.891      0.229      0.112
#
# 4 epochs completed in 0.013 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 5.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 5.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.152 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  2.10it/s]
#                    all         74         91     0.0055      0.891      0.231      0.113
#                  glass          8          8   0.000863          1     0.0892     0.0408
#                  metal         16         21     0.0046      0.762      0.168     0.0685
#                  paper         23         24    0.00327      0.958      0.422      0.223
#                plastic         34         38     0.0133      0.842      0.246      0.121
# Speed: 0.3ms preprocess, 3.4ms inference, 0.0ms loss, 4.8ms postprocess per image
# Results saved to runs/detect/train

# %%
# Not required
import json
import shutil
import random
from pathlib import Path
from sklearn.model_selection import train_test_split
import yaml
from PIL import Image # Import Image from PIL

def convert_bbox_to_yolo(bbox, img_w, img_h):
    """
    Converts COCO bbox format [x_min, y_min, width, height] to YOLO format
    [x_center, y_center, width, height] normalized by image dimensions.

    Args:
        bbox (list): Bounding box in COCO format [x_min, y_min, width, height].
        img_w (int): Image width.
        img_h (int): Image height.

    Returns:
        tuple: Bounding box in YOLO format [x_center, y_center, width, height] normalized,
               or None if image dimensions are invalid.
    """
    # Add check for valid image dimensions to avoid division by zero
    if img_w <= 0 or img_h <= 0:
        print(f"Warning: Invalid image dimensions ({img_w}x{img_h}). Cannot convert bbox.")
        return None # Indicate failure to convert

    # Input bbox is [x_min, y_min, width, height]
    x_min, y_min, width, height = bbox

    # Calculate YOLO format: [x_center, y_center, width, height] (normalized)
    x_center = (x_min + width / 2) / img_w
    y_center = (y_min + height / 2) / img_h
    width = width / img_w
    height = height / img_h

    # Ensure values are within [0, 1] and handle potential floating point issues near boundaries
    x_center = max(0.0, min(1.0, x_center))
    y_center = max(0.0, min(1.0, y_center))
    width = max(0.0, min(1.0, width))
    height = max(0.0, min(1.0, height))

    # Add validation for calculated bbox values (optional, but good practice)
    if width < 0 or width > 1 or height < 0 or height > 1 or x_center < 0 or x_center > 1 or y_center < 0 or y_center > 1:
         print(f"Warning: Calculated YOLO bbox coordinates are outside [0, 1]. Original bbox: {bbox}, Image WxH: {img_w}x{img_h}, YOLO coords: {x_center, y_center, width, height}")
         # Depending on strictness, you might return None here or try to clamp values

    return x_center, y_center, width, height


def convert_coco_to_yolo(coco_root: Path, dataset_name: str, train_split: float = 0.8):
    """
    Converts a simple COCO-formatted dataset to YOLO format, splitting into
    train, validation, and test sets.

    Assumes the COCO data is structured as:
    coco_root/
        images/
            image1.jpg
            image2.jpg
            ...
        annotations.json

    The annotations.json should be a simple COCO format with 'images', 'annotations',
    and 'categories' keys. The 'bbox' in annotations should be [x_min, y_min, width, height].

    Args:
        coco_root (Path): Path to the root directory of the simple COCO dataset.
        dataset_name (str): Name for the output YOLO dataset directory.
        train_split (float): The proportion of the dataset to use for training (0.0 to 1.0).
                             The remaining data will be split equally between validation and test.

    Returns:
        Path: The path to the generated data.yaml file in the YOLO dataset directory.
    """

    images_dir = coco_root / 'images'
    annotations_path = coco_root / 'annotations.json'

    if not images_dir.is_dir():
        print(f"Error: Image directory not found at {images_dir}")
        return None
    if not annotations_path.is_file():
        print(f"Error: annotations.json not found at {annotations_path}")
        return None

    # Define output YOLO directory structure
    output_root = Path(f'/kaggle/working/{dataset_name}_yolo')
    images_train = output_root / 'images' / 'train'
    images_val = output_root / 'images' / 'val'
    images_test = output_root / 'images' / 'test'
    labels_train = output_root / 'labels' / 'train'
    labels_val = output_root / 'labels' / 'val'
    labels_test = output_root / 'labels' / 'test'

    # Clear and recreate folders
    for d in [images_train, images_val, images_test, labels_train, labels_val, labels_test]:
        if d.exists():
            shutil.rmtree(d)
        d.mkdir(parents=True, exist_ok=True)

    # Load COCO annotations
    with open(annotations_path, 'r') as f:
        coco_data = json.load(f)

    images_info = coco_data['images']
    annotations_info = coco_data['annotations']
    categories_info = coco_data['categories']

    # Create mappings for quick lookup
    image_id_to_info = {img['id']: img for img in images_info}
    annotations_by_image_id = defaultdict(list)
    for ann in annotations_info:
        annotations_by_image_id[ann['image_id']].append(ann)

    # Map category_id to the new single class ID (0 for 'trash')
    # We still need the original category_id to filter annotations if needed,
    # but for the YOLO labels, we'll always use the new single class ID.
    # category_id_to_name = {cat['id']: cat['name'] for cat in categories_info}
    # category_names = [cat['name'] for cat in categories_info] # For data.yaml

    # Get a list of all image IDs
    all_image_ids = list(image_id_to_info.keys())

    # Split image IDs into train, validation, and test sets
    # Split into train and the rest (val + test)
    train_ids, rest_ids = train_test_split(all_image_ids, train_size=train_split, random_state=42)
    # Split the rest into validation and test (50/50 of the remaining)
    val_ids, test_ids = train_test_split(rest_ids, test_size=0.5, random_state=42)

    print(f"Dataset split: Train={len(train_ids)} images, Validation={len(val_ids)} images, Test={len(test_ids)} images")


    # Function to process a single split
    def process_split(image_ids, target_image_folder, target_label_folder):
        print(f"Processing split for {target_image_folder.parent.name}/{target_image_folder.name}...")
        files_processed_count = 0
        labels_written_count = 0

        for img_id in image_ids:
            img_info = image_id_to_info.get(img_id)
            if not img_info:
                print(f"Warning: Image ID {img_id} not found in images_info. Skipping.")
                continue

            original_file_name = img_info['file_name']
            img_w, img_h = img_info['width'], img_info['height']

            source_image_path = images_dir / original_file_name
            target_image_path = target_image_folder / original_file_name

            # Copy image
            if source_image_path.exists():
                shutil.copy(source_image_path, target_image_path)
            else:
                print(f"Warning: Source image not found, cannot copy: {source_image_path}")
                continue # Skip if image doesn't exist

            # Prepare label data
            yolo_data_for_file = []
            current_image_annotations = annotations_by_image_id.get(img_id, [])

            for ann in current_image_annotations:
                # We don't need the original category_id for the YOLO label file,
                # as we are collapsing all categories into 'trash' (class ID 0).
                # category_id = ann['category_id']
                bbox_coco = ann['bbox'] # [x_min, y_min, width, height]

                # Convert COCO bbox to YOLO format
                yolo_bbox_coords = convert_bbox_to_yolo(bbox_coco, img_w, img_h)

                if yolo_bbox_coords:
                    # Always use class ID 0 for 'trash'
                    class_id = 0
                    # yolo_bbox_coords is (x_center, y_center, width, height)
                    yolo_data_for_file.append(f"{class_id} {yolo_bbox_coords[0]:.6f} {yolo_bbox_coords[1]:.6f} {yolo_bbox_coords[2]:.6f} {yolo_bbox_coords[3]:.6f}")

            # Write label file if there's any valid annotation data
            # Use the original_file_name's stem for the .txt file
            label_file_name = Path(original_file_name).stem + '.txt'
            label_file_path = target_label_folder / label_file_name

            # Only create label file if there are annotations
            if yolo_data_for_file:
                 with open(label_file_path, 'w') as f:
                    f.write('\n'.join(yolo_data_for_file))
                 labels_written_count += 1
            # else:
                # If no annotations for this image and you still want an empty label file:
                # Path(label_file_path).touch() # Create an empty file

            files_processed_count += 1
            if files_processed_count % 100 == 0: # Print progress every 100 files
                print(f"  Processed {files_processed_count}/{len(image_ids)} images for {target_image_folder.name}...")


        print(f"Finished processing for {target_image_folder.name}. Copied {files_processed_count} images. Wrote {labels_written_count} label files.")


    # Process each split
    if train_ids:
        process_split(train_ids, images_train, labels_train)
    else:
        print("No training data to process.")

    if val_ids:
        process_split(val_ids, images_val, labels_val)
    else:
        print("No validation data to process.")

    if test_ids:
         process_split(test_ids, images_test, labels_test)
    else:
        print("No test data to process.")


    # Create data.yaml file with a single 'trash' category
    data_yaml = {
        'path': str(output_root), # Path to the dataset root
        'train': 'images/train', # Path to training images relative to 'path'
        'val': 'images/val',     # Path to validation images relative to 'path'
        'test': 'images/test',   # Path to test images relative to 'path'
        'nc': 1,                 # Number of classes (only one: trash)
        'names': ['trash']       # List of class names
    }

    data_yaml_path = output_root / 'data.yaml'
    with open(data_yaml_path, 'w') as f:
        yaml.dump(data_yaml, f, default_flow_style=False)

    print(f"\nGenerated data.yaml at {data_yaml_path}")

    return data_yaml_path # Return the path to the data.yaml file

# %% [markdown]
# Helper function for zipping and downloading a folder

# %%
# Example usage (you can modify this to zip a specific folder like your YOLO dataset)
# Replace '/kaggle/working/AquaTrash_yolo' with the actual path to the folder you want to zip
# zip_and_download_folder('/kaggle/working/AquaTrash_yolo', 'my_yolo_dataset_archive.zip')
zip_and_download_folder('/content/runs/detect')
# Out:
# Creating zip archive: detect.zip from /content/runs/detect...
# Zip archive created successfully.
# Downloading detect.zip...
# Download triggered.
