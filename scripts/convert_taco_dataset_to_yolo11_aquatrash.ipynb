# %% [markdown]
# The purpose of this notebook is to convert a dataset to a format that can be used to train a YOLOv8 model.
#
# To use, make a copy of this notebook, and adapt it to work with your specific dataset. Please save your version of this ipynb file on GitHub in *recyclo/scripts*.
#
# (File > Save a copy in GitHub > File path = "scripts/my_filename.ipynb" to save notebook in scripts folder)
#
# Once you've generated your YOLOv8 dataset, and are confident you can train a model with it, please upload your converted dataset to the Recyclo datasets google drive, https://drive.google.com/drive/folders/1bUkIYQRXX08OKI5TuOSg-eqntSudGaFB.
#
# (Why Google Drive? Because these datasets are too large for GitHub!)

# %%
# !pip install -U ultralytics

from ultralytics import YOLO
import os
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.147-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.147-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 15.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 69.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 58.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 34.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 42.9 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.147 ultralytics-thop-2.0.14
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# # Convert datasets for YOLOv8
#
# ### General
#
# In general, YOLO models output the following for a given image:
# * Bounding box
# * Class label
# * Confidence score
#
# To train a YOLO model, we need object detection datasets that contain images of what we're looking for (trash), and annotations: class labels and bounding boxes.
#
# ### YOLOv8
#
# In this project we will use Ultralytics YOLOv8 object detection.
#
# YOLOv8 expects datasets in the following format:
#
# ```
# dataset/
# ├── images/
# │   ├── train/  <-- image files for training
# │   └── val/    <-- image files for validation after each epoch. Must not overlap with images in train.
# ├── labels/
# │   ├── train/  <-- one .txt file per train image. Contains class and bbox info..
# │   └── val/    <-- one .txt file per val image
# └── data.yaml   <-- config file,
# ```
#
# Example labels/train file:
# ```
# <class_id> <x_center> <y_center> <width> <height>
# ```
#
# Example data.yaml file:
# ```
# path: /content/dataset  # Root folder
# train: images/train
# val: images/val
#
# nc: 5  # number of classes
# names: ['bottle', 'can', 'plastic bag', 'wrapper', 'paper']
#
# ```
#
# ### Colabs
#
# When you open the "Files" tab on the left, you'll find yourself in a folder containing
# * ..
# * sample data
#
# This is a colab thing, the "content" folder, to get you started.
# Ignore it: click the .. to go up a level.

# %% [markdown]
# ---
# ⚠️ ***CHANGE THIS FILE FROM HERE DOWN TO SUIT YOUR DATASET*** ⚠️
#
# The sections above apply for all dataset conversions.
#
# ---

# %% [markdown]
# ### TACO dataset
#
# #### Overview
#
# The TACO dataset uses COCO-style formatting (segmentation).
#
# Sidebar: COCO, Common Objects in Context, is a object detection, segmentation, and captioning dataset developed by Microsoft. It uses an annotations.json file to organize image data. This json annotation approach has become standard for other datasets to use.
#
# So, TACO has an annotations.json file containing:
# *   "images":  List of image metadata
# *   "annotations":  List of label data (type of trash, bounding box definition, segmentation data; corresponds to images list)
# *   "categories":  List of the different categories this dataset uses
#
# #### Conversion
# To convert the TACO dataset to a format YOLOv8 can use, we must:
# * Split the TACO images into train and val sets
# * Extract label and bbox info from annotations.json, and save it in individual txt files corresponding to the image files
# * Make a data.yaml file

# %% [markdown]
# To verify that your conversion worked, make sure you can train a model and that it outputs images with a bounding box and label.

# %%
import json
import shutil
import random
from pathlib import Path
from sklearn.model_selection import train_test_split
import yaml
import pandas as pd # Import pandas

# === IMPORT DATASET ===

# Define the target directory for the dataset
dataset_target_path = Path('/kaggle/working/AquaTrash_dataset')
# Check if the dataset directory already exists
if not dataset_target_path.exists():
    print(f"Cloning AquaTrash dataset to {dataset_target_path}...")
    # !git clone https://github.com/Harsh9524/AquaTrash.git /kaggle/working/AquaTrash_dataset
    print(f"Dataset downloaded to {dataset_target_path}\n")
else:
    print(f"Dataset directory {dataset_target_path} already exists. Skipping clone.\n")
# print(f"Dataset downloaded to {input_root}\n")

# === CONFIG ===
input_root = Path('/kaggle/working/AquaTrash_dataset') # Update to the directory where AquaTrash was cloned
output_root = Path('/kaggle/working/aquatrash_yolo') # You can change the output directory name
train_ratio = 0.8  # 80% training, 20% validation

# === OUTPUT STRUCTURE ===
images_train = output_root / 'images' / 'train'
images_val = output_root / 'images' / 'val'
labels_train = output_root / 'labels' / 'train'
labels_val = output_root / 'labels' / 'val'

# Create folders
for folder in [images_train, images_val, labels_train, labels_val]:
    folder.mkdir(parents=True, exist_ok=True)

# === LOAD ANNOTATIONS ===
# Assuming annotations.csv contains columns: 'image_name', 'x_min', 'y_min', 'x_max', 'y_max', 'class_name'

# Initialize variables before the try block
annotations_df = None
image_names_list = [] # Use image names as identifiers
image_name_to_info = {} # Map image name to its info
annotations_by_image = {} # Group annotations by image name
category_info_list = [] # List of unique categories
category_map = {} # Map category name to class ID
category_names = [] # List of category names for data.yaml

# # Define the suffix to remove if it exists in the image_name
# # Based on the previous warning, this seems to be the format
# SUFFIX_TO_REMOVE = '_jpg.rf.beffaf3b548106ccf1da5dc629bc9504.jpg' # Adjust if the suffix is different
# # Also define the correct directory for images within the input_root
IMAGE_SOURCE_DIR = 'Images'

try:
    # Attempt to read the CSV file
    # Add dtype specification for bounding box columns to ensure they are numbers
    annotations_df = pd.read_csv(
        input_root / 'annotations.csv',
        dtype={'x_min': float, 'y_min': float, 'x_max': float, 'y_max': float}
    )

    # We need image dimensions (width and height) which are not in our CSV.
    # You will need to get these from the image files themselves.
    # Let's create a helper function to get image size.
    # This requires Pillow (PIL) library.
    try:
        from PIL import Image
    except ImportError:
        print("Pillow library not found. Installing...")
        # !pip install Pillow
        from PIL import Image # Import again after installation

    def get_image_size(image_path):
        try:
            with Image.open(image_path) as img:
                return img.size # Returns (width, height)
        except FileNotFoundError:
            print(f"Warning: Image file not found when trying to get size: {image_path}") # Keep this warning if you want to know which files are missing
            return None # Indicate failure
        except Exception as e:
            print(f"Error getting size of image {image_path}: {e}")
            return None


    # Create 'images' information from unique image entries in the DataFrame
    unique_image_names_in_csv = annotations_df['image_name'].drop_duplicates().tolist()
    image_name_to_info = {}
    for image_name_in_csv in unique_image_names_in_csv:
        # Clean the image name from the CSV if the suffix is present
        # Assume the original file name is the part before the suffix
        original_image_name = image_name_in_csv
        # Check if the suffix exists and remove it. Also ensure it ends with .jpg or similar image extension
        # if original_image_name.endswith(SUFFIX_TO_REMOVE):
        #     original_image_name = original_image_name[:-len(SUFFIX_TO_REMOVE)] + '.jpg' # Assume original is .jpg
        # # You might need additional logic here if file extensions vary or if there are other suffix patterns

        # Construct the full image path using the potentially cleaned name and the correct image directory
        img_path_full = input_root / IMAGE_SOURCE_DIR / original_image_name # <--- Changed path here

        size = get_image_size(img_path_full)
        if size:
            width, height = size
            # Store the original image_name from the CSV in the info dictionary
            # This helps link back to the annotations DataFrame rows
            image_name_to_info[image_name_in_csv] = {
                'file_name': original_image_name, # Store the actual file name on disk
                'width': width,
                'height': height
            }
        else:
            # If size couldn't be obtained (file not found etc.), print a warning and skip this image
            print(f"Warning: Skipping image {image_name_in_csv} due to missing file or error getting size.")
            print(f"Attempted path: {img_path_full}")


    # Group annotations by image name (using the original image_name from CSV as the key)
    annotations_by_image = {}
    for index, row in annotations_df.iterrows():
        image_name = row['image_name']

        # Skip if image info wasn't loaded (due to missing file/size error)
        if image_name not in image_name_to_info:
            continue

        # Get bbox directly from columns
        bbox = [row['x_min'], row['y_min'], row['x_max'], row['y_max']]

        annotation = {
            'image_name': image_name, # Keep original image name from CSV
            'class_name': row['class_name'], # Use class_name directly
            'bbox': bbox # Store as [x_min, y_min, x_max, y_max]
        }
        annotations_by_image.setdefault(image_name, []).append(annotation)

    # Create 'categories' information
    unique_class_names = annotations_df['class_name'].drop_duplicates().tolist()
    # Sort category names alphabetically to ensure consistent class IDs
    unique_class_names.sort()

    category_info_list = []
    for idx, class_name in enumerate(unique_class_names):
        category_info_list.append({
            'id': idx, # Assign integer ID based on sorted order
            'name': class_name
        })

    category_map = {cat['name']: cat['id'] for cat in category_info_list} # Map name to ID
    category_names = [cat['name'] for cat in category_info_list] # List of names for data.yaml


except pd.errors.EmptyDataError:
    print(f"Error: The file {input_root / 'annotations.csv'} is empty.")
    # Do not exit, allow script to continue with empty data
except FileNotFoundError:
    print(f"Error: The file {input_root / 'annotations.csv'} was not found.")
    # Do not exit, allow script to continue with empty data
except KeyError as e:
    print(f"Error: Missing expected column in annotations.csv: {e}. Please check your column names ('image_name', 'x_min', 'y_min', 'x_max', 'y_max', 'class_name').")
    # Do not exit, allow script to continue with empty data
except Exception as e:
    print(f"An unexpected error occurred while processing the CSV file: {e}")
    # Do not exit, allow script to continue with empty data

# === SPLIT DATA ===
# Check if image_name_to_info was successfully populated
if not image_name_to_info:
    print("No image data loaded from annotations.csv or image files. Skipping data splitting and processing.")
    train_names = []
    val_names = []
else:
    # Split using the original image names from the CSV which are keys in image_name_to_info
    all_image_names = list(image_name_to_info.keys())
    # Only split if there are images
    if all_image_names:
        train_names, val_names = train_test_split(all_image_names, train_size=train_ratio, random_state=42)
    else:
        print("No valid images found after processing annotations.csv. Skipping data splitting and processing.")
        train_names = []
        val_names = []

# === PROCESS AND WRITE LABELS AND COPY IMAGES ===

def convert_bbox_to_yolo(bbox, img_w, img_h):
    # Add check for valid image dimensions to avoid division by zero
    if img_w <= 0 or img_h <= 0:
        print(f"Warning: Invalid image dimensions ({img_w}x{img_h}). Cannot convert bbox.")
        return None # Indicate failure to convert

    # Input bbox is [x_min, y_min, x_max, y_max]
    x_min, y_min, x_max, y_max = bbox

    # Calculate YOLO format: [x_center, y_center, width, height] (normalized)
    x_center = ((x_min + x_max) / 2) / img_w
    y_center = ((y_min + y_max) / 2) / img_h
    width = (x_max - x_min) / img_w
    height = (y_max - y_min) / img_h

    # Ensure values are within [0, 1] and handle potential floating point issues near boundaries
    x_center = max(0.0, min(1.0, x_center))
    y_center = max(0.0, min(1.0, y_center))
    width = max(0.0, min(1.0, width))
    height = max(0.0, min(1.0, height))


    # Add validation for calculated bbox values
    if width <= 1e-6 or height <= 1e-6: # Using a small epsilon for float comparison
        print(f"Warning: Calculated YOLO bbox has zero or near-zero width ({width}) or height ({height}). Original bbox: {bbox}, Image WxH: {img_w}x{img_h}")
        # Optionally, you could return None here if zero-size boxes are invalid
        # return None

    return x_center, y_center, width, height

def process_dataset_split(image_names_split, target_image_folder, target_label_folder):
    """
    Copies images to the target folder and creates YOLO label files.
    image_names_split: List of image names (from CSV) for this split (train/val).
    target_image_folder: Path to the folder where images for this split will be copied.
    target_label_folder: Path to the folder where .txt label files will be saved.
    """
    print(f"Processing split for {target_image_folder.parent.name}/{target_image_folder.name}...")
    files_processed_count = 0
    labels_written_count = 0

    for image_name_from_csv in image_names_split:
        if image_name_from_csv not in image_name_to_info:
            print(f"Warning: Skipping {image_name_from_csv}, not found in image_name_to_info (likely skipped during annotation loading).")
            continue

        img_info = image_name_to_info[image_name_from_csv]
        original_file_name = img_info['file_name'] # Actual file name on disk
        img_w, img_h = img_info['width'], img_info['height']

        source_image_path = input_root / IMAGE_SOURCE_DIR / original_file_name
        target_image_path = target_image_folder / original_file_name

        # Copy image
        if source_image_path.exists():
            shutil.copy(source_image_path, target_image_path)
        else:
            print(f"Warning: Source image not found, cannot copy: {source_image_path}")
            continue # Skip if image doesn't exist

        # Prepare label data
        yolo_data_for_file = []
        current_image_annotations = annotations_by_image.get(image_name_from_csv, [])

        if not current_image_annotations:
            pass


        for ann in current_image_annotations:
            class_name = ann['class_name']
            bbox = ann['bbox'] # [x_min, y_min, x_max, y_max]

            if class_name not in category_map:
                print(f"Warning: Class name '{class_name}' for image {image_name_from_csv} not in category_map. Skipping this annotation.")
                continue

            class_id = category_map[class_name]
            yolo_bbox_coords = convert_bbox_to_yolo(bbox, img_w, img_h)

            if yolo_bbox_coords:
                # yolo_bbox_coords is (x_center, y_center, width, height)
                yolo_data_for_file.append(f"{class_id} {yolo_bbox_coords[0]:.6f} {yolo_bbox_coords[1]:.6f} {yolo_bbox_coords[2]:.6f} {yolo_bbox_coords[3]:.6f}")

        # Write label file if there's any valid annotation data
        if yolo_data_for_file:
            # Use the original_file_name's stem for the .txt file
            label_file_name = Path(original_file_name).stem + '.txt'
            label_file_path = target_label_folder / label_file_name
            with open(label_file_path, 'w') as f:
                f.write('\n'.join(yolo_data_for_file))
            labels_written_count +=1

        files_processed_count += 1
        if files_processed_count % 100 == 0: # Print progress every 100 files
            print(f"  Processed {files_processed_count}/{len(image_names_split)} images for {target_image_folder.name}...")

    print(f"Finished processing for {target_image_folder.name}. Copied {files_processed_count} images. Wrote {labels_written_count} label files.")


# Process training data
if train_names:
    print("\nProcessing training data...")
    process_dataset_split(train_names, images_train, labels_train)
else:
    print("\nNo training data to process.")

# Process validation data
if val_names:
    print("\nProcessing validation data...")
    process_dataset_split(val_names, images_val, labels_val)
else:
    print("\nNo validation data to process.")

print("\nFinished copying images and writing label files.\n")
# Out:
# Dataset directory /kaggle/working/AquaTrash_dataset already exists. Skipping clone.
#
#
# Processing training data...
# Processing split for images/train...
#   Processed 100/295 images for train...
#   Processed 200/295 images for train...
# Finished processing for train. Copied 295 images. Wrote 295 label files.
#
# Processing validation data...
# Processing split for images/val...
# Finished processing for val. Copied 74 images. Wrote 74 label files.
#
# Finished copying images and writing label files.

# %%
data_yaml_content = {
    'train': str(images_train.resolve()),  # Absolute path to training images
    'val': str(images_val.resolve()),    # Absolute path to validation images
    'nc': len(category_names),             # Number of classes
    'names': category_names                # List of class names
}

yaml_path = output_root / 'data.yaml'
try:
    with open(yaml_path, 'w') as f:
        yaml.dump(data_yaml_content, f, default_flow_style=False, sort_keys=False)
    print(f"Successfully created {yaml_path}")
    print("Content of data.yaml:")
    # Print content for verification
    with open(yaml_path, 'r') as f:
        print(f.read())
    if not category_names:
        print("Warning: 'category_names' is empty in data.yaml. 'nc' is 0. YOLO training will likely fail due to no classes defined.")
except Exception as e:
    print(f"Error creating or writing to {yaml_path}: {e}")

model = YOLO("yolo11n.pt")

# --- Verification for model initialization ---
if model is not None:
    print(f"Model initialized successfully. Type: {type(model)}")
    try:
        model.info() # This usually prints model summary if loaded correctly
    except Exception as e:
        print(f"Could not get model.info(): {e}")
else:
    print("Error: Model initialization failed, 'model' is None.")
    # Consider exiting or raising an error if model initialization is critical
# --- End verification ---

results = model.train(data=output_root / 'data.yaml', epochs=5, imgsz=640)

# --- Verification for model training ---
if results is not None:
    print("Training process completed. Results object obtained.")
    if hasattr(results, 'metrics') and results.metrics:
        print(f"Training metrics available: {results.metrics.keys()}")
        # Example: print mAP50-95 if available
        if hasattr(results, 'maps') and results.maps is not None: # maps is a list of mAP per epoch
             print(f"mAP50-95 for last epoch: {results.maps[-1] if results.maps else 'N/A'}")
    else:
        print("Warning: Training results metrics not found or empty in the results object.")

    # Check if the trainer object and save directory are available
    if hasattr(model, 'trainer') and model.trainer is not None:
        print(f"Trainer object is available. Save directory: {model.trainer.save_dir}")
        if hasattr(model.trainer, 'best') and model.trainer.best:
            print(f"Path to best weights: {model.trainer.best}")
        else:
            print("Warning: model.trainer.best path not found.")
    else:
        print("Error: model.trainer is None after training. Training likely failed to initialize or complete properly.")

else:
    print("Error: Training process did not return a results object. 'results' is None.")
# --- End verification ---
# Out:
# Successfully created /kaggle/working/aquatrash_yolo/data.yaml
# Content of data.yaml:
# train: /kaggle/working/aquatrash_yolo/images/train
# val: /kaggle/working/aquatrash_yolo/images/val
# nc: 4
# names:
# - glass
# - metal
# - paper
# - plastic
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 77.2MB/s]
# Model initialized successfully. Type: <class 'ultralytics.models.yolo.model.YOLO'>
# YOLOv8n summary: 129 layers, 3,157,200 parameters, 0 gradients, 8.9 GFLOPs
# Ultralytics 8.3.147 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/aquatrash_yolo/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=5, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 14.2MB/s]
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752092  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# Model summary: 129 layers, 3,011,628 parameters, 3,011,612 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 61.1MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 749.4±298.5 MB/s, size: 23.7 KB)
# train: Scanning /kaggle/working/aquatrash_yolo/labels/train... 295 images, 0 backgrounds, 0 corrupt: 100%|██████████| 295/295 [00:00<00:00, 2621.47it/s]
# train: New cache created: /kaggle/working/aquatrash_yolo/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 577.8±137.2 MB/s, size: 154.9 KB)
# val: Scanning /kaggle/working/aquatrash_yolo/labels/val... 74 images, 0 backgrounds, 0 corrupt: 100%|██████████| 74/74 [00:00<00:00, 1872.63it/s]
# val: New cache created: /kaggle/working/aquatrash_yolo/labels/val.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/5       2.1G      1.821      4.047      1.675         20        640: 100%|██████████| 19/19 [00:10<00:00,  1.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:03<00:00,  1.12s/it]
#                    all         74         91     0.0024      0.441     0.0763     0.0438
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/5      2.57G      1.767       3.42      1.582         16        640: 100%|██████████| 19/19 [00:06<00:00,  2.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  2.47it/s]
#                    all         74         91     0.0063      0.827      0.185     0.0907
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/5      2.59G      1.725       3.14      1.535         13        640: 100%|██████████| 19/19 [00:07<00:00,  2.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  2.78it/s]
#                    all         74         91    0.00725      0.844      0.206     0.0958
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/5       2.6G       1.67      2.999      1.514         17        640: 100%|██████████| 19/19 [00:08<00:00,  2.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  2.87it/s]
#                    all         74         91    0.00607      0.925      0.206     0.0858
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         5/5      2.63G      1.716      2.909      1.553         12        640: 100%|██████████| 19/19 [00:06<00:00,  3.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  1.67it/s]
#                    all         74         91      0.592     0.0748      0.255       0.11
# 5 epochs completed in 0.015 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.147 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  2.70it/s]
#                    all         74         91      0.591     0.0722      0.254       0.11
#                  glass          8          8          1          0      0.198     0.0478
#                  metal         16         21      0.148     0.0476       0.13     0.0527
#                  paper         23         24          1     0.0809      0.434      0.202
#                plastic         34         38      0.217       0.16      0.253      0.138
# Speed: 0.3ms preprocess, 3.2ms inference, 0.0ms loss, 5.0ms postprocess per image
# Results saved to runs/detect/train
# Training process completed. Results object obtained.
# Warning: Training results metrics not found or empty in the results object.
# Trainer object is available. Save directory: runs/detect/train
# Path to best weights: runs/detect/train/weights/best.pt

# %% [markdown]
# If the model outputs even one image with a bounding box and label, then the dataset should work for our project! Verify this using the code below.

# %%
import cv2
from random import sample
import matplotlib.pyplot as plt

if model.trainer is None:
    raise RuntimeError(
        "model.trainer is None. This usually means the training process "
        "failed or was interrupted. Please check the output of the "
        "model.train() call for specific error messages from YOLO. "
        "Common causes include issues with 'data.yaml' (e.g., nc=0, incorrect paths), "
        "missing/corrupt data, or resource limitations."
    )

# Dynamically get the path to the best weights from the completed training.
# The 'model' object is the one on which 'train' was called, and its 'trainer'
# attribute stores information about the run, including the save directory.
best_weights_path = Path(model.trainer.save_dir) / 'weights' / 'best.pt'

# Load the trained model for inference using the dynamically found path.
# This reassigns the 'model' variable to the loaded inference model.
model = YOLO(best_weights_path)

# Use the 'images_train' path defined earlier for consistency.
train_images_path = images_train 

image_files = list(train_images_path.glob('*.jpg'))

# Check if images were found before attempting to sample
if not image_files:
    print(f"Error: No images found in {train_images_path}. Cannot display predictions.")
    sample_images = [] # Ensure sample_images is empty to skip the loop
elif len(image_files) < 10:
    print(f"Warning: Found only {len(image_files)} images in {train_images_path}. Using all available images for prediction.")
    sample_images = image_files # Use all found images if less than 10
else:
    sample_images = sample(image_files, 10)

for image_path in sample_images:
    result = model(image_path)[0]
    annotated_image = result.plot()

    plt.figure(figsize=(8, 6))
    plt.imshow(annotated_image)
    plt.title(f'Predictions: {image_path.name}')
    plt.axis('off')
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# If the model successfully generated even one image with a bounding box and label, please download the converted dataset and upload it on Google Drive, https://www.google.com/url?q=https%3A%2F%2Fdrive.google.com%2Fdrive%2Ffolders%2F1bUkIYQRXX08OKI5TuOSg-eqntSudGaFB.

# %%
from datetime import datetime

dataset_name = 'aquatrash_yolo'

# Generate date prefix
date_str = datetime.now().strftime('%Y%m%d')
zip_name = f"{date_str}_{dataset_name}.zip"

# Change directory and zip
# %cd /kaggle/working/{dataset_name}
# !zip -r /content/{zip_name} .

print(f"✅ Zip created at /content/{zip_name}")
# Out:
# /kaggle/working/aquatrash_yolo
#   adding: labels/ (stored 0%)
#   adding: labels/val/ (stored 0%)
#   adding: labels/val/000019_jpg.rf.e4d28c72e4ca25a59b07de7d8cc87080.txt (deflated 14%)
#   adding: labels/val/000021_jpg.rf.22832d293d317b13e588374218a71e00.txt (deflated 40%)
#   adding: labels/val/000009_jpg.rf.8434a803f417f51fe5ebe4f6b9697cce.txt (deflated 16%)
#   adding: labels/val/000015_jpg.rf.8a658891a7ac82f12000145ec489cf4c.txt (deflated 31%)
#   adding: labels/val/000094_JPG.rf.b6241bd0418850c0ca1916017d039774.txt (deflated 5%)
#   adding: labels/val/000007_JPG.rf.a40debf74b3f5228742cd22b8ea9ce08.txt (deflated 8%)
#   adding: labels/val/000015_jpg.rf.eebd5ba151182f6edadd573ffdf6fe85.txt (deflated 28%)
#   adding: labels/val/000015_JPG.rf.df7d83766fb301cd8635988698f82196.txt (deflated 5%)
#   adding: labels/val/000025_jpg.rf.2c5a598559f4ac3e19a1a3bf2a098d4a.txt (deflated 11%)
#   adding: labels/val/000011_jpg.rf.8b7fff6ea8f7330e402b6a7757b1866b.txt (deflated 8%)
#   adding: labels/val/000091_JPG.rf.6ab34e036290bbab1a78573b63cfb996.txt (deflated 8%)
#   adding: labels/val/000017_jpg.rf.1b16bea2730faf919fea7016568d1630.txt (deflated 5%)
#   adding: labels/val/000097_JPG.rf.f5d6b5572b60dba12a4b39a6af33ac05.txt (deflated 11%)
#   adding: labels/val/000039_JPG.rf.18085a5d84e17aca7dbc278f39f141a0.txt (deflated 8%)
#   adding: labels/val/000021_jpg.rf.686ef3b74a19214af6e22e15ad692bca.txt (deflated 5%)
#   adding: labels/val/000064_jpg.rf.d848c83989a9551ef394ff479572f411.txt (deflated 11%)
#   adding: labels/val/000027_jpg.rf.17f02195e9d2f6c52cf2ec29995d1190.txt (deflated 5%)
#   adding: labels/val/000041_jpg.rf.a45728032928eb56e55b61ebf7d5a5a0.txt (deflated 11%)
#   adding: labels/val/000031_jpg.rf.8c396e9a76da42438aed8a9346072d35.txt (deflated 19%)
#   adding: labels/val/000041_jpg.rf.92043de1d993c43f5aa9b77afd2f1d63.txt (deflated 8%)
#   adding: labels/val/000063_jpg.rf.52308eca5e26989dbf3d5d54da6e7dc4.txt (deflated 16%)
#   adding: labels/val/000048_jpg.rf.d1fe2466217a45a9b771617022ee7c18.txt (deflated 8%)
#   adding: labels/val/000012_jpg.rf.fb1054104801ab389977b568bde7e0ce.txt (deflated 5%)
#   adding: labels/val/000064_jpg.rf.a1cc41f6879e58b49881a28cd5ea539c.txt (deflated 8%)
#   adding: labels/val/000069_jpg.rf.cb1b72feff05a77571afa6dcdcccc334.txt (deflated 8%)
#   adding: labels/val/000081_JPG.rf.a35d5c0eaa37af2f138eb0e1e2401329.txt (deflated 8%)
#   adding: labels/val/000037_jpg.rf.313662ef20a5ccca5fc196365095bf22.txt (deflated 5%)
#   adding: labels/val/000008_jpg.rf.a24ec77372a4a2d8f9cd694ffec10c9a.txt (deflated 5%)
#   adding: labels/val/000080_jpg.rf.905783efbe74ab1c175fa94d5697d4e0.txt (deflated 11%)
#   adding: labels/val/000071_jpg.rf.03e05c930100da1c0facea5f23b89f7d.txt (deflated 8%)
#   adding: labels/val/000128_JPG.rf.eb71904df1426bfc208c7f961ae52d22.txt (deflated 46%)
#   adding: labels/val/000061_jpg.rf.e15cc3e3cd9bc8fb042b83bfaae11857.txt (deflated 5%)
#   adding: labels/val/000020_JPG.rf.ebbafb64b09f4937003dcda6b94d27ee.txt (deflated 5%)
#   adding: labels/val/000001_jpg.rf.42c4ba88119aae9d425f5c004cb2ce0d.txt (deflated 8%)
#   adding: labels/val/000079_jpg.rf.29fa0266416a159608cf24b4e72c0b6a.txt (deflated 8%)
#   adding: labels/val/000077_jpg.rf.37455f94e58126e1310cae690bdf8e25.txt (deflated 8%)
#   adding: labels/val/000092_JPG.rf.41d0b245d0c489dfc1914d665a7e5e62.txt (deflated 28%)
#   adding: labels/val/000061_jpg.rf.c09706e87e6b429d4069e8bddb554c44.txt (deflated 8%)
#   adding: labels/val/000108_JPG.rf.a2d50edbe09c14b390aeabac181f2e0f.txt (deflated 11%)
#   adding: labels/val/000024_jpg.rf.5545363767994e0edf0a31ceda3dc6e5.txt (deflated 14%)
#   adding: labels/val/000004_jpg.rf.a08d4635ed056a7cc41f66fefa9eccc4.txt (deflated 16%)
#   adding: labels/val/000029_jpg.rf.cf85d3fcd918116e30994de824d50752.txt (deflated 8%)
#   adding: labels/val/000000_jpg.rf.beffaf3b548106ccf1da5dc629bc9504.txt (deflated 28%)
#   adding: labels/val/000035_jpg.rf.50f05fa6ede845869668871e91e31f71.txt (deflated 8%)
#   adding: labels/val/000069_JPG.rf.754c7034631beace810600af537cf1d3.txt (deflated 11%)
#   adding: labels/val/000006_jpg.rf.33a70c1d2244237b53e6924046000d26.txt (deflated 11%)
#   adding: labels/val/000097_jpg.rf.5ee362e58370980eb351d337f6409ef4.txt (deflated 27%)
#   adding: labels/val/000012_jpg.rf.c50f074f2cd7a6b5362f0c6f98300848.txt (deflated 28%)
#   adding: labels/val/000054_jpg.rf.3fa00c0cefb8d7fac889afd3fbfff716.txt (deflated 27%)
#   adding: labels/val/000030_jpg.rf.decccf4babe0f1d8526ce55ce0d931d0.txt (deflated 16%)
#   adding: labels/val/000084_JPG.rf.942837bfb405ac2730506b6f511f608e.txt (deflated 38%)
#   adding: labels/val/000000_jpg.rf.ee75fdf06813399a8376c6ff7056423a.txt (deflated 11%)
#   adding: labels/val/000124_JPG.rf.11c5626f03313f2a2700d2131bbee98e.txt (deflated 8%)
#   adding: labels/val/000058_jpg.rf.04df31ce152c94461e36817d87803047.txt (deflated 16%)
#   adding: labels/val/000067_JPG.rf.2758d801c66557b16af99505fcadeca8.txt (deflated 14%)
#   adding: labels/val/000053_JPG.rf.8bab99ebbbad46087e65e6c47f7fdaf0.txt (deflated 5%)
#   adding: labels/val/000085_JPG.rf.6601a3f912670beac53085714278db85.txt (deflated 5%)
#   adding: labels/val/000066_JPG.rf.4d451656ce9628a9eb263c2b47828227.txt (deflated 8%)
#   adding: labels/val/000033_jpg.rf.b651954382c3ffa0651021309555c8d9.txt (deflated 19%)
#   adding: labels/val/000086_jpg.rf.21d6c190ab94e71b2f49fb97de73d378.txt (deflated 14%)
#   adding: labels/val/000098_JPG.rf.a5665b7913007535189b824dfb05aedc.txt (deflated 8%)
#   adding: labels/val/000022_jpg.rf.24374a2700679021d5ab94c2ad2434e7.txt (deflated 11%)
#   adding: labels/val/000019_jpg.rf.cdf730508ce823ef87c6ee777bf9cf1c.txt (deflated 27%)
#   adding: labels/val/000061_jpg.rf.d9ca75b67361d9fcc54b1c8962457f19.txt (deflated 8%)
#   adding: labels/val/000054_jpg.rf.24392ce9c7bd1720c838a311c17f958e.txt (deflated 14%)
#   adding: labels/val/000029_jpg.rf.5784f2b6c1db027a77b6dce92fe4560d.txt (deflated 8%)
#   adding: labels/val/000049_jpg.rf.3dc5ad8a124f2516da33d49496ff55dc.txt (deflated 11%)
#   adding: labels/val/000025_jpg.rf.27b0c7d7e6bb159099bf20cc703c2662.txt (deflated 16%)
#   adding: labels/val/000033_JPG.rf.1a792603df082c1ffc695159498aa4eb.txt (deflated 8%)
#   adding: labels/val/000002_jpg.rf.cc63f3f198e4bafa011b425d63252066.txt (deflated 5%)
#   adding: labels/val/000082_jpg.rf.aa55332900465a30687548c20145a4e4.txt (deflated 14%)
#   adding: labels/val/000065_jpg.rf.adefa5b0d326eea9e928516289993384.txt (deflated 8%)
#   adding: labels/val/000010_jpg.rf.d731a0e01f49ec0a95a0f3a1b10ef155.txt (deflated 8%)
#   adding: labels/val/000042_jpg.rf.01523622698a610b1e98c82007f8d91f.txt (deflated 27%)
#   adding: labels/train/ (stored 0%)
#   adding: labels/train/000007_jpg.rf.aacac0039250183e0db8e195ab9a1e9f.txt (deflated 11%)
#   adding: labels/train/000027_jpg.rf.971b8cf615c3c0239d8d8acf9bf5e93b.txt (deflated 14%)
#   adding: labels/train/000083_jpg.rf.249c5fa4724ca90ecd2ad773286ea1ac.txt (deflated 5%)
#   adding: labels/train/000040_jpg.rf.acee0a18ebd6288ce78e384562c3071c.txt (deflated 11%)
#   adding: labels/train/000087_jpg.rf.690ec33d4afb8bd8fe24d397b278fa19.txt (deflated 14%)
#   adding: labels/train/000030_jpg.rf.e1e9870f5ac27db278018cf38e4134d4.txt (deflated 8%)
#   adding: labels/train/000091_JPG.rf.54bec092812303b6db4922bdb9945a4f.txt (deflated 5%)
#   adding: labels/train/000027_jpg.rf.78100628554443378adcc62660a75524.txt (deflated 5%)
#   adding: labels/train/000068_JPG.rf.b6d34dfe4b896d0c753385ca4c3072a3.txt (deflated 8%)
#   adding: labels/train/000070_JPG.rf.ac12be75acbb1f1fca8f1947860d0da1.txt (deflated 8%)
#   adding: labels/train/000026_JPG.rf.4e2d2c91e5c4c4797ec026217430960c.txt (deflated 44%)
#   adding: labels/train/000118_JPG.rf.7210ba6eef46f0727afbc548098fee07.txt (deflated 14%)
#   adding: labels/train/000001_jpg.rf.3b10b06a0479e6c9e52202033c95d203.txt (deflated 16%)
#   adding: labels/train/000018_JPG.rf.36e111eac7cbfd6aaa50376c786844a0.txt (deflated 28%)
#   adding: labels/train/000048_JPG.rf.192e18b148d3faf4514fd896eb5e5326.txt (deflated 11%)
#   adding: labels/train/000055_JPG.rf.0ba25c38ed10af00810dda648d2461a0.txt (deflated 14%)
#   adding: labels/train/000062_jpg.rf.acdd0f27e3fcc9d7a86af6b9c7e22d79.txt (deflated 29%)
#   adding: labels/train/000067_jpg.rf.8746caea06137e0d921d481470170ef3.txt (deflated 5%)
#   adding: labels/train/000006_JPG.rf.9b7b9fcb1ec280c54ddf5eafa9a0ba02.txt (deflated 8%)
#   adding: labels/train/000043_JPG.rf.97b188ae84207f3ee32e795188a04d0d.txt (deflated 5%)
#   adding: labels/train/000043_jpg.rf.89692ae77bf2b39f40254f4998e61121.txt (deflated 8%)
#   adding: labels/train/000003_JPG.rf.94d22bad4e3f02b1bef15f769561cd9e.txt (deflated 27%)
#   adding: labels/train/000014_JPG.rf.7b43c4e66af30c5b5e9914628b7a92e1.txt (deflated 8%)
#   adding: labels/train/000046_JPG.rf.c5f7cb4aba7aaca4f6386737a180f353.txt (deflated 14%)
#   adding: labels/train/000021_jpg.rf.dedb632cd4867ee95608a988ff38fee7.txt (deflated 37%)
#   adding: labels/train/000096_JPG.rf.81524839612961c65378b67c9944af85.txt (deflated 8%)
#   adding: labels/train/000082_JPG.rf.f4ab7cd5eb7f3f2eaec22644a49b4280.txt (deflated 28%)
#   adding: labels/train/000106_JPG.rf.dc2345e3176c7524cfdbb42983dd3db0.txt (deflated 28%)
#   adding: labels/train/000098_jpg.rf.293ef58f232e1d7f69675e47277df69f.txt (deflated 11%)
#   adding: labels/train/000067_jpg.rf.a9517e2a94617e0eb350cc2dedc84fa7.txt (deflated 8%)
#   adding: labels/train/000013_jpg.rf.276a38f9b9f8e84d3f72cc9cabba0cfc.txt (deflated 25%)
#   adding: labels/train/000027_JPG.rf.8063f46827257d27073fc88c205da226.txt (deflated 39%)
#   adding: labels/train/000074_jpg.rf.ec9d0227c327aae1a43d1ece31927667.txt (deflated 24%)
#   adding: labels/train/000078_jpg.rf.7bbd087a733dfd7a22418dab6e9d0bce.txt (deflated 8%)
#   adding: labels/train/000072_jpg.rf.390f3117daa887331568b07f96fbd893.txt (deflated 8%)
#   adding: labels/train/000081_JPG.rf.ea3619a1163b1494d458dbd578f58523.txt (deflated 14%)
#   adding: labels/train/000049_jpg.rf.0c8e5b44339feb4cc686ebbd443732c3.txt (deflated 5%)
#   adding: labels/train/000023_jpg.rf.5aa9e0a58af86a4baa08d4bfe7513ef9.txt (deflated 8%)
#   adding: labels/train/000079_JPG.rf.0f2718510c3e0e2a18fbc4e7d4883d61.txt (deflated 29%)
#   adding: labels/train/000086_JPG.rf.2b89cfe42c327e4eea7d99d8c5fa456e.txt (deflated 5%)
#   adding: labels/train/000095_jpg.rf.5a1e9f2f9e387ba2f2c8155b8410656e.txt (deflated 5%)
#   adding: labels/train/000015_jpg.rf.f1be72fdd82f24951e7abf8c86b9dbeb.txt (deflated 40%)
#   adding: labels/train/000079_JPG.rf.0d7e0fb2df1f2aaa5b5c3966ccf931b1.txt (deflated 11%)
#   adding: labels/train/000064_JPG.rf.a76010b9e4374502cab5dc7a4bf721ab.txt (deflated 8%)
#   adding: labels/train/000030_JPG.rf.c15e0ebc324ac9b1c9789f824124ebb8.txt (deflated 5%)
#   adding: labels/train/000022_jpg.rf.6305b19f11fbdabcba40fa94e8b45bbd.txt (deflated 27%)
#   adding: labels/train/000073_JPG.rf.145dc63ae9acd801448a99fe37a03c94.txt (deflated 11%)
#   adding: labels/train/000096_JPG.rf.bb1e71a6719d5b92c64747e681d3193a.txt (deflated 8%)
#   adding: labels/train/000066_jpg.rf.75f8981fccaeeb5214198ca1b0011e4e.txt (deflated 8%)
#   adding: labels/train/000003_jpg.rf.9ca0e5925486fa97540b07414ea9b277.txt (deflated 11%)
#   adding: labels/train/000040_jpg.rf.4e71645b58f3690e9fb7c065df60327c.txt (deflated 16%)
#   adding: labels/train/000063_jpg.rf.d1a3a30f3844145e3301b8899b07fac8.txt (deflated 14%)
#   adding: labels/train/000062_JPG.rf.d6fb3faeeeebdde7bc81cac72f5f2667.txt (deflated 8%)
#   adding: labels/train/000052_jpg.rf.25b847f3b003bf3d15c848751ee6c4e3.txt (deflated 8%)
#   adding: labels/train/000071_JPG.rf.2b5d02a4e6c70c644358c781ec3d1faa.txt (deflated 11%)
#   adding: labels/train/000069_JPG.rf.4769df06d950594f211723a5fb04c972.txt (deflated 8%)
#   adding: labels/train/000006_jpg.rf.0c45474870c2a5df516344df31448c15.txt (deflated 11%)
#   adding: labels/train/000076_JPG.rf.a119806e7929c22e2c21ee95d0913e0d.txt (deflated 5%)
#   adding: labels/train/000069_jpg.rf.46d560bf60ef856322d7dfbf2d0fbbbb.txt (deflated 14%)
#   adding: labels/train/000051_jpg.rf.92178b1d22661dc4a10ffe6bfd5b4277.txt (deflated 28%)
#   adding: labels/train/000071_JPG.rf.71712e41ac49488b771991daa54266a9.txt (deflated 11%)
#   adding: labels/train/000060_JPG.rf.484b7b820b45a4f99f2657b9e9179be9.txt (deflated 19%)
#   adding: labels/train/000001_JPG.rf.ccfdd243a78a6cfa119be0349d18c0ed.txt (deflated 29%)
#   adding: labels/train/000059_jpg.rf.8a05b618a5d7b50ee78f9014a0f0b85f.txt (deflated 22%)
#   adding: labels/train/000110_JPG.rf.1234fd1e36c337e944e129929f83d0db.txt (deflated 5%)
#   adding: labels/train/000022_JPG.rf.2142a3416365cf34993f4abb1d7d8458.txt (deflated 27%)
#   adding: labels/train/000037_jpg.rf.8ad39cbfee50a24f9206369a13376025.txt (deflated 40%)
#   adding: labels/train/000117_JPG.rf.792aeeed8617c75c61e6ca1c5a433dae.txt (deflated 8%)
#   adding: labels/train/000095_JPG.rf.e753a5b2a9e39abe1223dd53e3e1cc3b.txt (deflated 19%)
#   adding: labels/train/000099_JPG.rf.c2ef3af6f95642fde1e1f26c70bc8726.txt (deflated 8%)
#   adding: labels/train/000051_jpg.rf.b4ca307c76db86f30e337b25e9fa54cd.txt (deflated 8%)
#   adding: labels/train/000024_jpg.rf.5ae48b6ddd7f0f7f3ba97f14717cc6c6.txt (deflated 28%)
#   adding: labels/train/000014_jpg.rf.38b062b115e46087392c4a6a42009aa3.txt (deflated 36%)
#   adding: labels/train/000049_jpg.rf.272258d1d7994ce7f1064abf6690dc20.txt (deflated 16%)
#   adding: labels/train/000072_jpg.rf.94042e6b9b6418ed601c5b245790afcc.txt (deflated 27%)
#   adding: labels/train/000005_jpg.rf.2e2ec7a6579289fe5714bdb2753880b4.txt (deflated 8%)
#   adding: labels/train/000088_JPG.rf.0b5b57682430c8c107553f91bf24be8e.txt (deflated 38%)
#   adding: labels/train/000055_jpg.rf.58e1c338ac4aa308d78ceb9b8e93d7ee.txt (deflated 11%)
#   adding: labels/train/000092_JPG.rf.f79df099c5856824fcd647d2767596c7.txt (deflated 11%)
#   adding: labels/train/000039_jpg.rf.abffb6d1a849a745b7323aa5402ea595.txt (deflated 5%)
#   adding: labels/train/000005_JPG.rf.216ea83ee4d2dd49c9633c1367894151.txt (deflated 14%)
#   adding: labels/train/000055_jpg.rf.44eeba23c4e8813b50a409ad8fb34ad0.txt (deflated 8%)
#   adding: labels/train/000084_jpg.rf.f44a770ba1b45b5390f90e977e147578.txt (deflated 28%)
#   adding: labels/train/000025_jpg.rf.96f8a937bf9ac013ea3422706daad7f2.txt (deflated 8%)
#   adding: labels/train/000050_jpg.rf.10dfca50c92084c90bd0ec9b2b5fbaed.txt (deflated 16%)
#   adding: labels/train/000080_JPG.rf.993f9dbfdbb7c771b54270554b538de5.txt (deflated 8%)
#   adding: labels/train/000098_JPG.rf.11ffd21ae91ef5ba3c82ec792c0f0b60.txt (deflated 8%)
#   adding: labels/train/000073_jpg.rf.89b23fe20d196ec2e09be07f273d97f6.txt (deflated 8%)
#   adding: labels/train/000004_jpg.rf.2b05f74aef4b9075fc4850b59e2cb840.txt (deflated 8%)
#   adding: labels/train/000082_jpg.rf.6b6f7ad63a90f9d9d860b803e99ec49a.txt (deflated 8%)
#   adding: labels/train/000083_JPG.rf.9d560f08f9052b58d3e4d55b076c2cca.txt (deflated 5%)
#   adding: labels/train/000026_jpg.rf.0c461fdb6595f50eeb6fee3b8532f452.txt (deflated 14%)
#   adding: labels/train/000065_jpg.rf.db526887a8a626cbec62106baf05c712.txt (deflated 11%)
#   adding: labels/train/000044_jpg.rf.215bd723ad8d987f75dd33f33fbf2c00.txt (deflated 16%)
#   adding: labels/train/000047_jpg.rf.c04a677ec28e0c24aaeec39f894b1fe2.txt (deflated 27%)
#   adding: labels/train/000059_jpg.rf.e9dd8b4e994229ab3e92710b6cc8e4af.txt (deflated 27%)
#   adding: labels/train/000101_JPG.rf.a7c1b7e330f8e26da6f5e66603e76bf6.txt (deflated 11%)
#   adding: labels/train/000011_jpg.rf.6559a6761a9fef22596aaea88cde3747.txt (deflated 8%)
#   adding: labels/train/000051_JPG.rf.6539945e2a3c2ed0824526617798b26c.txt (deflated 8%)
#   adding: labels/train/000095_JPG.rf.6a841ed816f96a34eaaba03356885682.txt (deflated 5%)
#   adding: labels/train/000028_jpg.rf.b86deb4fce55807f757fa2b52feba0af.txt (deflated 8%)
#   adding: labels/train/000009_jpg.rf.c6c0c6c8403228f34ac9b2e13fb43904.txt (deflated 8%)
#   adding: labels/train/000053_jpg.rf.58742b4cc98ffea73836546c05bc1547.txt (deflated 8%)
#   adding: labels/train/000001_jpg.rf.a23b83dbda863601c92725ae9ba3bab7.txt (deflated 8%)
#   adding: labels/train/000090_JPG.rf.bc3088c0d0847041b9a2274937af9057.txt (deflated 5%)
#   adding: labels/train/000010_jpg.rf.69db314ea2d581e398dbbc6b0477b22a.txt (deflated 8%)
#   adding: labels/train/000056_jpg.rf.0d4d304fd2f03ba889305fb9ff43394b.txt (deflated 8%)
#   adding: labels/train/000099_JPG.rf.39fa14946e0ae5cf85c07ed1af0c3d00.txt (deflated 5%)
#   adding: labels/train/000086_JPG.rf.a9c84c634a161dec85f5ca62fff0d0b7.txt (deflated 5%)
#   adding: labels/train/000068_jpg.rf.f0ac438ac2d888e854e2b6292484f6b7.txt (deflated 8%)
#   adding: labels/train/000011_jpg.rf.5ce2ed4dcf441076fc5244f22aedb9b7.txt (deflated 5%)
#   adding: labels/train/000074_jpg.rf.8aa73efb149a020c7c5397c454598483.txt (deflated 8%)
#   adding: labels/train/000020_jpg.rf.b2ba1f0d153f592d072b38bdd755df45.txt (deflated 11%)
#   adding: labels/train/000091_jpg.rf.1c2835b63b19d5c0af7a27129abfbb2f.txt (deflated 8%)
#   adding: labels/train/000047_JPG.rf.72be7e73ce0d387830038342f92e0d6d.txt (deflated 5%)
#   adding: labels/train/000044_jpg.rf.b397d82ddd718a92bb3e8adc6d0cbea7.txt (deflated 11%)
#   adding: labels/train/000078_jpg.rf.f28c5c7961f5d92ad58e2cab69afbb60.txt (deflated 11%)
#   adding: labels/train/000026_jpg.rf.7f0e1403c9665cc1ab664ca6100d6308.txt (deflated 28%)
#   adding: labels/train/000029_JPG.rf.fcf8924626cf7b9079801100444609a4.txt (deflated 25%)
#   adding: labels/train/000032_jpg.rf.fee88c0ab919cec5db2c78d4cb2d2b3d.txt (deflated 8%)
#   adding: labels/train/000038_jpg.rf.42a1060772b6e12dea0366652ecf9817.txt (deflated 5%)
#   adding: labels/train/000018_jpg.rf.5ed8b50a0baee1603b659c848822fa24.txt (deflated 11%)
#   adding: labels/train/000003_jpg.rf.cf210b41c1d6dfa4e817572b3eae08b6.txt (deflated 8%)
#   adding: labels/train/000072_JPG.rf.694e1d668b22358432288e9027607c66.txt (deflated 14%)
#   adding: labels/train/000020_jpg.rf.94c0d1159c8aaa257792cf2c13801ef9.txt (deflated 8%)
#   adding: labels/train/000042_JPG.rf.3540075c32a95902f389fb56efabf3da.txt (deflated 8%)
#   adding: labels/train/000096_jpg.rf.9a4acf1ff6f712d135693810d6776ba6.txt (deflated 8%)
#   adding: labels/train/000044_JPG.rf.62df54827e28b5224339874dad868241.txt (deflated 5%)
#   adding: labels/train/000055_jpg.rf.819465c234876c06ce66ea2fc9c9b2d6.txt (deflated 14%)
#   adding: labels/train/000083_jpg.rf.d2118dfada822631307421d62fc27a7d.txt (deflated 16%)
#   adding: labels/train/000079_jpg.rf.b2d3b1c6905651b9cf1d939eafd87a52.txt (deflated 8%)
#   adding: labels/train/000007_jpg.rf.dd0bfb8e733e43961547eec533fea3b8.txt (deflated 38%)
#   adding: labels/train/000031_jpg.rf.361fe414c2979c2ebc9941f147c6ad6a.txt (deflated 11%)
#   adding: labels/train/000078_JPG.rf.11fe3fdd9daf4c106fd15d42463088c9.txt (deflated 11%)
#   adding: labels/train/000007_jpg.rf.c1aa0a792a4edb7de41bcc9a00738a8a.txt (deflated 28%)
#   adding: labels/train/000016_jpg.rf.73e85f3f95f7bdba3be928f90b7586f5.txt (deflated 8%)
#   adding: labels/train/000013_JPG.rf.da886096a055f2b459a99d202eb3fdbf.txt (deflated 8%)
#   adding: labels/train/000073_JPG.rf.b7b3da44f9a28163038e7d3429b67b27.txt (deflated 5%)
#   adding: labels/train/000087_JPG.rf.468a151affd32005f62c675d8e1bb714.txt (deflated 8%)
#   adding: labels/train/000057_jpg.rf.090b69a8cf99e176436fb111a65e81c9.txt (deflated 5%)
#   adding: labels/train/000048_jpg.rf.2381f52a308a97ca3ee02325e2c93824.txt (deflated 42%)
#   adding: labels/train/000093_jpg.rf.8d536f36e117812a1ef369c7b67f0635.txt (deflated 8%)
#   adding: labels/train/000034_jpg.rf.a2ab4f9fc73f9a6b8ccdde4129d1c8ea.txt (deflated 8%)
#   adding: labels/train/000005_jpg.rf.003793a128998b50c820a5951d5a5ba5.txt (deflated 8%)
#   adding: labels/train/000045_jpg.rf.35d41e4cce69c5e3fdf60eba5fd9f01e.txt (deflated 14%)
#   adding: labels/train/000076_jpg.rf.b9b869ca9da200bf355acbf878fd5893.txt (deflated 5%)
#   adding: labels/train/000068_jpg.rf.454129fcb1f7c7d009626ba0adddc8b3.txt (deflated 11%)
#   adding: labels/train/000056_JPG.rf.dfcd12c23a39c09df1dd428915deb8f6.txt (deflated 8%)
#   adding: labels/train/000064_JPG.rf.82e6a02e0c40403343b8b5d42eb828be.txt (deflated 8%)
#   adding: labels/train/000093_JPG.rf.80736b0d6e3659f91445ad3fce4c95e4.txt (deflated 11%)
#   adding: labels/train/000036_JPG.rf.0c1ef2f74ed2d1b89a669bf5ffd06078.txt (deflated 16%)
#   adding: labels/train/000006_jpg.rf.6748007ba9263baa2c6a7961da13e343.txt (deflated 8%)
#   adding: labels/train/000073_jpg.rf.6842cbbd47a4deaa5efba665912652c5.txt (deflated 8%)
#   adding: labels/train/000038_jpg.rf.f495ce764fef2fedcefdf9da0b96510a.txt (deflated 8%)
#   adding: labels/train/000070_JPG.rf.002423292827c0192719e23f3ee1d20a.txt (deflated 11%)
#   adding: labels/train/000059_jpg.rf.acd795453e9adb3e6722da8075e66b05.txt (deflated 14%)
#   adding: labels/train/000085_JPG.rf.3a330c761f605d89e6574aebf45e90a1.txt (deflated 8%)
#   adding: labels/train/000045_jpg.rf.a3ae271406456c4ad09b79565c688343.txt (deflated 16%)
#   adding: labels/train/000074_JPG.rf.47a9151525777468c44e8691f29e6789.txt (deflated 29%)
#   adding: labels/train/000107_JPG.rf.8e2873181ee1acfb953a1ef5f3506bda.txt (deflated 8%)
#   adding: labels/train/000019_jpg.rf.a18fa60b6d2094c68414610227aa951d.txt (deflated 38%)
#   adding: labels/train/000089_jpg.rf.2260e83c8296b37a3532392442fe36ff.txt (deflated 8%)
#   adding: labels/train/000111_JPG.rf.927d622eef402872a82857c9023d8dc8.txt (deflated 38%)
#   adding: labels/train/000019_JPG.rf.84f4d33da2cd2fcf85f50f1d715a46eb.txt (deflated 8%)
#   adding: labels/train/000040_jpg.rf.70a4d78ca394877e9ecd43e10e3ec9ab.txt (deflated 8%)
#   adding: labels/train/000090_JPG.rf.c97c3949f635efcdd64c34a3507e0843.txt (deflated 11%)
#   adding: labels/train/000129_JPG.rf.eb4bb302dd9580081c49afc5465f58ce.txt (deflated 43%)
#   adding: labels/train/000122_JPG.rf.257323c30f94a7c71f2db4613eb8bac5.txt (deflated 5%)
#   adding: labels/train/000021_JPG.rf.83716ea370ecf4752af77f799e00cff8.txt (deflated 14%)
#   adding: labels/train/000104_JPG.rf.332a5aa47edc75e29cc9a26b80635198.txt (deflated 42%)
#   adding: labels/train/000062_JPG.rf.6b330fe3640fd645f556b593287bd5b5.txt (deflated 28%)
#   adding: labels/train/000005_jpg.rf.64c6c9f622771b349148c96d537e8ff5.txt (deflated 8%)
#   adding: labels/train/000013_jpg.rf.9ba00883de5b5dd801c272cce5818c89.txt (deflated 8%)
#   adding: labels/train/000127_JPG.rf.fd5002b407acccd8ae1e918c23cf7b91.txt (deflated 36%)
#   adding: labels/train/000008_jpg.rf.aebe91f54e904a647432057275ae9403.txt (deflated 28%)
#   adding: labels/train/000043_jpg.rf.dcc353439f9822c87e9addf87786a0bd.txt (deflated 5%)
#   adding: labels/train/000034_jpg.rf.82ca4f12eecc7c30bea59f141d42dfb3.txt (deflated 14%)
#   adding: labels/train/000023_jpg.rf.2c7afb3316f1734a18b8d1169b907f85.txt (deflated 16%)
#   adding: labels/train/000081_jpg.rf.ddc70e72bf7f39fce3a6892c203459f3.txt (deflated 36%)
#   adding: labels/train/000105_JPG.rf.a330a129113c4f5f88b610530a971012.txt (deflated 11%)
#   adding: labels/train/000058_JPG.rf.4ca01dd26d4560668e688cef86d9991b.txt (deflated 5%)
#   adding: labels/train/000057_jpg.rf.36c41aa6a8b0706bcdabbc74693ca82b.txt (deflated 11%)
#   adding: labels/train/000088_jpg.rf.9728d1367ea3ab96892d07a6bc662ec3.txt (deflated 11%)
#   adding: labels/train/000048_jpg.rf.de00f8d19645a2ddeb2c60fa6cbee63f.txt (deflated 8%)
#   adding: labels/train/000121_JPG.rf.cf0d71db1bc87ad39a55c0a70bbbd0a0.txt (deflated 5%)
#   adding: labels/train/000032_jpg.rf.7133218ca5f644dad64b6936fb74201f.txt (deflated 5%)
#   adding: labels/train/000042_jpg.rf.50f2d9c09c3129b84f2ef041e24b38c0.txt (deflated 11%)
#   adding: labels/train/000002_jpg.rf.ba12a4ce95a3dd81818a5e373efe28be.txt (deflated 8%)
#   adding: labels/train/000000_jpg.rf.e662cb85f63817325956fea222d0990f.txt (deflated 5%)
#   adding: labels/train/000092_jpg.rf.ffe152373a93f35fe9e4e95baa88cf63.txt (deflated 8%)
#   adding: labels/train/000090_jpg.rf.ec22543b6e14ec1cac1f5a0013bb863d.txt (deflated 5%)
#   adding: labels/train/000012_jpg.rf.5054aa20e9cbd6b10b821db6b300ac0c.txt (deflated 14%)
#   adding: labels/train/000031_jpg.rf.29e96ddf2bdb022113e103b7a75835de.txt (deflated 14%)
#   adding: labels/train/000083_JPG.rf.9d1f623c8bef60b865c9c20abfd54386.txt (deflated 5%)
#   adding: labels/train/000067_JPG.rf.88f9c6d648c46d0a3195d049c83b8b3d.txt (deflated 8%)
#   adding: labels/train/000025_JPG.rf.815dda9504412159afed35e46b5a7bc6.txt (deflated 8%)
#   adding: labels/train/000056_jpg.rf.95e52796966f772775c4d95c5c3d62ac.txt (deflated 14%)
#   adding: labels/train/000094_JPG.rf.a30f2b512b80a5829b54518071bcce59.txt (deflated 5%)
#   adding: labels/train/000008_JPG.rf.b7fd07c74e94aeda797b5469cb78809a.txt (deflated 28%)
#   adding: labels/train/000016_jpg.rf.62a0c2e7104b1c47655ff1d0bc5890dd.txt (deflated 8%)
#   adding: labels/train/000099_jpg.rf.553bd2f567aead09fa6ce582ee1f1fdb.txt (deflated 11%)
#   adding: labels/train/000076_jpg.rf.175c02bcb8e9c7b877f0e092de470156.txt (deflated 8%)
#   adding: labels/train/000053_jpg.rf.6767a8e4466955cd84a41f391e4aef80.txt (deflated 11%)
#   adding: labels/train/000040_JPG.rf.fc1bb55b2d7de403f691406d979da825.txt (deflated 5%)
#   adding: labels/train/000008_jpg.rf.581796408fb44c037aa30c62dd8400c5.txt (deflated 14%)
#   adding: labels/train/000094_jpg.rf.ffade2ec7e41ef7d1fe564591764eb43.txt (deflated 14%)
#   adding: labels/train/000000_JPG.rf.d3371cb3d63a59c5ba6730368b7905af.txt (deflated 14%)
#   adding: labels/train/000017_jpg.rf.8f00dc3b244ac3116d76a494bf3d15c1.txt (deflated 8%)
#   adding: labels/train/000018_jpg.rf.0058d47042114f3a156f9232b3a53568.txt (deflated 14%)
#   adding: labels/train/000036_jpg.rf.6989ea6ca94bc9345c0d3781c5524d8f.txt (deflated 29%)
#   adding: labels/train/000037_JPG.rf.93d931816a73f48ddc2f46341f3316c2.txt (deflated 16%)
#   adding: labels/train/000071_jpg.rf.0f771105c36a967b8532d02db90a47df.txt (deflated 16%)
#   adding: labels/train/000056_jpg.rf.59f517d36d5603cf93fab05fe19eaf51.txt (deflated 16%)
#   adding: labels/train/000045_jpg.rf.455034f3fb1f0f78b617ba0d877dea3c.txt (deflated 25%)
#   adding: labels/train/000052_jpg.rf.a786dd2b6c05e8ffdb102af2b2e11be1.txt (deflated 14%)
#   adding: labels/train/000012_JPG.rf.2c4c735b011d8b107a71fea25fa2e7cd.txt (deflated 14%)
#   adding: labels/train/000017_jpg.rf.ba2e5fa6533e4d7816d2a7e294a6d040.txt (deflated 11%)
#   adding: labels/train/000047_jpg.rf.e449cc43414312bd60753116ff1cd5b9.txt (deflated 27%)
#   adding: labels/train/000037_jpg.rf.faf287f1243cfc2dcab9aca232abe93d.txt (deflated 27%)
#   adding: labels/train/000017_JPG.rf.da78d08bc1a77af01c0c4c51a71f6f70.txt (deflated 14%)
#   adding: labels/train/000100_JPG.rf.09ba700d952797e7bcc046066f1758d4.txt (deflated 11%)
#   adding: labels/train/000009_JPG.rf.ae53b7d399c8fa7b5a4d80c2c59d92ed.txt (deflated 37%)
#   adding: labels/train/000042_jpg.rf.04f62abf4f94222669321580b8270762.txt (deflated 8%)
#   adding: labels/train/000061_JPG.rf.5d8e6c70d07936c222d0513ae3ab920f.txt (deflated 11%)
#   adding: labels/train/000024_jpg.rf.090bff7e0ebd097734b99fa1013d587d.txt (deflated 16%)
#   adding: labels/train/000120_JPG.rf.520a1f3428c6ebd24d3fdd103082afc0.txt (deflated 8%)
#   adding: labels/train/000115_JPG.rf.427cc9deffec8a9b16bf0afcad140b25.txt (deflated 39%)
#   adding: labels/train/000013_jpg.rf.29e141f4c018605414d7abd5ec4740e9.txt (deflated 8%)
#   adding: labels/train/000068_JPG.rf.8ad38475b9ee36d5d972e3f3105dba6e.txt (deflated 37%)
#   adding: labels/train/000066_jpg.rf.4cd79288b17ea0efdc2d548acfaeb4cb.txt (deflated 8%)
#   adding: labels/train/000003_jpg.rf.9977c8a2ac9cb00ea0f60901a4b77333.txt (deflated 14%)
#   adding: labels/train/000029_jpg.rf.f3e792ceb992bc41415a77a69c5b93ee.txt (deflated 11%)
#   adding: labels/train/000082_JPG.rf.00a21c7095239899701f24df09060248.txt (deflated 5%)
#   adding: labels/train/000084_JPG.rf.92caefae2de3a94bbab6df88bdf33dc8.txt (deflated 8%)
#   adding: labels/train/000065_JPG.rf.e06e729d4af3f1e6a87e4fa2435cc782.txt (deflated 27%)
#   adding: labels/train/000014_jpg.rf.927348ca51d74a05e3c578fcce761d33.txt (deflated 5%)
#   adding: labels/train/000080_jpg.rf.bfa237d8070193b4cb690ae88b747d0f.txt (deflated 27%)
#   adding: labels/train/000072_JPG.rf.15eda39142f329e131b4f7b7a8524e6c.txt (deflated 29%)
#   adding: labels/train/000054_JPG.rf.76b2370020ef79a2e46989421daa1133.txt (deflated 8%)
#   adding: labels/train/000052_JPG.rf.9d27271635175c59e9509c7f70d87801.txt (deflated 5%)
#   adding: labels/train/000031_JPG.rf.5556409546e8d45b63abb898a841cbf0.txt (deflated 14%)
#   adding: labels/train/000033_jpg.rf.3c607c41efea726d6b92ffdf6596d6dd.txt (deflated 11%)
#   adding: labels/train/000085_jpg.rf.3474819b7c82c49b380fcdf478766207.txt (deflated 27%)
#   adding: labels/train/000060_jpg.rf.81ffb8074efac19d9e5262ef20bfb798.txt (deflated 5%)
#   adding: labels/train/000060_jpg.rf.9f232ad79a42efbeb938398e8867ad51.txt (deflated 11%)
#   adding: labels/train/000089_JPG.rf.950dfd2b9380d77f7e5e80a9ff068b5d.txt (deflated 5%)
#   adding: labels/train/000023_jpg.rf.1957fc0be7e5963e79f9caa40915198d.txt (deflated 47%)
#   adding: labels/train/000030_jpg.rf.cf4fb622e9b578e660bdc9bfd12accc3.txt (deflated 5%)
#   adding: labels/train/000032_JPG.rf.2f4a0c2e65acfb0c0bd48599204a16a5.txt (deflated 11%)
#   adding: labels/train/000070_jpg.rf.b72d2081548c4410e01638f1713062dc.txt (deflated 8%)
#   adding: labels/train/000024_JPG.rf.f8cbab833a31156b0ba7441b9bcee081.txt (deflated 28%)
#   adding: labels/train/000081_jpg.rf.3324339669b6639069474cead9b2d18a.txt (deflated 8%)
#   adding: labels/train/000016_JPG.rf.9a8b06d326724914d88ff7bf7e59a19b.txt (deflated 25%)
#   adding: labels/train/000065_JPG.rf.8ffc3e122419146e7016bcefe3df02fc.txt (deflated 5%)
#   adding: labels/train/000038_jpg.rf.e84ad63ee9a34f619e6bd2b41ef98607.txt (deflated 8%)
#   adding: labels/train/000035_JPG.rf.0d4d0bd8899beca4e91a1510ceaee1fc.txt (deflated 38%)
#   adding: labels/train/000077_JPG.rf.e9b90c05e5361fe7c9eeb5f3c644a975.txt (deflated 14%)
#   adding: labels/train/000010_JPG.rf.80b3f35a4216f2c10fe1457f402994bf.txt (deflated 27%)
#   adding: labels/train/000047_jpg.rf.07bed9ecc70954519a440edb39ffa37f.txt (deflated 27%)
#   adding: labels/train/000036_jpg.rf.da61f54af653c78b4df5c3ef1c2606d1.txt (deflated 14%)
#   adding: labels/train/000038_JPG.rf.d949f49ef17f034a45517c7ee5d4ccd5.txt (deflated 8%)
#   adding: labels/train/000041_JPG.rf.b9c7187161b371d475b9cd1e1e8d1e9a.txt (deflated 8%)
#   adding: labels/train/000063_JPG.rf.c34b95fa0c610f82e3cada41a46d5f95.txt (deflated 11%)
#   adding: labels/train/000028_jpg.rf.da8e70a1ce6cda35988ebe1471b0cd78.txt (deflated 5%)
#   adding: labels/train/000076_JPG.rf.a0b9ad753a233efb6df431527a468297.txt (deflated 5%)
#   adding: labels/train/000023_JPG.rf.c65a0d2377e99a060d4cfac3b8273594.txt (deflated 25%)
#   adding: labels/train/000028_jpg.rf.dda4470887046c5c09a97fd6b6e6d3f1.txt (deflated 8%)
#   adding: labels/train/000050_JPG.rf.db57f41c8e36c19a476b085e91bcf3d7.txt (deflated 11%)
#   adding: labels/train/000062_jpg.rf.606ca7944ce7d2b7f87f8ab0d1840baf.txt (deflated 27%)
#   adding: labels/train/000075_JPG.rf.56a161638e45d3d42c88e751bae4ff44.txt (deflated 11%)
#   adding: labels/train/000034_JPG.rf.d6ff68db163a8b54ffcd3abf769bfe20.txt (deflated 28%)
#   adding: labels/train/000077_jpg.rf.7107bcb67410ae43090bc6c4644d2e01.txt (deflated 8%)
#   adding: labels/train/000035_jpg.rf.1452f2f42d63e062ed907eaa79e8e892.txt (deflated 11%)
#   adding: labels/train/000043_jpg.rf.4d513b8ca4c5a243fcfb10ad7d3d3052.txt (deflated 14%)
#   adding: labels/train/000075_jpg.rf.70594fffc48d625deb65ece444d3696c.txt (deflated 5%)
#   adding: labels/train/000004_jpg.rf.bc8c3c9f203da611f150d441db9ac7ae.txt (deflated 16%)
#   adding: labels/train/000026_jpg.rf.cb9edd2738736188ea9a5c1a33f2d085.txt (deflated 14%)
#   adding: labels/train/000070_jpg.rf.b047a475b7f68a21260af3a9000acf42.txt (deflated 11%)
#   adding: labels/train/000057_JPG.rf.149bf40f203756af065d76c89db81c27.txt (deflated 8%)
#   adding: labels/train/000010_jpg.rf.6c2f5a56db2ee454cac569cf9b78437a.txt (deflated 11%)
#   adding: labels/train/000035_jpg.rf.8db8187059ccaf7094168b0fb6272c8a.txt (deflated 25%)
#   adding: labels/train/000032_jpg.rf.8dd019d56117c6c3bfe285d764931d2f.txt (deflated 8%)
#   adding: labels/train/000049_JPG.rf.e209e826a07c82e6068790992a260120.txt (deflated 16%)
#   adding: labels/train/000102_JPG.rf.3c36d45336bb9af4b54cb2ac29766390.txt (deflated 11%)
#   adding: labels/train/000050_jpg.rf.2e801127ca66b17e472bca68800afb40.txt (deflated 14%)
#   adding: labels/train/000075_jpg.rf.bd32d52408fa0d543d2c48baacf7404c.txt (deflated 8%)
#   adding: labels/train/000039_jpg.rf.35f589fbfaa26392393ed6370dcb7d72.txt (deflated 8%)
#   adding: labels/train/000059_JPG.rf.924270bb72369c33953e656b40325fbd.txt (deflated 5%)
#   adding: labels/train/000074_JPG.rf.67fca822f9b1926b356922af64e583f4.txt (deflated 5%)
#   adding: labels/train/000088_JPG.rf.e947547f0688564d69784cf4b067cc05.txt (deflated 8%)
#   adding: labels/train/000084_jpg.rf.0b52fe6d752013618857704318aab583.txt (deflated 14%)
#   adding: labels/train/000022_jpg.rf.6c1e872d94a0fb00c1d2b610a5c3184a.txt (deflated 11%)
#   adding: labels/train/000093_JPG.rf.664f76e5289f311393e8e9388334022d.txt (deflated 11%)
#   adding: labels/train/000016_jpg.rf.44f83f63a4ab9ab4519ff90f087397c4.txt (deflated 8%)
#   adding: labels/train/000014_jpg.rf.ea60de2dbaca4cb3980931bc035b65b9.txt (deflated 8%)
#   adding: labels/val.cache (deflated 75%)
#   adding: labels/train.cache (deflated 77%)
#   adding: data.yaml (deflated 34%)
#   adding: images/ (stored 0%)
#   adding: images/val/ (stored 0%)
#   adding: images/val/000054_jpg.rf.24392ce9c7bd1720c838a311c17f958e.jpg (deflated 0%)
#   adding: images/val/000041_jpg.rf.a45728032928eb56e55b61ebf7d5a5a0.jpg (deflated 0%)
#   adding: images/val/000025_jpg.rf.2c5a598559f4ac3e19a1a3bf2a098d4a.jpg (deflated 1%)
#   adding: images/val/000033_JPG.rf.1a792603df082c1ffc695159498aa4eb.jpg (deflated 1%)
#   adding: images/val/000063_jpg.rf.52308eca5e26989dbf3d5d54da6e7dc4.jpg (deflated 0%)
#   adding: images/val/000019_jpg.rf.cdf730508ce823ef87c6ee777bf9cf1c.jpg (deflated 0%)
#   adding: images/val/000064_jpg.rf.d848c83989a9551ef394ff479572f411.jpg (deflated 1%)
#   adding: images/val/000030_jpg.rf.decccf4babe0f1d8526ce55ce0d931d0.jpg (deflated 0%)
#   adding: images/val/000067_JPG.rf.2758d801c66557b16af99505fcadeca8.jpg (deflated 0%)
#   adding: images/val/000035_jpg.rf.50f05fa6ede845869668871e91e31f71.jpg (deflated 1%)
#   adding: images/val/000061_jpg.rf.e15cc3e3cd9bc8fb042b83bfaae11857.jpg (deflated 0%)
#   adding: images/val/000092_JPG.rf.41d0b245d0c489dfc1914d665a7e5e62.jpg (deflated 16%)
#   adding: images/val/000069_jpg.rf.cb1b72feff05a77571afa6dcdcccc334.jpg (deflated 0%)
#   adding: images/val/000108_JPG.rf.a2d50edbe09c14b390aeabac181f2e0f.jpg (deflated 0%)
#   adding: images/val/000004_jpg.rf.a08d4635ed056a7cc41f66fefa9eccc4.jpg (deflated 0%)
#   adding: images/val/000042_jpg.rf.01523622698a610b1e98c82007f8d91f.jpg (deflated 2%)
#   adding: images/val/000007_JPG.rf.a40debf74b3f5228742cd22b8ea9ce08.jpg (deflated 1%)
#   adding: images/val/000085_JPG.rf.6601a3f912670beac53085714278db85.jpg (deflated 0%)
#   adding: images/val/000020_JPG.rf.ebbafb64b09f4937003dcda6b94d27ee.jpg (deflated 1%)
#   adding: images/val/000033_jpg.rf.b651954382c3ffa0651021309555c8d9.jpg (deflated 1%)
#   adding: images/val/000079_jpg.rf.29fa0266416a159608cf24b4e72c0b6a.jpg (deflated 0%)
#   adding: images/val/000019_jpg.rf.e4d28c72e4ca25a59b07de7d8cc87080.jpg (deflated 0%)
#   adding: images/val/000071_jpg.rf.03e05c930100da1c0facea5f23b89f7d.jpg (deflated 0%)
#   adding: images/val/000012_jpg.rf.c50f074f2cd7a6b5362f0c6f98300848.jpg (deflated 0%)
#   adding: images/val/000061_jpg.rf.c09706e87e6b429d4069e8bddb554c44.jpg (deflated 6%)
#   adding: images/val/000091_JPG.rf.6ab34e036290bbab1a78573b63cfb996.jpg (deflated 0%)
#   adding: images/val/000010_jpg.rf.d731a0e01f49ec0a95a0f3a1b10ef155.jpg (deflated 1%)
#   adding: images/val/000061_jpg.rf.d9ca75b67361d9fcc54b1c8962457f19.jpg (deflated 0%)
#   adding: images/val/000084_JPG.rf.942837bfb405ac2730506b6f511f608e.jpg (deflated 1%)
#   adding: images/val/000058_jpg.rf.04df31ce152c94461e36817d87803047.jpg (deflated 1%)
#   adding: images/val/000080_jpg.rf.905783efbe74ab1c175fa94d5697d4e0.jpg (deflated 0%)
#   adding: images/val/000015_JPG.rf.df7d83766fb301cd8635988698f82196.jpg (deflated 1%)
#   adding: images/val/000025_jpg.rf.27b0c7d7e6bb159099bf20cc703c2662.jpg (deflated 0%)
#   adding: images/val/000024_jpg.rf.5545363767994e0edf0a31ceda3dc6e5.jpg (deflated 0%)
#   adding: images/val/000000_jpg.rf.ee75fdf06813399a8376c6ff7056423a.jpg (deflated 0%)
#   adding: images/val/000001_jpg.rf.42c4ba88119aae9d425f5c004cb2ce0d.jpg (deflated 0%)
#   adding: images/val/000029_jpg.rf.5784f2b6c1db027a77b6dce92fe4560d.jpg (deflated 0%)
#   adding: images/val/000029_jpg.rf.cf85d3fcd918116e30994de824d50752.jpg (deflated 0%)
#   adding: images/val/000002_jpg.rf.cc63f3f198e4bafa011b425d63252066.jpg (deflated 0%)
#   adding: images/val/000098_JPG.rf.a5665b7913007535189b824dfb05aedc.jpg (deflated 0%)
#   adding: images/val/000000_jpg.rf.beffaf3b548106ccf1da5dc629bc9504.jpg (deflated 0%)
#   adding: images/val/000015_jpg.rf.eebd5ba151182f6edadd573ffdf6fe85.jpg (deflated 0%)
#   adding: images/val/000097_JPG.rf.f5d6b5572b60dba12a4b39a6af33ac05.jpg (deflated 0%)
#   adding: images/val/000124_JPG.rf.11c5626f03313f2a2700d2131bbee98e.jpg (deflated 10%)
#   adding: images/val/000021_jpg.rf.22832d293d317b13e588374218a71e00.jpg (deflated 1%)
#   adding: images/val/000069_JPG.rf.754c7034631beace810600af537cf1d3.jpg (deflated 0%)
#   adding: images/val/000048_jpg.rf.d1fe2466217a45a9b771617022ee7c18.jpg (deflated 1%)
#   adding: images/val/000031_jpg.rf.8c396e9a76da42438aed8a9346072d35.jpg (deflated 3%)
#   adding: images/val/000065_jpg.rf.adefa5b0d326eea9e928516289993384.jpg (deflated 0%)
#   adding: images/val/000077_jpg.rf.37455f94e58126e1310cae690bdf8e25.jpg (deflated 0%)
#   adding: images/val/000027_jpg.rf.17f02195e9d2f6c52cf2ec29995d1190.jpg (deflated 1%)
#   adding: images/val/000015_jpg.rf.8a658891a7ac82f12000145ec489cf4c.jpg (deflated 0%)
#   adding: images/val/000086_jpg.rf.21d6c190ab94e71b2f49fb97de73d378.jpg (deflated 0%)
#   adding: images/val/000012_jpg.rf.fb1054104801ab389977b568bde7e0ce.jpg (deflated 0%)
#   adding: images/val/000053_JPG.rf.8bab99ebbbad46087e65e6c47f7fdaf0.jpg (deflated 0%)
#   adding: images/val/000049_jpg.rf.3dc5ad8a124f2516da33d49496ff55dc.jpg (deflated 0%)
#   adding: images/val/000082_jpg.rf.aa55332900465a30687548c20145a4e4.jpg (deflated 0%)
#   adding: images/val/000021_jpg.rf.686ef3b74a19214af6e22e15ad692bca.jpg (deflated 0%)
#   adding: images/val/000011_jpg.rf.8b7fff6ea8f7330e402b6a7757b1866b.jpg (deflated 0%)
#   adding: images/val/000039_JPG.rf.18085a5d84e17aca7dbc278f39f141a0.jpg (deflated 0%)
#   adding: images/val/000022_jpg.rf.24374a2700679021d5ab94c2ad2434e7.jpg (deflated 1%)
#   adding: images/val/000066_JPG.rf.4d451656ce9628a9eb263c2b47828227.jpg (deflated 4%)
#   adding: images/val/000097_jpg.rf.5ee362e58370980eb351d337f6409ef4.jpg (deflated 0%)
#   adding: images/val/000017_jpg.rf.1b16bea2730faf919fea7016568d1630.jpg (deflated 0%)
#   adding: images/val/000054_jpg.rf.3fa00c0cefb8d7fac889afd3fbfff716.jpg (deflated 2%)
#   adding: images/val/000009_jpg.rf.8434a803f417f51fe5ebe4f6b9697cce.jpg (deflated 1%)
#   adding: images/val/000128_JPG.rf.eb71904df1426bfc208c7f961ae52d22.jpg (deflated 2%)
#   adding: images/val/000008_jpg.rf.a24ec77372a4a2d8f9cd694ffec10c9a.jpg (deflated 0%)
#   adding: images/val/000041_jpg.rf.92043de1d993c43f5aa9b77afd2f1d63.jpg (deflated 1%)
#   adding: images/val/000006_jpg.rf.33a70c1d2244237b53e6924046000d26.jpg (deflated 2%)
#   adding: images/val/000037_jpg.rf.313662ef20a5ccca5fc196365095bf22.jpg (deflated 1%)
#   adding: images/val/000094_JPG.rf.b6241bd0418850c0ca1916017d039774.jpg (deflated 0%)
#   adding: images/val/000081_JPG.rf.a35d5c0eaa37af2f138eb0e1e2401329.jpg (deflated 1%)
#   adding: images/val/000064_jpg.rf.a1cc41f6879e58b49881a28cd5ea539c.jpg (deflated 0%)
#   adding: images/train/ (stored 0%)
#   adding: images/train/000013_jpg.rf.29e141f4c018605414d7abd5ec4740e9.jpg (deflated 0%)
#   adding: images/train/000071_JPG.rf.2b5d02a4e6c70c644358c781ec3d1faa.jpg (deflated 0%)
#   adding: images/train/000005_jpg.rf.2e2ec7a6579289fe5714bdb2753880b4.jpg (deflated 0%)
#   adding: images/train/000105_JPG.rf.a330a129113c4f5f88b610530a971012.jpg (deflated 1%)
#   adding: images/train/000102_JPG.rf.3c36d45336bb9af4b54cb2ac29766390.jpg (deflated 1%)
#   adding: images/train/000082_JPG.rf.f4ab7cd5eb7f3f2eaec22644a49b4280.jpg (deflated 0%)
#   adding: images/train/000029_JPG.rf.fcf8924626cf7b9079801100444609a4.jpg (deflated 1%)
#   adding: images/train/000050_JPG.rf.db57f41c8e36c19a476b085e91bcf3d7.jpg (deflated 0%)
#   adding: images/train/000007_jpg.rf.aacac0039250183e0db8e195ab9a1e9f.jpg (deflated 1%)
#   adding: images/train/000085_JPG.rf.3a330c761f605d89e6574aebf45e90a1.jpg (deflated 1%)
#   adding: images/train/000101_JPG.rf.a7c1b7e330f8e26da6f5e66603e76bf6.jpg (deflated 4%)
#   adding: images/train/000115_JPG.rf.427cc9deffec8a9b16bf0afcad140b25.jpg (deflated 0%)
#   adding: images/train/000055_JPG.rf.0ba25c38ed10af00810dda648d2461a0.jpg (deflated 1%)
#   adding: images/train/000127_JPG.rf.fd5002b407acccd8ae1e918c23cf7b91.jpg (deflated 3%)
#   adding: images/train/000040_jpg.rf.acee0a18ebd6288ce78e384562c3071c.jpg (deflated 0%)
#   adding: images/train/000011_jpg.rf.6559a6761a9fef22596aaea88cde3747.jpg (deflated 1%)
#   adding: images/train/000007_jpg.rf.dd0bfb8e733e43961547eec533fea3b8.jpg (deflated 0%)
#   adding: images/train/000028_jpg.rf.dda4470887046c5c09a97fd6b6e6d3f1.jpg (deflated 0%)
#   adding: images/train/000041_JPG.rf.b9c7187161b371d475b9cd1e1e8d1e9a.jpg (deflated 0%)
#   adding: images/train/000043_jpg.rf.4d513b8ca4c5a243fcfb10ad7d3d3052.jpg (deflated 1%)
#   adding: images/train/000069_jpg.rf.46d560bf60ef856322d7dfbf2d0fbbbb.jpg (deflated 0%)
#   adding: images/train/000083_JPG.rf.9d560f08f9052b58d3e4d55b076c2cca.jpg (deflated 0%)
#   adding: images/train/000063_jpg.rf.d1a3a30f3844145e3301b8899b07fac8.jpg (deflated 0%)
#   adding: images/train/000094_JPG.rf.a30f2b512b80a5829b54518071bcce59.jpg (deflated 2%)
#   adding: images/train/000073_JPG.rf.b7b3da44f9a28163038e7d3429b67b27.jpg (deflated 0%)
#   adding: images/train/000007_jpg.rf.c1aa0a792a4edb7de41bcc9a00738a8a.jpg (deflated 14%)
#   adding: images/train/000073_jpg.rf.6842cbbd47a4deaa5efba665912652c5.jpg (deflated 0%)
#   adding: images/train/000005_jpg.rf.003793a128998b50c820a5951d5a5ba5.jpg (deflated 0%)
#   adding: images/train/000079_JPG.rf.0f2718510c3e0e2a18fbc4e7d4883d61.jpg (deflated 1%)
#   adding: images/train/000085_jpg.rf.3474819b7c82c49b380fcdf478766207.jpg (deflated 0%)
#   adding: images/train/000091_jpg.rf.1c2835b63b19d5c0af7a27129abfbb2f.jpg (deflated 0%)
#   adding: images/train/000060_jpg.rf.81ffb8074efac19d9e5262ef20bfb798.jpg (deflated 0%)
#   adding: images/train/000072_JPG.rf.694e1d668b22358432288e9027607c66.jpg (deflated 0%)
#   adding: images/train/000000_jpg.rf.e662cb85f63817325956fea222d0990f.jpg (deflated 1%)
#   adding: images/train/000057_JPG.rf.149bf40f203756af065d76c89db81c27.jpg (deflated 0%)
#   adding: images/train/000078_JPG.rf.11fe3fdd9daf4c106fd15d42463088c9.jpg (deflated 8%)
#   adding: images/train/000009_JPG.rf.ae53b7d399c8fa7b5a4d80c2c59d92ed.jpg (deflated 2%)
#   adding: images/train/000012_jpg.rf.5054aa20e9cbd6b10b821db6b300ac0c.jpg (deflated 1%)
#   adding: images/train/000078_jpg.rf.7bbd087a733dfd7a22418dab6e9d0bce.jpg (deflated 0%)
#   adding: images/train/000030_jpg.rf.e1e9870f5ac27db278018cf38e4134d4.jpg (deflated 0%)
#   adding: images/train/000089_JPG.rf.950dfd2b9380d77f7e5e80a9ff068b5d.jpg (deflated 0%)
#   adding: images/train/000037_jpg.rf.faf287f1243cfc2dcab9aca232abe93d.jpg (deflated 0%)
#   adding: images/train/000043_JPG.rf.97b188ae84207f3ee32e795188a04d0d.jpg (deflated 0%)
#   adding: images/train/000024_jpg.rf.090bff7e0ebd097734b99fa1013d587d.jpg (deflated 1%)
#   adding: images/train/000081_JPG.rf.ea3619a1163b1494d458dbd578f58523.jpg (deflated 0%)
#   adding: images/train/000012_JPG.rf.2c4c735b011d8b107a71fea25fa2e7cd.jpg (deflated 1%)
#   adding: images/train/000055_jpg.rf.44eeba23c4e8813b50a409ad8fb34ad0.jpg (deflated 6%)
#   adding: images/train/000005_JPG.rf.216ea83ee4d2dd49c9633c1367894151.jpg (deflated 9%)
#   adding: images/train/000035_jpg.rf.8db8187059ccaf7094168b0fb6272c8a.jpg (deflated 4%)
#   adding: images/train/000044_jpg.rf.215bd723ad8d987f75dd33f33fbf2c00.jpg (deflated 0%)
#   adding: images/train/000062_jpg.rf.acdd0f27e3fcc9d7a86af6b9c7e22d79.jpg (deflated 0%)
#   adding: images/train/000072_JPG.rf.15eda39142f329e131b4f7b7a8524e6c.jpg (deflated 0%)
#   adding: images/train/000072_jpg.rf.94042e6b9b6418ed601c5b245790afcc.jpg (deflated 0%)
#   adding: images/train/000059_JPG.rf.924270bb72369c33953e656b40325fbd.jpg (deflated 0%)
#   adding: images/train/000048_jpg.rf.2381f52a308a97ca3ee02325e2c93824.jpg (deflated 5%)
#   adding: images/train/000070_jpg.rf.b72d2081548c4410e01638f1713062dc.jpg (deflated 0%)
#   adding: images/train/000021_jpg.rf.dedb632cd4867ee95608a988ff38fee7.jpg (deflated 0%)
#   adding: images/train/000030_jpg.rf.cf4fb622e9b578e660bdc9bfd12accc3.jpg (deflated 0%)
#   adding: images/train/000088_JPG.rf.0b5b57682430c8c107553f91bf24be8e.jpg (deflated 11%)
#   adding: images/train/000073_jpg.rf.89b23fe20d196ec2e09be07f273d97f6.jpg (deflated 0%)
#   adding: images/train/000048_JPG.rf.192e18b148d3faf4514fd896eb5e5326.jpg (deflated 1%)
#   adding: images/train/000074_jpg.rf.8aa73efb149a020c7c5397c454598483.jpg (deflated 0%)
#   adding: images/train/000035_jpg.rf.1452f2f42d63e062ed907eaa79e8e892.jpg (deflated 0%)
#   adding: images/train/000068_JPG.rf.8ad38475b9ee36d5d972e3f3105dba6e.jpg (deflated 0%)
#   adding: images/train/000034_jpg.rf.a2ab4f9fc73f9a6b8ccdde4129d1c8ea.jpg (deflated 0%)
#   adding: images/train/000066_jpg.rf.4cd79288b17ea0efdc2d548acfaeb4cb.jpg (deflated 0%)
#   adding: images/train/000084_JPG.rf.92caefae2de3a94bbab6df88bdf33dc8.jpg (deflated 1%)
#   adding: images/train/000000_JPG.rf.d3371cb3d63a59c5ba6730368b7905af.jpg (deflated 0%)
#   adding: images/train/000096_JPG.rf.81524839612961c65378b67c9944af85.jpg (deflated 0%)
#   adding: images/train/000023_JPG.rf.c65a0d2377e99a060d4cfac3b8273594.jpg (deflated 9%)
#   adding: images/train/000076_jpg.rf.b9b869ca9da200bf355acbf878fd5893.jpg (deflated 0%)
#   adding: images/train/000043_jpg.rf.dcc353439f9822c87e9addf87786a0bd.jpg (deflated 0%)
#   adding: images/train/000020_jpg.rf.94c0d1159c8aaa257792cf2c13801ef9.jpg (deflated 0%)
#   adding: images/train/000013_jpg.rf.9ba00883de5b5dd801c272cce5818c89.jpg (deflated 0%)
#   adding: images/train/000026_jpg.rf.0c461fdb6595f50eeb6fee3b8532f452.jpg (deflated 0%)
#   adding: images/train/000020_jpg.rf.b2ba1f0d153f592d072b38bdd755df45.jpg (deflated 0%)
#   adding: images/train/000049_jpg.rf.272258d1d7994ce7f1064abf6690dc20.jpg (deflated 8%)
#   adding: images/train/000083_JPG.rf.9d1f623c8bef60b865c9c20abfd54386.jpg (deflated 0%)
#   adding: images/train/000052_JPG.rf.9d27271635175c59e9509c7f70d87801.jpg (deflated 1%)
#   adding: images/train/000067_JPG.rf.88f9c6d648c46d0a3195d049c83b8b3d.jpg (deflated 11%)
#   adding: images/train/000090_JPG.rf.c97c3949f635efcdd64c34a3507e0843.jpg (deflated 16%)
#   adding: images/train/000099_JPG.rf.39fa14946e0ae5cf85c07ed1af0c3d00.jpg (deflated 0%)
#   adding: images/train/000028_jpg.rf.da8e70a1ce6cda35988ebe1471b0cd78.jpg (deflated 1%)
#   adding: images/train/000025_JPG.rf.815dda9504412159afed35e46b5a7bc6.jpg (deflated 6%)
#   adding: images/train/000078_jpg.rf.f28c5c7961f5d92ad58e2cab69afbb60.jpg (deflated 0%)
#   adding: images/train/000005_jpg.rf.64c6c9f622771b349148c96d537e8ff5.jpg (deflated 2%)
#   adding: images/train/000057_jpg.rf.090b69a8cf99e176436fb111a65e81c9.jpg (deflated 0%)
#   adding: images/train/000089_jpg.rf.2260e83c8296b37a3532392442fe36ff.jpg (deflated 0%)
#   adding: images/train/000018_jpg.rf.0058d47042114f3a156f9232b3a53568.jpg (deflated 0%)
#   adding: images/train/000088_jpg.rf.9728d1367ea3ab96892d07a6bc662ec3.jpg (deflated 0%)
#   adding: images/train/000051_JPG.rf.6539945e2a3c2ed0824526617798b26c.jpg (deflated 1%)
#   adding: images/train/000025_jpg.rf.96f8a937bf9ac013ea3422706daad7f2.jpg (deflated 0%)
#   adding: images/train/000060_jpg.rf.9f232ad79a42efbeb938398e8867ad51.jpg (deflated 0%)
#   adding: images/train/000022_jpg.rf.6c1e872d94a0fb00c1d2b610a5c3184a.jpg (deflated 0%)
#   adding: images/train/000036_JPG.rf.0c1ef2f74ed2d1b89a669bf5ffd06078.jpg (deflated 1%)
#   adding: images/train/000062_jpg.rf.606ca7944ce7d2b7f87f8ab0d1840baf.jpg (deflated 1%)
#   adding: images/train/000073_JPG.rf.145dc63ae9acd801448a99fe37a03c94.jpg (deflated 0%)
#   adding: images/train/000026_JPG.rf.4e2d2c91e5c4c4797ec026217430960c.jpg (deflated 5%)
#   adding: images/train/000049_jpg.rf.0c8e5b44339feb4cc686ebbd443732c3.jpg (deflated 1%)
# ...
#   adding: images/train/000021_JPG.rf.83716ea370ecf4752af77f799e00cff8.jpg (deflated 2%)
#   adding: images/train/000080_JPG.rf.993f9dbfdbb7c771b54270554b538de5.jpg (deflated 1%)
#   adding: images/train/000050_jpg.rf.10dfca50c92084c90bd0ec9b2b5fbaed.jpg (deflated 1%)
#   adding: images/train/000071_JPG.rf.71712e41ac49488b771991daa54266a9.jpg (deflated 0%)
#   adding: images/train/000076_JPG.rf.a0b9ad753a233efb6df431527a468297.jpg (deflated 0%)
#   adding: images/train/000026_jpg.rf.7f0e1403c9665cc1ab664ca6100d6308.jpg (deflated 0%)
#   adding: images/train/000010_jpg.rf.6c2f5a56db2ee454cac569cf9b78437a.jpg (deflated 0%)
#   adding: images/train/000093_jpg.rf.8d536f36e117812a1ef369c7b67f0635.jpg (deflated 0%)
#   adding: images/train/000019_jpg.rf.a18fa60b6d2094c68414610227aa951d.jpg (deflated 0%)
#   adding: images/train/000016_jpg.rf.62a0c2e7104b1c47655ff1d0bc5890dd.jpg (deflated 0%)
#   adding: images/train/000006_jpg.rf.0c45474870c2a5df516344df31448c15.jpg (deflated 1%)
#   adding: images/train/000076_JPG.rf.a119806e7929c22e2c21ee95d0913e0d.jpg (deflated 0%)
#   adding: images/train/000042_JPG.rf.3540075c32a95902f389fb56efabf3da.jpg (deflated 0%)
#   adding: images/train/000023_jpg.rf.2c7afb3316f1734a18b8d1169b907f85.jpg (deflated 0%)
#   adding: images/train/000043_jpg.rf.89692ae77bf2b39f40254f4998e61121.jpg (deflated 2%)
#   adding: images/train/000055_jpg.rf.58e1c338ac4aa308d78ceb9b8e93d7ee.jpg (deflated 1%)
#   adding: images/train/000038_JPG.rf.d949f49ef17f034a45517c7ee5d4ccd5.jpg (deflated 1%)
#   adding: images/train/000019_JPG.rf.84f4d33da2cd2fcf85f50f1d715a46eb.jpg (deflated 1%)
#   adding: images/train/000036_jpg.rf.6989ea6ca94bc9345c0d3781c5524d8f.jpg (deflated 0%)
#   adding: images/train/000082_jpg.rf.6b6f7ad63a90f9d9d860b803e99ec49a.jpg (deflated 1%)
#   adding: images/train/000092_JPG.rf.f79df099c5856824fcd647d2767596c7.jpg (deflated 0%)
#   adding: images/train/000106_JPG.rf.dc2345e3176c7524cfdbb42983dd3db0.jpg (deflated 8%)
#   adding: images/train/000051_jpg.rf.92178b1d22661dc4a10ffe6bfd5b4277.jpg (deflated 1%)
#   adding: images/train/000048_jpg.rf.de00f8d19645a2ddeb2c60fa6cbee63f.jpg (deflated 1%)
#   adding: images/train/000024_jpg.rf.5ae48b6ddd7f0f7f3ba97f14717cc6c6.jpg (deflated 0%)
#   adding: images/train/000117_JPG.rf.792aeeed8617c75c61e6ca1c5a433dae.jpg (deflated 1%)
#   adding: images/train/000067_jpg.rf.8746caea06137e0d921d481470170ef3.jpg (deflated 0%)
#   adding: images/train/000014_jpg.rf.38b062b115e46087392c4a6a42009aa3.jpg (deflated 0%)
#   adding: images/train/000047_JPG.rf.72be7e73ce0d387830038342f92e0d6d.jpg (deflated 0%)
#   adding: images/train/000040_jpg.rf.70a4d78ca394877e9ecd43e10e3ec9ab.jpg (deflated 1%)
#   adding: images/train/000079_JPG.rf.0d7e0fb2df1f2aaa5b5c3966ccf931b1.jpg (deflated 8%)
#   adding: images/train/000029_jpg.rf.f3e792ceb992bc41415a77a69c5b93ee.jpg (deflated 0%)
#   adding: images/train/000014_jpg.rf.927348ca51d74a05e3c578fcce761d33.jpg (deflated 1%)
#   adding: images/train/000017_jpg.rf.8f00dc3b244ac3116d76a494bf3d15c1.jpg (deflated 0%)
#   adding: images/train/000022_JPG.rf.2142a3416365cf34993f4abb1d7d8458.jpg (deflated 2%)
#   adding: images/train/000032_jpg.rf.8dd019d56117c6c3bfe285d764931d2f.jpg (deflated 1%)
#   adding: images/train/000018_jpg.rf.5ed8b50a0baee1603b659c848822fa24.jpg (deflated 1%)
#   adding: images/train/000093_JPG.rf.80736b0d6e3659f91445ad3fce4c95e4.jpg (deflated 0%)
#   adding: images/train/000091_JPG.rf.54bec092812303b6db4922bdb9945a4f.jpg (deflated 10%)
#   adding: images/train/000088_JPG.rf.e947547f0688564d69784cf4b067cc05.jpg (deflated 1%)
#   adding: images/train/000034_jpg.rf.82ca4f12eecc7c30bea59f141d42dfb3.jpg (deflated 1%)
#   adding: images/train/000056_JPG.rf.dfcd12c23a39c09df1dd428915deb8f6.jpg (deflated 0%)
#   adding: images/train/000053_jpg.rf.6767a8e4466955cd84a41f391e4aef80.jpg (deflated 1%)
#   adding: images/train/000096_JPG.rf.bb1e71a6719d5b92c64747e681d3193a.jpg (deflated 2%)
#   adding: images/train/000006_jpg.rf.6748007ba9263baa2c6a7961da13e343.jpg (deflated 1%)
#   adding: images/train/000022_jpg.rf.6305b19f11fbdabcba40fa94e8b45bbd.jpg (deflated 0%)
#   adding: images/train/000010_jpg.rf.69db314ea2d581e398dbbc6b0477b22a.jpg (deflated 0%)
#   adding: images/train/000092_jpg.rf.ffe152373a93f35fe9e4e95baa88cf63.jpg (deflated 0%)
#   adding: images/train/000003_jpg.rf.9ca0e5925486fa97540b07414ea9b277.jpg (deflated 0%)
#   adding: images/train/000045_jpg.rf.a3ae271406456c4ad09b79565c688343.jpg (deflated 0%)
#   adding: images/train/000010_JPG.rf.80b3f35a4216f2c10fe1457f402994bf.jpg (deflated 1%)
#   adding: images/train/000040_jpg.rf.4e71645b58f3690e9fb7c065df60327c.jpg (deflated 0%)
#   adding: images/train/000035_JPG.rf.0d4d0bd8899beca4e91a1510ceaee1fc.jpg (deflated 1%)
#   adding: images/train/000034_JPG.rf.d6ff68db163a8b54ffcd3abf769bfe20.jpg (deflated 1%)
#   adding: images/train/000096_jpg.rf.9a4acf1ff6f712d135693810d6776ba6.jpg (deflated 0%)
#   adding: images/train/000013_JPG.rf.da886096a055f2b459a99d202eb3fdbf.jpg (deflated 0%)
#   adding: images/train/000033_jpg.rf.3c607c41efea726d6b92ffdf6596d6dd.jpg (deflated 0%)
#   adding: images/train/000024_JPG.rf.f8cbab833a31156b0ba7441b9bcee081.jpg (deflated 15%)
#   adding: images/train/000067_jpg.rf.a9517e2a94617e0eb350cc2dedc84fa7.jpg (deflated 0%)
#   adding: images/train/000077_jpg.rf.7107bcb67410ae43090bc6c4644d2e01.jpg (deflated 0%)
#   adding: images/train/000107_JPG.rf.8e2873181ee1acfb953a1ef5f3506bda.jpg (deflated 3%)
#   adding: images/train/000014_JPG.rf.7b43c4e66af30c5b5e9914628b7a92e1.jpg (deflated 2%)
#   adding: images/train/000081_jpg.rf.ddc70e72bf7f39fce3a6892c203459f3.jpg (deflated 0%)
#   adding: images/train/000001_jpg.rf.a23b83dbda863601c92725ae9ba3bab7.jpg (deflated 0%)
#   adding: images/train/000084_jpg.rf.f44a770ba1b45b5390f90e977e147578.jpg (deflated 3%)
#   adding: images/train/000045_jpg.rf.455034f3fb1f0f78b617ba0d877dea3c.jpg (deflated 7%)
#   adding: images/train/000047_jpg.rf.e449cc43414312bd60753116ff1cd5b9.jpg (deflated 4%)
#   adding: images/train/000004_jpg.rf.2b05f74aef4b9075fc4850b59e2cb840.jpg (deflated 0%)
#   adding: images/train/000074_JPG.rf.67fca822f9b1926b356922af64e583f4.jpg (deflated 0%)
#   adding: images/train/000044_JPG.rf.62df54827e28b5224339874dad868241.jpg (deflated 0%)
#   adding: images/train/000047_jpg.rf.07bed9ecc70954519a440edb39ffa37f.jpg (deflated 0%)
#   adding: images/train/000077_JPG.rf.e9b90c05e5361fe7c9eeb5f3c644a975.jpg (deflated 1%)
#   adding: images/train/000044_jpg.rf.b397d82ddd718a92bb3e8adc6d0cbea7.jpg (deflated 0%)
#   adding: images/train/000095_JPG.rf.e753a5b2a9e39abe1223dd53e3e1cc3b.jpg (deflated 3%)
#   adding: images/train/000110_JPG.rf.1234fd1e36c337e944e129929f83d0db.jpg (deflated 0%)
#   adding: images/train/000004_jpg.rf.bc8c3c9f203da611f150d441db9ac7ae.jpg (deflated 0%)
#   adding: images/train/000038_jpg.rf.e84ad63ee9a34f619e6bd2b41ef98607.jpg (deflated 1%)
#   adding: images/train/000111_JPG.rf.927d622eef402872a82857c9023d8dc8.jpg (deflated 0%)
#   adding: images/train/000056_jpg.rf.0d4d304fd2f03ba889305fb9ff43394b.jpg (deflated 0%)
#   adding: images/train/000093_JPG.rf.664f76e5289f311393e8e9388334022d.jpg (deflated 4%)
#   adding: images/train/000027_JPG.rf.8063f46827257d27073fc88c205da226.jpg (deflated 7%)
#   adding: images/train/000080_jpg.rf.bfa237d8070193b4cb690ae88b747d0f.jpg (deflated 0%)
#   adding: images/train/000027_jpg.rf.971b8cf615c3c0239d8d8acf9bf5e93b.jpg (deflated 0%)
#   adding: images/train/000040_JPG.rf.fc1bb55b2d7de403f691406d979da825.jpg (deflated 0%)
#   adding: images/train/000038_jpg.rf.42a1060772b6e12dea0366652ecf9817.jpg (deflated 1%)
#   adding: images/train/000008_jpg.rf.581796408fb44c037aa30c62dd8400c5.jpg (deflated 0%)
#   adding: images/train/000050_jpg.rf.2e801127ca66b17e472bca68800afb40.jpg (deflated 5%)
#   adding: images/train/000086_JPG.rf.2b89cfe42c327e4eea7d99d8c5fa456e.jpg (deflated 1%)
#   adding: images/train/000082_JPG.rf.00a21c7095239899701f24df09060248.jpg (deflated 0%)
#   adding: images/train/000129_JPG.rf.eb4bb302dd9580081c49afc5465f58ce.jpg (deflated 3%)
#   adding: images/train/000055_jpg.rf.819465c234876c06ce66ea2fc9c9b2d6.jpg (deflated 1%)
#   adding: images/train/000030_JPG.rf.c15e0ebc324ac9b1c9789f824124ebb8.jpg (deflated 2%)
#   adding: images/train/000014_jpg.rf.ea60de2dbaca4cb3980931bc035b65b9.jpg (deflated 0%)
#   adding: images/train/000098_JPG.rf.11ffd21ae91ef5ba3c82ec792c0f0b60.jpg (deflated 1%)
#   adding: images/train/000032_JPG.rf.2f4a0c2e65acfb0c0bd48599204a16a5.jpg (deflated 7%)
#   adding: images/train/000027_jpg.rf.78100628554443378adcc62660a75524.jpg (deflated 0%)
#   adding: images/train/000053_jpg.rf.58742b4cc98ffea73836546c05bc1547.jpg (deflated 3%)
#   adding: images/train/000046_JPG.rf.c5f7cb4aba7aaca4f6386737a180f353.jpg (deflated 0%)
#   adding: images/train/000061_JPG.rf.5d8e6c70d07936c222d0513ae3ab920f.jpg (deflated 0%)
#   adding: images/train/000039_jpg.rf.abffb6d1a849a745b7323aa5402ea595.jpg (deflated 1%)
#   adding: images/train/000074_jpg.rf.ec9d0227c327aae1a43d1ece31927667.jpg (deflated 0%)
#   adding: images/train/000008_JPG.rf.b7fd07c74e94aeda797b5469cb78809a.jpg (deflated 2%)
#   adding: images/train/000120_JPG.rf.520a1f3428c6ebd24d3fdd103082afc0.jpg (deflated 1%)
#   adding: images/train/000070_jpg.rf.b047a475b7f68a21260af3a9000acf42.jpg (deflated 1%)
#   adding: images/train/000047_jpg.rf.c04a677ec28e0c24aaeec39f894b1fe2.jpg (deflated 1%)
#   adding: images/train/000049_JPG.rf.e209e826a07c82e6068790992a260120.jpg (deflated 1%)
#   adding: images/train/000037_JPG.rf.93d931816a73f48ddc2f46341f3316c2.jpg (deflated 0%)
#   adding: images/train/000042_jpg.rf.04f62abf4f94222669321580b8270762.jpg (deflated 1%)
#   adding: images/train/000074_JPG.rf.47a9151525777468c44e8691f29e6789.jpg (deflated 0%)
#   adding: images/train/000122_JPG.rf.257323c30f94a7c71f2db4613eb8bac5.jpg (deflated 0%)
#   adding: images/train/000104_JPG.rf.332a5aa47edc75e29cc9a26b80635198.jpg (deflated 18%)
#   adding: images/train/000026_jpg.rf.cb9edd2738736188ea9a5c1a33f2d085.jpg (deflated 0%)
#   adding: images/train/000057_jpg.rf.36c41aa6a8b0706bcdabbc74693ca82b.jpg (deflated 0%)
#   adding: images/train/000099_JPG.rf.c2ef3af6f95642fde1e1f26c70bc8726.jpg (deflated 2%)
#   adding: images/train/000032_jpg.rf.7133218ca5f644dad64b6936fb74201f.jpg (deflated 1%)
#   adding: images/train/000054_JPG.rf.76b2370020ef79a2e46989421daa1133.jpg (deflated 0%)
#   adding: images/train/000045_jpg.rf.35d41e4cce69c5e3fdf60eba5fd9f01e.jpg (deflated 0%)
#   adding: images/train/000062_JPG.rf.6b330fe3640fd645f556b593287bd5b5.jpg (deflated 0%)
#   adding: images/train/000013_jpg.rf.276a38f9b9f8e84d3f72cc9cabba0cfc.jpg (deflated 0%)
#   adding: images/train/000052_jpg.rf.25b847f3b003bf3d15c848751ee6c4e3.jpg (deflated 1%)
#   adding: images/train/000001_JPG.rf.ccfdd243a78a6cfa119be0349d18c0ed.jpg (deflated 1%)
#   adding: images/train/000036_jpg.rf.da61f54af653c78b4df5c3ef1c2606d1.jpg (deflated 0%)
#   adding: images/train/000100_JPG.rf.09ba700d952797e7bcc046066f1758d4.jpg (deflated 5%)
#   adding: images/train/000076_jpg.rf.175c02bcb8e9c7b877f0e092de470156.jpg (deflated 1%)
#   adding: images/train/000070_JPG.rf.002423292827c0192719e23f3ee1d20a.jpg (deflated 0%)
#   adding: images/train/000059_jpg.rf.8a05b618a5d7b50ee78f9014a0f0b85f.jpg (deflated 0%)
#   adding: images/train/000083_jpg.rf.d2118dfada822631307421d62fc27a7d.jpg (deflated 0%)
#   adding: images/train/000058_JPG.rf.4ca01dd26d4560668e688cef86d9991b.jpg (deflated 0%)
#   adding: images/train/000059_jpg.rf.e9dd8b4e994229ab3e92710b6cc8e4af.jpg (deflated 14%)
#   adding: images/train/000099_jpg.rf.553bd2f567aead09fa6ce582ee1f1fdb.jpg (deflated 0%)
#   adding: images/train/000081_jpg.rf.3324339669b6639069474cead9b2d18a.jpg (deflated 1%)
#   adding: images/train/000059_jpg.rf.acd795453e9adb3e6722da8075e66b05.jpg (deflated 0%)
#   adding: images/train/000090_jpg.rf.ec22543b6e14ec1cac1f5a0013bb863d.jpg (deflated 0%)
#   adding: images/train/000052_jpg.rf.a786dd2b6c05e8ffdb102af2b2e11be1.jpg (deflated 1%)
#   adding: images/train/000095_JPG.rf.6a841ed816f96a34eaaba03356885682.jpg (deflated 0%)
#   adding: images/train/000002_jpg.rf.ba12a4ce95a3dd81818a5e373efe28be.jpg (deflated 0%)
#   adding: images/train/000016_jpg.rf.73e85f3f95f7bdba3be928f90b7586f5.jpg (deflated 1%)
#   adding: images/train/000063_JPG.rf.c34b95fa0c610f82e3cada41a46d5f95.jpg (deflated 0%)
#   adding: images/train/000075_jpg.rf.bd32d52408fa0d543d2c48baacf7404c.jpg (deflated 0%)
#   adding: images/train/000090_JPG.rf.bc3088c0d0847041b9a2274937af9057.jpg (deflated 0%)
#   adding: images/train/000039_jpg.rf.35f589fbfaa26392393ed6370dcb7d72.jpg (deflated 1%)
#   adding: images/train/000042_jpg.rf.50f2d9c09c3129b84f2ef041e24b38c0.jpg (deflated 2%)
#   adding: images/train/000121_JPG.rf.cf0d71db1bc87ad39a55c0a70bbbd0a0.jpg (deflated 0%)
#   adding: images/train/000031_JPG.rf.5556409546e8d45b63abb898a841cbf0.jpg (deflated 2%)
#   adding: images/train/000065_jpg.rf.db526887a8a626cbec62106baf05c712.jpg (deflated 0%)
#   adding: images/train/000038_jpg.rf.f495ce764fef2fedcefdf9da0b96510a.jpg (deflated 1%)
#   adding: images/train/000023_jpg.rf.1957fc0be7e5963e79f9caa40915198d.jpg (deflated 0%)
#   adding: images/train/000028_jpg.rf.b86deb4fce55807f757fa2b52feba0af.jpg (deflated 0%)
#   adding: images/train/000069_JPG.rf.4769df06d950594f211723a5fb04c972.jpg (deflated 0%)
#   adding: images/train/000064_JPG.rf.82e6a02e0c40403343b8b5d42eb828be.jpg (deflated 5%)
#   adding: images/train/000003_jpg.rf.cf210b41c1d6dfa4e817572b3eae08b6.jpg (deflated 1%)
#   adding: images/train/000066_jpg.rf.75f8981fccaeeb5214198ca1b0011e4e.jpg (deflated 0%)
#   adding: images/train/000037_jpg.rf.8ad39cbfee50a24f9206369a13376025.jpg (deflated 1%)
#   adding: images/train/000118_JPG.rf.7210ba6eef46f0727afbc548098fee07.jpg (deflated 0%)
#   adding: images/train/000001_jpg.rf.3b10b06a0479e6c9e52202033c95d203.jpg (deflated 0%)
#   adding: images/train/000062_JPG.rf.d6fb3faeeeebdde7bc81cac72f5f2667.jpg (deflated 0%)
#   adding: images/train/000003_JPG.rf.94d22bad4e3f02b1bef15f769561cd9e.jpg (deflated 11%)
#   adding: images/train/000064_JPG.rf.a76010b9e4374502cab5dc7a4bf721ab.jpg (deflated 0%)
#   adding: images/train/000087_jpg.rf.690ec33d4afb8bd8fe24d397b278fa19.jpg (deflated 0%)
#   adding: images/train/000003_jpg.rf.9977c8a2ac9cb00ea0f60901a4b77333.jpg (deflated 0%)
#   adding: images/train/000087_JPG.rf.468a151affd32005f62c675d8e1bb714.jpg (deflated 2%)
#   adding: images/train/000083_jpg.rf.249c5fa4724ca90ecd2ad773286ea1ac.jpg (deflated 0%)
#   adding: images/train/000075_JPG.rf.56a161638e45d3d42c88e751bae4ff44.jpg (deflated 1%)
#   adding: images/train/000056_jpg.rf.59f517d36d5603cf93fab05fe19eaf51.jpg (deflated 7%)
#   adding: images/train/000031_jpg.rf.29e96ddf2bdb022113e103b7a75835de.jpg (deflated 0%)
#   adding: images/train/000075_jpg.rf.70594fffc48d625deb65ece444d3696c.jpg (deflated 0%)
#   adding: images/train/000011_jpg.rf.5ce2ed4dcf441076fc5244f22aedb9b7.jpg (deflated 0%)
#   adding: images/train/000070_JPG.rf.ac12be75acbb1f1fca8f1947860d0da1.jpg (deflated 2%)
#   adding: images/train/000098_jpg.rf.293ef58f232e1d7f69675e47277df69f.jpg (deflated 0%)
#   adding: images/train/000017_JPG.rf.da78d08bc1a77af01c0c4c51a71f6f70.jpg (deflated 1%)
#   adding: images/train/000095_jpg.rf.5a1e9f2f9e387ba2f2c8155b8410656e.jpg (deflated 0%)
#   adding: images/train/000008_jpg.rf.aebe91f54e904a647432057275ae9403.jpg (deflated 4%)
#   adding: images/train/000051_jpg.rf.b4ca307c76db86f30e337b25e9fa54cd.jpg (deflated 1%)
#   adding: images/train/000086_JPG.rf.a9c84c634a161dec85f5ca62fff0d0b7.jpg (deflated 3%)
#   adding: images/train/000060_JPG.rf.484b7b820b45a4f99f2657b9e9179be9.jpg (deflated 0%)
#   adding: images/train/000068_jpg.rf.454129fcb1f7c7d009626ba0adddc8b3.jpg (deflated 0%)
#   adding: images/train/000072_jpg.rf.390f3117daa887331568b07f96fbd893.jpg (deflated 0%)
#   adding: images/train/000094_jpg.rf.ffade2ec7e41ef7d1fe564591764eb43.jpg (deflated 0%)
#   adding: images/train/000065_JPG.rf.8ffc3e122419146e7016bcefe3df02fc.jpg (deflated 0%)
#   adding: images/train/000017_jpg.rf.ba2e5fa6533e4d7816d2a7e294a6d040.jpg (deflated 1%)
#   adding: images/train/000016_JPG.rf.9a8b06d326724914d88ff7bf7e59a19b.jpg (deflated 1%)
# ✅ Zip created at /content/20250602_aquatrash_yolo.zip
